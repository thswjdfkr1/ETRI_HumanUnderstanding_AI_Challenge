# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install optuna catboost
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting catboost
#   Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (8.5.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 30.8 MB/s eta 0:00:00
# Downloading catboost-1.2.8-cp312-cp312-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 23.4 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna, catboost
# Successfully installed catboost-1.2.8 colorlog-6.10.1 optuna-4.5.0

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import glob
import random
import os
import matplotlib.pyplot as plt
import seaborn as sns
import ast
from functools import reduce
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ParameterSampler
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

import optuna
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline

from lightgbm import LGBMClassifier
from lightgbm import early_stopping, log_evaluation
from xgboost import XGBClassifier
from catboost import CatBoostClassifier


from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier

from tqdm import tqdm
from collections import defaultdict
from itertools import combinations

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
# from pytorch_tabnet.tab_network import TabNetEncoder

# %%
seed = 810

def set_seed(sd):
    random.seed(sd)
    np.random.seed(sd)
    os.environ['PYTHONHASHSEED'] = str(sd)
    random.seed(sd)
    np.random.seed(sd)
    torch.manual_seed(sd)
    torch.cuda.manual_seed_all(sd)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(seed)

# %%
data_dir = '/content/drive/MyDrive/ETRI_휴먼이해_인공지능/ETRI_lifelog_dataset/'

# %%
Q1_Q3 = pd.read_csv(data_dir + 'prep_df_Q1-3.csv')
S1_S2 = pd.read_csv(data_dir + 'prep_df_S1-2.csv')
S3 = pd.read_csv(data_dir + 'prep_df_S3.csv')

pred_df_list = [Q1_Q3,S1_S2,S3]
prep_df = reduce(lambda left, right: pd.merge(left, right, on=['subject_id', 'date'], how='outer'), pred_df_list)

metrics_train = pd.read_csv(data_dir + 'ch2025_metrics_train.csv')
sample_submission = pd.read_csv(data_dir + 'ch2025_submission_sample.csv')

# %%
prep_df.shape
# Out:
# (806, 432)

# %% [markdown]
# # train/test 데이터셋

# %%
# datetime 형으로 변환
metrics_train['lifelog_date'] = pd.to_datetime(metrics_train['lifelog_date']).dt.date
sample_submission['lifelog_date'] = pd.to_datetime(sample_submission['lifelog_date']).dt.date
prep_df['date'] = pd.to_datetime(prep_df['date']).dt.date
# prep_df.loc[:, 'date'] = pd.to_datetime(prep_df.loc[:, 'date']).dt.date

# %%
# train_df
metrics_train_renamed = metrics_train.rename(columns = {'lifelog_date': 'date'})

train_df = pd.merge(metrics_train_renamed, prep_df, on=['subject_id', 'date'], how='inner')
print(train_df.shape)
# Out:
# (450, 439)

# %%
# test_df
sample_submission_renamed = sample_submission.rename(columns = {'lifelog_date': 'date'})

test_df = pd.merge(sample_submission_renamed, prep_df, on=['subject_id', 'date'], how='inner')
print(test_df.shape)
# Out:
# (250, 439)

# %%
# def clear_columns_names(df):
#   df.columns = (df.columns
#                 .str.replace(r"[^\w]", "_", regex=True)
#                 .str.replace(r'__+','_', regex=True)
#                 .str.strip('_')
#                 )
#   return df

# train_df = clear_columns_names(train_df)
# test_df = clear_columns_names(test_df)

# %% [markdown]
# # X/y 설정

# %%
x = train_df.drop(columns=['subject_id', 'sleep_date', 'date', 'Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3'])
y = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']]
test_x = test_df[x.columns]

x.fillna(0, inplace=True)
y.fillna(0, inplace=True)
test_x.fillna(0, inplace=True)

# %%
print('train shape:', train_df.shape)
print('train X shape:', x.shape)
print('train y shape:', y.shape)
print()
print('test X shape:', test_df.shape)
print('test shape:', test_x.shape)
# Out:
# train shape: (450, 439)
# train X shape: (450, 430)
# train y shape: (450, 6)
#
# test X shape: (250, 439)
# test shape: (250, 430)

# %%
def find_duplicate(df):
  return df.columns[df.columns.duplicated()].tolist()

dup_x = find_duplicate(x)
dup_test_x = find_duplicate(test_x)
print('x_중복컬럼:', dup_x)
print('test_x_중복컬럼:', dup_test_x)

x_columns = set(x.columns)
test_x_columns = set(test_x.columns)

only_x = x_columns - test_x_columns
only_test_x = test_x_columns - x_columns
print('only_x:', only_x)
print('only_x_test:', only_test_x)
# Out:
# x_중복컬럼: []
# test_x_중복컬럼: []
# only_x: set()
# only_x_test: set()

# %% [markdown]
# # 종속변수별 features

# %%
# features = {
#     'Q1_feat': x.columns[x.columns.str.startswith('Q1')],
#     'Q2_feat': x.columns[x.columns.str.startswith('Q2')],
#     'Q3_feat': x.columns[x.columns.str.startswith('Q2')],
#     'S1_feat': x.columns[x.columns.str.startswith('S1')],
#     'S2_feat': x.columns[x.columns.str.startswith('S1')],
#     'S3_feat': x.columns[x.columns.str.startswith('S3')]
# }

# target_to_feat = {
#     'Q1': features['Q1_feat'],
#     'Q2': features['Q2_feat'],
#     'Q3': features['Q3_feat'],
#     'S1': features['S1_feat'],
#     'S2': features['S2_feat'],
#     'S3': features['S3_feat']
# }

# %%
feat = {
    'Q1': 'Q1',
    'Q2': 'Q2',
    'Q3': 'Q2',
    'S1': 'S1',
    'S2': 'S1',
    'S3': 'S3'
}

features = {k: x.columns[x.columns.str.startswith(v)] for k, v in feat.items()}

# %% [markdown]
# # 데이터 분할

# %%
targets_binary = ['Q1', 'Q2', 'Q3', 'S2', 'S3']
target_multi = ['S1']

split_data = {}
for col in targets_binary + target_multi:
    y = train_df[col]
    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, stratify=y, random_state=seed)
    split_data[col] = (x_train, x_val, y_train, y_val)

# %% [markdown]
# # smote + lgbm

# %%
# def check_smote_sample(split_data, col):
#     x_train, _, y_train, _ = split_data[col]

#     smote = SMOTE(sampling_strategy='minority', random_state=seed)

#     skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
#     for train_idx, _ in skf.split(x_train, y_train):
#         x_fold, y_fold = x_train.iloc[train_idx], y_train.iloc[train_idx]
#         x_resampled, y_resampled = smote.fit_resample(x_fold, y_fold)

#         print(f"Before SMOTE: {y_fold.value_counts().to_dict()}")
#         print(f"After SMOTE: {pd.Series(y_resampled).value_counts().to_dict()}")
#         print(f"x_resampled shape: {x_resampled.shape}")

#         break  # 한 fold만 확인

# %%
lgbm_best_param_dict = {}

def smote_optuna_binary(split_date):
  for col in targets_binary:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]


    def objective_binary(trial):
      params = {
          'learning_rate': trial.suggest_float("lr", 1e-5, 1e-1, log=True),
          'n_estimators': trial.suggest_int('n_estimators', 50, 500),
          'max_depth': trial.suggest_int('max_depth', 2, 32),
          'num_leaves': trial.suggest_int('num_leaves', 16, 64),
          'subsample': trial.suggest_float('subsample', 0.5, 1.0),
          'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
          'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
          'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
          'path_smooth' : trial.suggest_loguniform('path_smooth', 1e-8, 1e-3),
          'num_leaves' : trial.suggest_int('num_leaves', 30, 200),
          'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
          'max_bin' : trial.suggest_int('max_bin', 100, 255),
          'feature_fraction' : trial.suggest_uniform('feature_fraction', 0.5, 0.9),
          'bagging_fraction' : trial.suggest_uniform('bagging_fraction', 0.5, 0.9),
          'random_state': seed,
          'n_jobs': -1,
          'verbosity': -1
      }

      feat = features[col]
      clf_binary = LGBMClassifier(**params)
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='minority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score = cross_val_score(pipeline, x_train[feat], y_train, cv=cv, scoring='f1').mean()

      trial.report(score, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score

    study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=seed))
    study.optimize(objective_binary, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    lgbm_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_binary(split_data)
# Out:
# [I 2025-10-24 06:23:21,817] A new study created in memory with name: no-name-3e228266-d16d-4362-843a-6f447d2c69f1
# === target: Q1 ===
# [I 2025-10-24 06:23:23,557] Trial 0 finished with value: 0.5161165090159672 and parameters: {'lr': 1.5106249671860432e-05, 'n_estimators': 339, 'max_depth': 31, 'num_leaves': 17, 'subsample': 0.5023240118702073, 'colsample_bytree': 0.7526598267090864, 'reg_alpha': 0.6834515648539062, 'reg_lambda': 4.603537484050716, 'path_smooth': 4.1267228833656876e-08, 'min_data_in_leaf': 74, 'max_bin': 172, 'feature_fraction': 0.6605739639515698, 'bagging_fraction': 0.592452365530872}. Best is trial 0 with value: 0.5161165090159672.
# [I 2025-10-24 06:23:25,830] Trial 1 finished with value: 0.509876431081947 and parameters: {'lr': 2.708916662683437e-05, 'n_estimators': 186, 'max_depth': 4, 'num_leaves': 63, 'subsample': 0.5372630344763973, 'colsample_bytree': 0.849442817276649, 'reg_alpha': 0.09266314028306984, 'reg_lambda': 1.1663679970572534, 'path_smooth': 2.0788347659089347e-06, 'min_data_in_leaf': 50, 'max_bin': 141, 'feature_fraction': 0.599451423457273, 'bagging_fraction': 0.7580210670788405}. Best is trial 0 with value: 0.5161165090159672.
# [I 2025-10-24 06:23:26,254] Trial 2 finished with value: 0.5398421001646808 and parameters: {'lr': 1.5387507769813355e-05, 'n_estimators': 478, 'max_depth': 25, 'num_leaves': 19, 'subsample': 0.8903762209202944, 'colsample_bytree': 0.7884919116004143, 'reg_alpha': 0.015516998171697351, 'reg_lambda': 4.807638732776518, 'path_smooth': 4.6122213491899746e-07, 'min_data_in_leaf': 100, 'max_bin': 184, 'feature_fraction': 0.5859246944646821, 'bagging_fraction': 0.8591900416062732}. Best is trial 2 with value: 0.5398421001646808.
# [I 2025-10-24 06:23:26,741] Trial 3 finished with value: 0.497880822517285 and parameters: {'lr': 0.0003949565350617718, 'n_estimators': 433, 'max_depth': 23, 'num_leaves': 39, 'subsample': 0.7071083559176792, 'colsample_bytree': 0.5496234775811784, 'reg_alpha': 0.013551397268244015, 'reg_lambda': 0.3294174003334398, 'path_smooth': 1.1082047819203755e-07, 'min_data_in_leaf': 41, 'max_bin': 202, 'feature_fraction': 0.6154333863457454, 'bagging_fraction': 0.6344213222785804}. Best is trial 2 with value: 0.5398421001646808.
# [I 2025-10-24 06:23:27,362] Trial 4 finished with value: 0.526905149555752 and parameters: {'lr': 0.00024842547867017325, 'n_estimators': 373, 'max_depth': 12, 'num_leaves': 19, 'subsample': 0.6246250399067793, 'colsample_bytree': 0.7905619719408312, 'reg_alpha': 0.5311818664356938, 'reg_lambda': 0.05908387293672967, 'path_smooth': 1.970364963074316e-08, 'min_data_in_leaf': 15, 'max_bin': 109, 'feature_fraction': 0.8716354302039999, 'bagging_fraction': 0.5817532287988983}. Best is trial 2 with value: 0.5398421001646808.
# [I 2025-10-24 06:23:27,628] Trial 5 pruned.
# [I 2025-10-24 06:23:27,976] Trial 6 finished with value: 0.5548215662281846 and parameters: {'lr': 0.004971176898604735, 'n_estimators': 454, 'max_depth': 17, 'num_leaves': 43, 'subsample': 0.8113435608863484, 'colsample_bytree': 0.5089423697793136, 'reg_alpha': 0.027209075541545648, 'reg_lambda': 0.7122607052005215, 'path_smooth': 8.866574261031164e-07, 'min_data_in_leaf': 62, 'max_bin': 102, 'feature_fraction': 0.8457642154451177, 'bagging_fraction': 0.5789877096369924}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:28,382] Trial 7 finished with value: 0.5335420686935193 and parameters: {'lr': 0.030708209305572505, 'n_estimators': 463, 'max_depth': 22, 'num_leaves': 19, 'subsample': 0.6542488308929868, 'colsample_bytree': 0.7237448195681488, 'reg_alpha': 0.2171478639402438, 'reg_lambda': 3.3978134684137644, 'path_smooth': 0.00028973076199137357, 'min_data_in_leaf': 56, 'max_bin': 240, 'feature_fraction': 0.7779933956373506, 'bagging_fraction': 0.6220690244156954}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:30,380] Trial 8 finished with value: 0.5319179205113992 and parameters: {'lr': 4.915582398065948e-05, 'n_estimators': 60, 'max_depth': 5, 'num_leaves': 46, 'subsample': 0.6438518665043911, 'colsample_bytree': 0.6589654033338963, 'reg_alpha': 0.07536134088594347, 'reg_lambda': 0.03184880122203618, 'path_smooth': 8.851563484150123e-08, 'min_data_in_leaf': 15, 'max_bin': 150, 'feature_fraction': 0.5734300459735587, 'bagging_fraction': 0.6766331659840753}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:31,204] Trial 9 pruned.
# [I 2025-10-24 06:23:31,540] Trial 10 pruned.
# [I 2025-10-24 06:23:31,969] Trial 11 pruned.
# [I 2025-10-24 06:23:32,187] Trial 12 finished with value: 0.5429940231489632 and parameters: {'lr': 0.006021345548435333, 'n_estimators': 275, 'max_depth': 25, 'num_leaves': 29, 'subsample': 0.8528657163700814, 'colsample_bytree': 0.6140904265707321, 'reg_alpha': 0.0015551897153078472, 'reg_lambda': 9.98085768781422, 'path_smooth': 2.0452367009361094e-05, 'min_data_in_leaf': 100, 'max_bin': 152, 'feature_fraction': 0.7038597709471098, 'bagging_fraction': 0.7880498247413726}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:32,447] Trial 13 finished with value: 0.5409321231594975 and parameters: {'lr': 0.011716400539893784, 'n_estimators': 269, 'max_depth': 13, 'num_leaves': 29, 'subsample': 0.8445456150718824, 'colsample_bytree': 0.583612722890957, 'reg_alpha': 0.0011149777707300792, 'reg_lambda': 0.6036994826199316, 'path_smooth': 2.1697841480054103e-05, 'min_data_in_leaf': 76, 'max_bin': 134, 'feature_fraction': 0.7169041518086439, 'bagging_fraction': 0.5075740451573518}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:32,715] Trial 14 pruned.
# [I 2025-10-24 06:23:32,986] Trial 15 pruned.
# [I 2025-10-24 06:23:33,302] Trial 16 finished with value: 0.5386952206990184 and parameters: {'lr': 0.090541508202328, 'n_estimators': 195, 'max_depth': 14, 'num_leaves': 37, 'subsample': 0.8248244638833507, 'colsample_bytree': 0.6968800214614178, 'reg_alpha': 0.004131109789370319, 'reg_lambda': 0.18765327009712943, 'path_smooth': 0.0008745080531220849, 'min_data_in_leaf': 31, 'max_bin': 125, 'feature_fraction': 0.8389084511581799, 'bagging_fraction': 0.7051533926917923}. Best is trial 6 with value: 0.5548215662281846.
# [I 2025-10-24 06:23:33,493] Trial 17 pruned.
# [I 2025-10-24 06:23:33,944] Trial 18 pruned.
# [I 2025-10-24 06:23:34,250] Trial 19 pruned.
# [I 2025-10-24 06:23:34,572] Trial 20 pruned.
# [I 2025-10-24 06:23:34,876] Trial 21 pruned.
# [I 2025-10-24 06:23:35,107] Trial 22 finished with value: 0.5597345721153594 and parameters: {'lr': 0.01410010085893031, 'n_estimators': 238, 'max_depth': 20, 'num_leaves': 24, 'subsample': 0.9453782791291039, 'colsample_bytree': 0.5699752659096942, 'reg_alpha': 0.001861356522201003, 'reg_lambda': 0.17650887418408673, 'path_smooth': 0.00016472753872970482, 'min_data_in_leaf': 93, 'max_bin': 123, 'feature_fraction': 0.7394788722560859, 'bagging_fraction': 0.5597572996302387}. Best is trial 22 with value: 0.5597345721153594.
# [I 2025-10-24 06:23:35,336] Trial 23 finished with value: 0.5432330277354624 and parameters: {'lr': 0.022721500594395046, 'n_estimators': 221, 'max_depth': 20, 'num_leaves': 23, 'subsample': 0.9523863087962539, 'colsample_bytree': 0.5006693451568162, 'reg_alpha': 0.002817042404742768, 'reg_lambda': 0.1319022632145193, 'path_smooth': 0.0001867899893616965, 'min_data_in_leaf': 91, 'max_bin': 118, 'feature_fraction': 0.8007616879218789, 'bagging_fraction': 0.5652694711470723}. Best is trial 22 with value: 0.5597345721153594.
# [I 2025-10-24 06:23:35,546] Trial 24 finished with value: 0.5415660818801628 and parameters: {'lr': 0.024674008894770356, 'n_estimators': 149, 'max_depth': 21, 'num_leaves': 23, 'subsample': 0.9423166651894579, 'colsample_bytree': 0.5059167554809927, 'reg_alpha': 0.006011791387753958, 'reg_lambda': 0.16306941535297118, 'path_smooth': 0.0002499131625193424, 'min_data_in_leaf': 90, 'max_bin': 117, 'feature_fraction': 0.807832983544616, 'bagging_fraction': 0.5706373130660076}. Best is trial 22 with value: 0.5597345721153594.
# [I 2025-10-24 06:23:35,818] Trial 25 finished with value: 0.5607284545541444 and parameters: {'lr': 0.09053886777569341, 'n_estimators': 247, 'max_depth': 19, 'num_leaves': 43, 'subsample': 0.9332288768829068, 'colsample_bytree': 0.5389206917500593, 'reg_alpha': 0.026022374842900223, 'reg_lambda': 0.04384404549621287, 'path_smooth': 0.00020299169003141677, 'min_data_in_leaf': 93, 'max_bin': 103, 'feature_fraction': 0.7570305715359311, 'bagging_fraction': 0.6318926007418939}. Best is trial 25 with value: 0.5607284545541444.
# [I 2025-10-24 06:23:36,068] Trial 26 pruned.
# [I 2025-10-24 06:23:36,302] Trial 27 pruned.
# [I 2025-10-24 06:23:36,577] Trial 28 finished with value: 0.5456482188911247 and parameters: {'lr': 0.054717969069047405, 'n_estimators': 382, 'max_depth': 23, 'num_leaves': 42, 'subsample': 0.8830065201152708, 'colsample_bytree': 0.6907580728689097, 'reg_alpha': 0.02244857317487879, 'reg_lambda': 0.029473710796943744, 'path_smooth': 0.0004670335267040041, 'min_data_in_leaf': 93, 'max_bin': 130, 'feature_fraction': 0.7478701978209857, 'bagging_fraction': 0.6002563346613005}. Best is trial 25 with value: 0.5607284545541444.
# [I 2025-10-24 06:23:36,885] Trial 29 pruned.
# [I 2025-10-24 06:23:37,366] Trial 30 pruned.
# [I 2025-10-24 06:23:37,637] Trial 31 finished with value: 0.5619412457276223 and parameters: {'lr': 0.041103239819340054, 'n_estimators': 385, 'max_depth': 23, 'num_leaves': 42, 'subsample': 0.8796332572389455, 'colsample_bytree': 0.6874728827302683, 'reg_alpha': 0.02229673431870128, 'reg_lambda': 0.02170400913623953, 'path_smooth': 0.00046717895870033337, 'min_data_in_leaf': 93, 'max_bin': 129, 'feature_fraction': 0.7480284083572197, 'bagging_fraction': 0.5955249460937695}. Best is trial 31 with value: 0.5619412457276223.
# [I 2025-10-24 06:23:37,990] Trial 32 pruned.
# [I 2025-10-24 06:23:38,270] Trial 33 finished with value: 0.5665089409334934 and parameters: {'lr': 0.03692935307989451, 'n_estimators': 472, 'max_depth': 16, 'num_leaves': 49, 'subsample': 0.8741606843594766, 'colsample_bytree': 0.6954576990924752, 'reg_alpha': 0.14105951636420194, 'reg_lambda': 0.002535864321175421, 'path_smooth': 1.588413313101872e-06, 'min_data_in_leaf': 96, 'max_bin': 141, 'feature_fraction': 0.7995015538952084, 'bagging_fraction': 0.5966463898396598}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:38,567] Trial 34 finished with value: 0.5475688390756883 and parameters: {'lr': 0.04307566673318864, 'n_estimators': 497, 'max_depth': 2, 'num_leaves': 50, 'subsample': 0.8721260364593078, 'colsample_bytree': 0.8176995497962306, 'reg_alpha': 0.13393091394511508, 'reg_lambda': 0.0010024735328128215, 'path_smooth': 0.0003839730642697036, 'min_data_in_leaf': 93, 'max_bin': 142, 'feature_fraction': 0.7327196445357576, 'bagging_fraction': 0.6203964943424527}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:38,833] Trial 35 finished with value: 0.5555233002291826 and parameters: {'lr': 0.09682119712463391, 'n_estimators': 394, 'max_depth': 25, 'num_leaves': 16, 'subsample': 0.5642812560645799, 'colsample_bytree': 0.7283226289884354, 'reg_alpha': 0.5714759182698541, 'reg_lambda': 0.002172299773997909, 'path_smooth': 4.61200979033433e-05, 'min_data_in_leaf': 97, 'max_bin': 127, 'feature_fraction': 0.7998306226742721, 'bagging_fraction': 0.6046065314947242}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:39,091] Trial 36 pruned.
# [I 2025-10-24 06:23:39,369] Trial 37 pruned.
# [I 2025-10-24 06:23:39,616] Trial 38 pruned.
# [I 2025-10-24 06:23:39,923] Trial 39 finished with value: 0.5445229003785551 and parameters: {'lr': 0.02274141502596084, 'n_estimators': 469, 'max_depth': 15, 'num_leaves': 42, 'subsample': 0.7258389909360454, 'colsample_bytree': 0.7863315686511091, 'reg_alpha': 0.014391618972487318, 'reg_lambda': 0.01054637185950739, 'path_smooth': 7.461857457463139e-07, 'min_data_in_leaf': 95, 'max_bin': 116, 'feature_fraction': 0.8108106578360891, 'bagging_fraction': 0.5833107014093516}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:40,204] Trial 40 pruned.
# [I 2025-10-24 06:23:40,457] Trial 41 finished with value: 0.5568296029402263 and parameters: {'lr': 0.0994175401744383, 'n_estimators': 389, 'max_depth': 25, 'num_leaves': 16, 'subsample': 0.5753623997645633, 'colsample_bytree': 0.7350539090696286, 'reg_alpha': 0.4268808053237771, 'reg_lambda': 0.0015858700914713059, 'path_smooth': 4.138145841250306e-05, 'min_data_in_leaf': 97, 'max_bin': 127, 'feature_fraction': 0.8045056950710318, 'bagging_fraction': 0.6037203690532608}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:40,713] Trial 42 finished with value: 0.5433127535406156 and parameters: {'lr': 0.06514592405093413, 'n_estimators': 440, 'max_depth': 21, 'num_leaves': 21, 'subsample': 0.5643874527796919, 'colsample_bytree': 0.7611192521991659, 'reg_alpha': 1.3664975925764893, 'reg_lambda': 0.001188711384858745, 'path_smooth': 0.0001880116274465665, 'min_data_in_leaf': 100, 'max_bin': 122, 'feature_fraction': 0.762256188131005, 'bagging_fraction': 0.637172473645664}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:41,028] Trial 43 pruned.
# [I 2025-10-24 06:23:41,404] Trial 44 finished with value: 0.5440743561749746 and parameters: {'lr': 0.03989341589240279, 'n_estimators': 404, 'max_depth': 17, 'num_leaves': 44, 'subsample': 0.6074551150785602, 'colsample_bytree': 0.6573138614459543, 'reg_alpha': 0.8396001751986845, 'reg_lambda': 0.006218683485561926, 'path_smooth': 6.235220465994946e-05, 'min_data_in_leaf': 80, 'max_bin': 109, 'feature_fraction': 0.8158758960849597, 'bagging_fraction': 0.7246273476652618}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:42,365] Trial 45 pruned.
# [I 2025-10-24 06:23:43,583] Trial 46 finished with value: 0.5470270656758418 and parameters: {'lr': 0.03522508093009926, 'n_estimators': 165, 'max_depth': 32, 'num_leaves': 51, 'subsample': 0.5331098297926378, 'colsample_bytree': 0.6787370439200565, 'reg_alpha': 0.008197201239573172, 'reg_lambda': 0.06284784570780717, 'path_smooth': 1.1355699425325937e-05, 'min_data_in_leaf': 91, 'max_bin': 112, 'feature_fraction': 0.7862519318620188, 'bagging_fraction': 0.5830334448834849}. Best is trial 33 with value: 0.5665089409334934.
# [I 2025-10-24 06:23:44,295] Trial 47 pruned.
# [I 2025-10-24 06:23:44,521] Trial 48 finished with value: 0.5765792377557084 and parameters: {'lr': 1.1829240481692007e-05, 'n_estimators': 303, 'max_depth': 13, 'num_leaves': 32, 'subsample': 0.8986806250207752, 'colsample_bytree': 0.5781104978571359, 'reg_alpha': 0.09024901265702105, 'reg_lambda': 0.0014611929574279922, 'path_smooth': 0.00011137009223515029, 'min_data_in_leaf': 100, 'max_bin': 105, 'feature_fraction': 0.8522577269149394, 'bagging_fraction': 0.6861650259370463}. Best is trial 48 with value: 0.5765792377557084.
# [I 2025-10-24 06:23:44,790] Trial 49 pruned.
# [I 2025-10-24 06:23:44,792] A new study created in memory with name: no-name-8b34515d-764e-474b-b39d-1800964a29bd
# Q1 최적 파라미터: {'lr': 1.1829240481692007e-05, 'n_estimators': 303, 'max_depth': 13, 'num_leaves': 32, 'subsample': 0.8986806250207752, 'colsample_bytree': 0.5781104978571359, 'reg_alpha': 0.09024901265702105, 'reg_lambda': 0.0014611929574279922, 'path_smooth': 0.00011137009223515029, 'min_data_in_leaf': 100, 'max_bin': 105, 'feature_fraction': 0.8522577269149394, 'bagging_fraction': 0.6861650259370463}
# Q1 최고 F1 점수: 0.5766
# ==================================================
#
# === target: Q2 ===
# [I 2025-10-24 06:23:45,132] Trial 0 finished with value: 0.5892650878912111 and parameters: {'lr': 1.5106249671860432e-05, 'n_estimators': 339, 'max_depth': 31, 'num_leaves': 17, 'subsample': 0.5023240118702073, 'colsample_bytree': 0.7526598267090864, 'reg_alpha': 0.6834515648539062, 'reg_lambda': 4.603537484050716, 'path_smooth': 4.1267228833656876e-08, 'min_data_in_leaf': 74, 'max_bin': 172, 'feature_fraction': 0.6605739639515698, 'bagging_fraction': 0.592452365530872}. Best is trial 0 with value: 0.5892650878912111.
# [I 2025-10-24 06:23:45,474] Trial 1 finished with value: 0.5852110001058486 and parameters: {'lr': 2.708916662683437e-05, 'n_estimators': 186, 'max_depth': 4, 'num_leaves': 63, 'subsample': 0.5372630344763973, 'colsample_bytree': 0.849442817276649, 'reg_alpha': 0.09266314028306984, 'reg_lambda': 1.1663679970572534, 'path_smooth': 2.0788347659089347e-06, 'min_data_in_leaf': 50, 'max_bin': 141, 'feature_fraction': 0.599451423457273, 'bagging_fraction': 0.7580210670788405}. Best is trial 0 with value: 0.5892650878912111.
# [I 2025-10-24 06:23:46,781] Trial 2 finished with value: 0.6162132475385487 and parameters: {'lr': 1.5387507769813355e-05, 'n_estimators': 478, 'max_depth': 25, 'num_leaves': 19, 'subsample': 0.8903762209202944, 'colsample_bytree': 0.7884919116004143, 'reg_alpha': 0.015516998171697351, 'reg_lambda': 4.807638732776518, 'path_smooth': 4.6122213491899746e-07, 'min_data_in_leaf': 100, 'max_bin': 184, 'feature_fraction': 0.5859246944646821, 'bagging_fraction': 0.8591900416062732}. Best is trial 2 with value: 0.6162132475385487.
# [I 2025-10-24 06:23:47,325] Trial 3 finished with value: 0.5895293110825846 and parameters: {'lr': 0.0003949565350617718, 'n_estimators': 433, 'max_depth': 23, 'num_leaves': 39, 'subsample': 0.7071083559176792, 'colsample_bytree': 0.5496234775811784, 'reg_alpha': 0.013551397268244015, 'reg_lambda': 0.3294174003334398, 'path_smooth': 1.1082047819203755e-07, 'min_data_in_leaf': 41, 'max_bin': 202, 'feature_fraction': 0.6154333863457454, 'bagging_fraction': 0.6344213222785804}. Best is trial 2 with value: 0.6162132475385487.
# [I 2025-10-24 06:23:48,044] Trial 4 finished with value: 0.6120434583863912 and parameters: {'lr': 0.00024842547867017325, 'n_estimators': 373, 'max_depth': 12, 'num_leaves': 19, 'subsample': 0.6246250399067793, 'colsample_bytree': 0.7905619719408312, 'reg_alpha': 0.5311818664356938, 'reg_lambda': 0.05908387293672967, 'path_smooth': 1.970364963074316e-08, 'min_data_in_leaf': 15, 'max_bin': 109, 'feature_fraction': 0.8716354302039999, 'bagging_fraction': 0.5817532287988983}. Best is trial 2 with value: 0.6162132475385487.
# [I 2025-10-24 06:23:48,362] Trial 5 finished with value: 0.6148066528066529 and parameters: {'lr': 0.05048517672789281, 'n_estimators': 361, 'max_depth': 18, 'num_leaves': 59, 'subsample': 0.7658682645346437, 'colsample_bytree': 0.9742843014092204, 'reg_alpha': 9.892295164270536, 'reg_lambda': 3.593864019211421, 'path_smooth': 2.451889181958769e-07, 'min_data_in_leaf': 85, 'max_bin': 190, 'feature_fraction': 0.7804231316322026, 'bagging_fraction': 0.7114993672863745}. Best is trial 2 with value: 0.6162132475385487.
# [I 2025-10-24 06:23:48,745] Trial 6 finished with value: 0.6318145847225703 and parameters: {'lr': 0.004971176898604735, 'n_estimators': 454, 'max_depth': 17, 'num_leaves': 43, 'subsample': 0.8113435608863484, 'colsample_bytree': 0.5089423697793136, 'reg_alpha': 0.027209075541545648, 'reg_lambda': 0.7122607052005215, 'path_smooth': 8.866574261031164e-07, 'min_data_in_leaf': 62, 'max_bin': 102, 'feature_fraction': 0.8457642154451177, 'bagging_fraction': 0.5789877096369924}. Best is trial 6 with value: 0.6318145847225703.
# [I 2025-10-24 06:23:49,184] Trial 7 finished with value: 0.6475346774090843 and parameters: {'lr': 0.030708209305572505, 'n_estimators': 463, 'max_depth': 22, 'num_leaves': 19, 'subsample': 0.6542488308929868, 'colsample_bytree': 0.7237448195681488, 'reg_alpha': 0.2171478639402438, 'reg_lambda': 3.3978134684137644, 'path_smooth': 0.00028973076199137357, 'min_data_in_leaf': 56, 'max_bin': 240, 'feature_fraction': 0.7779933956373506, 'bagging_fraction': 0.6220690244156954}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:49,499] Trial 8 finished with value: 0.6167943933908846 and parameters: {'lr': 4.915582398065948e-05, 'n_estimators': 60, 'max_depth': 5, 'num_leaves': 46, 'subsample': 0.6438518665043911, 'colsample_bytree': 0.6589654033338963, 'reg_alpha': 0.07536134088594347, 'reg_lambda': 0.03184880122203618, 'path_smooth': 8.851563484150123e-08, 'min_data_in_leaf': 15, 'max_bin': 150, 'feature_fraction': 0.5734300459735587, 'bagging_fraction': 0.6766331659840753}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:49,886] Trial 9 pruned.
# [I 2025-10-24 06:23:50,423] Trial 10 finished with value: 0.6369240508833364 and parameters: {'lr': 0.09973570945357453, 'n_estimators': 192, 'max_depth': 30, 'num_leaves': 31, 'subsample': 0.9983482371324646, 'colsample_bytree': 0.9102704241543812, 'reg_alpha': 0.0017523992934812807, 'reg_lambda': 0.008715999635183123, 'path_smooth': 0.00046239991285911474, 'min_data_in_leaf': 36, 'max_bin': 253, 'feature_fraction': 0.5102416498210152, 'bagging_fraction': 0.7669039268999743}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:50,940] Trial 11 finished with value: 0.6236908379184802 and parameters: {'lr': 0.09136108152433281, 'n_estimators': 188, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9781257140139507, 'colsample_bytree': 0.9330615222882648, 'reg_alpha': 0.0011723756966183349, 'reg_lambda': 0.003889328553820967, 'path_smooth': 0.0005112095014621532, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5019493750943811, 'bagging_fraction': 0.7662020009863196}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:51,346] Trial 12 finished with value: 0.6337752385426804 and parameters: {'lr': 0.013398146831354863, 'n_estimators': 235, 'max_depth': 25, 'num_leaves': 29, 'subsample': 0.9763804673164594, 'colsample_bytree': 0.8853351394054366, 'reg_alpha': 0.0015551897153078472, 'reg_lambda': 0.012453778454908391, 'path_smooth': 0.0003924625822861102, 'min_data_in_leaf': 31, 'max_bin': 229, 'feature_fraction': 0.758928243224532, 'bagging_fraction': 0.7872160285248717}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:51,541] Trial 13 finished with value: 0.628671679197995 and parameters: {'lr': 0.019930963127878707, 'n_estimators': 59, 'max_depth': 28, 'num_leaves': 34, 'subsample': 0.8574433219756716, 'colsample_bytree': 0.6887319193544634, 'reg_alpha': 0.4805776140239637, 'reg_lambda': 0.17226775646196066, 'path_smooth': 4.7009726709380874e-05, 'min_data_in_leaf': 52, 'max_bin': 219, 'feature_fraction': 0.7101696192980772, 'bagging_fraction': 0.512122430591642}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:52,276] Trial 14 finished with value: 0.6237042035287649 and parameters: {'lr': 0.00414397872093749, 'n_estimators': 275, 'max_depth': 23, 'num_leaves': 24, 'subsample': 0.6263832617019479, 'colsample_bytree': 0.8593873689322548, 'reg_alpha': 5.725613355142806, 'reg_lambda': 0.018348104036371216, 'path_smooth': 3.178291080990174e-05, 'min_data_in_leaf': 30, 'max_bin': 255, 'feature_fraction': 0.5102474401806703, 'bagging_fraction': 0.7027857745925364}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:52,509] Trial 15 finished with value: 0.623549814339288 and parameters: {'lr': 0.030524701303187043, 'n_estimators': 118, 'max_depth': 13, 'num_leaves': 53, 'subsample': 0.6977912472754476, 'colsample_bytree': 0.7006381962327882, 'reg_alpha': 1.9124922010381273, 'reg_lambda': 0.005906443432895061, 'path_smooth': 4.791489932452157e-05, 'min_data_in_leaf': 71, 'max_bin': 215, 'feature_fraction': 0.7092514853075329, 'bagging_fraction': 0.8935321546155103}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:52,913] Trial 16 finished with value: 0.638661704777484 and parameters: {'lr': 0.0973013953491115, 'n_estimators': 312, 'max_depth': 28, 'num_leaves': 36, 'subsample': 0.9066298636580062, 'colsample_bytree': 0.9752973267431267, 'reg_alpha': 0.003364935117313058, 'reg_lambda': 0.10835192820279207, 'path_smooth': 0.00018563312488221738, 'min_data_in_leaf': 44, 'max_bin': 235, 'feature_fraction': 0.8237316784361286, 'bagging_fraction': 0.6526288505211912}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:53,409] Trial 17 finished with value: 0.6380876775711782 and parameters: {'lr': 0.0071737752130245245, 'n_estimators': 409, 'max_depth': 22, 'num_leaves': 50, 'subsample': 0.8867914312336954, 'colsample_bytree': 0.9935265990093503, 'reg_alpha': 0.004187017458604506, 'reg_lambda': 1.5769917816868595, 'path_smooth': 9.009343602317729e-06, 'min_data_in_leaf': 45, 'max_bin': 204, 'feature_fraction': 0.8301732689949494, 'bagging_fraction': 0.5214343220133224}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:53,720] Trial 18 pruned.
# [I 2025-10-24 06:23:54,029] Trial 19 finished with value: 0.6369649796409467 and parameters: {'lr': 0.012660038143285555, 'n_estimators': 303, 'max_depth': 20, 'num_leaves': 24, 'subsample': 0.9242771910514589, 'colsample_bytree': 0.8215677766102712, 'reg_alpha': 0.03507516947567193, 'reg_lambda': 0.1315838010103157, 'path_smooth': 6.087193458696525e-06, 'min_data_in_leaf': 78, 'max_bin': 168, 'feature_fraction': 0.8857470549590628, 'bagging_fraction': 0.6472268027569847}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:56,952] Trial 20 pruned.
# [I 2025-10-24 06:23:57,561] Trial 21 finished with value: 0.6306419436166271 and parameters: {'lr': 0.008959943493177877, 'n_estimators': 410, 'max_depth': 21, 'num_leaves': 49, 'subsample': 0.8176359219240804, 'colsample_bytree': 0.9917880525013808, 'reg_alpha': 0.004317340455859172, 'reg_lambda': 1.187932380019664, 'path_smooth': 9.354562003289142e-06, 'min_data_in_leaf': 42, 'max_bin': 204, 'feature_fraction': 0.8200151822826461, 'bagging_fraction': 0.5221991409352227}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:58,021] Trial 22 finished with value: 0.6440974606491847 and parameters: {'lr': 0.04759673102605509, 'n_estimators': 458, 'max_depth': 28, 'num_leaves': 53, 'subsample': 0.9261230397155794, 'colsample_bytree': 0.9471976456869308, 'reg_alpha': 0.004039640347320522, 'reg_lambda': 1.8173980717368912, 'path_smooth': 1.6633853742863932e-05, 'min_data_in_leaf': 50, 'max_bin': 218, 'feature_fraction': 0.8128902622950441, 'bagging_fraction': 0.6129305298561324}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:58,454] Trial 23 finished with value: 0.6301431997762146 and parameters: {'lr': 0.052721220383043554, 'n_estimators': 460, 'max_depth': 29, 'num_leaves': 56, 'subsample': 0.9201161216868089, 'colsample_bytree': 0.9393957345660465, 'reg_alpha': 0.004021365164821135, 'reg_lambda': 0.45623895542446774, 'path_smooth': 0.0009374956590266877, 'min_data_in_leaf': 56, 'max_bin': 220, 'feature_fraction': 0.7945594971486651, 'bagging_fraction': 0.605341074309315}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:58,998] Trial 24 finished with value: 0.6318918144913631 and parameters: {'lr': 0.02239091960615426, 'n_estimators': 500, 'max_depth': 26, 'num_leaves': 35, 'subsample': 0.7049768858464263, 'colsample_bytree': 0.5917908588078714, 'reg_alpha': 0.04633666687839431, 'reg_lambda': 1.9382675510709677, 'path_smooth': 9.706713500234026e-05, 'min_data_in_leaf': 48, 'max_bin': 239, 'feature_fraction': 0.742337180400813, 'bagging_fraction': 0.6704665181368651}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:59,380] Trial 25 finished with value: 0.6431816933813577 and parameters: {'lr': 0.09363144754595239, 'n_estimators': 361, 'max_depth': 28, 'num_leaves': 42, 'subsample': 0.9112788585439685, 'colsample_bytree': 0.9412126862157195, 'reg_alpha': 0.16993046935975975, 'reg_lambda': 9.779051256477105, 'path_smooth': 3.0473610710447e-05, 'min_data_in_leaf': 57, 'max_bin': 215, 'feature_fraction': 0.8559162664109745, 'bagging_fraction': 0.7268526962742885}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:23:59,769] Trial 26 pruned.
# [I 2025-10-24 06:24:00,131] Trial 27 pruned.
# [I 2025-10-24 06:24:00,490] Trial 28 finished with value: 0.6454611970147798 and parameters: {'lr': 0.01852712790811222, 'n_estimators': 341, 'max_depth': 16, 'num_leaves': 54, 'subsample': 0.6668172656572715, 'colsample_bytree': 0.9492893063759634, 'reg_alpha': 2.63570378502374, 'reg_lambda': 6.552838013104603, 'path_smooth': 2.6367287955606647e-06, 'min_data_in_leaf': 56, 'max_bin': 161, 'feature_fraction': 0.6772197729230806, 'bagging_fraction': 0.6043825058338714}. Best is trial 7 with value: 0.6475346774090843.
# [I 2025-10-24 06:24:00,855] Trial 29 pruned.
# [I 2025-10-24 06:24:01,146] Trial 30 pruned.
# [I 2025-10-24 06:24:01,505] Trial 31 finished with value: 0.6524055568173215 and parameters: {'lr': 0.04832158296780985, 'n_estimators': 333, 'max_depth': 20, 'num_leaves': 51, 'subsample': 0.7343217844040516, 'colsample_bytree': 0.9539536842221169, 'reg_alpha': 0.3916698297831571, 'reg_lambda': 6.450751638251804, 'path_smooth': 1.3829908765886003e-05, 'min_data_in_leaf': 56, 'max_bin': 176, 'feature_fraction': 0.6305825336098354, 'bagging_fraction': 0.6268535651154195}. Best is trial 31 with value: 0.6524055568173215.
# [I 2025-10-24 06:24:01,879] Trial 32 finished with value: 0.6536207550596899 and parameters: {'lr': 0.02409758448773075, 'n_estimators': 334, 'max_depth': 15, 'num_leaves': 53, 'subsample': 0.7396752419612489, 'colsample_bytree': 0.890086531884336, 'reg_alpha': 0.804430166673044, 'reg_lambda': 0.8173060218957555, 'path_smooth': 4.849244959214214e-06, 'min_data_in_leaf': 53, 'max_bin': 131, 'feature_fraction': 0.6408717248872763, 'bagging_fraction': 0.6107670141253644}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:02,229] Trial 33 finished with value: 0.6440069337463231 and parameters: {'lr': 0.008265644018110125, 'n_estimators': 334, 'max_depth': 16, 'num_leaves': 59, 'subsample': 0.7321526909137317, 'colsample_bytree': 0.900013687952523, 'reg_alpha': 0.42515541149220076, 'reg_lambda': 0.8885076826293895, 'path_smooth': 9.197075444756895e-07, 'min_data_in_leaf': 56, 'max_bin': 127, 'feature_fraction': 0.6297864807228505, 'bagging_fraction': 0.620924078231306}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:02,571] Trial 34 pruned.
# [I 2025-10-24 06:24:02,902] Trial 35 finished with value: 0.6476233819051876 and parameters: {'lr': 0.02741894569705745, 'n_estimators': 280, 'max_depth': 9, 'num_leaves': 53, 'subsample': 0.7396123034583104, 'colsample_bytree': 0.7123609475686139, 'reg_alpha': 2.39446092986211, 'reg_lambda': 3.0347039474470274, 'path_smooth': 1.7745983702179752e-06, 'min_data_in_leaf': 65, 'max_bin': 160, 'feature_fraction': 0.6840162609443523, 'bagging_fraction': 0.6743772282546993}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:03,456] Trial 36 pruned.
# [I 2025-10-24 06:24:03,826] Trial 37 pruned.
# [I 2025-10-24 06:24:04,316] Trial 38 pruned.
# [I 2025-10-24 06:24:04,580] Trial 39 pruned.
# [I 2025-10-24 06:24:04,957] Trial 40 pruned.
# [I 2025-10-24 06:24:05,308] Trial 41 pruned.
# [I 2025-10-24 06:24:05,636] Trial 42 finished with value: 0.639987528461424 and parameters: {'lr': 0.024415341630444027, 'n_estimators': 314, 'max_depth': 20, 'num_leaves': 55, 'subsample': 0.641703832648891, 'colsample_bytree': 0.7573493748699471, 'reg_alpha': 4.232617736506467, 'reg_lambda': 2.7128108054143043, 'path_smooth': 4.047418292760603e-06, 'min_data_in_leaf': 64, 'max_bin': 165, 'feature_fraction': 0.6795685482373492, 'bagging_fraction': 0.5850286526512409}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:05,967] Trial 43 finished with value: 0.6433273121459643 and parameters: {'lr': 0.016209241312440947, 'n_estimators': 262, 'max_depth': 11, 'num_leaves': 61, 'subsample': 0.5859539737217413, 'colsample_bytree': 0.6795976539643901, 'reg_alpha': 8.151943791799429, 'reg_lambda': 6.9274962074675095, 'path_smooth': 5.284463635524577e-07, 'min_data_in_leaf': 60, 'max_bin': 141, 'feature_fraction': 0.6220309266208509, 'bagging_fraction': 0.6243804602148948}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:06,310] Trial 44 finished with value: 0.6491152513178704 and parameters: {'lr': 0.031493945536123086, 'n_estimators': 350, 'max_depth': 15, 'num_leaves': 51, 'subsample': 0.752329356699273, 'colsample_bytree': 0.9139214076970603, 'reg_alpha': 0.6824117304156759, 'reg_lambda': 4.113137778103807, 'path_smooth': 3.0815012681947663e-06, 'min_data_in_leaf': 70, 'max_bin': 159, 'feature_fraction': 0.6521882897748228, 'bagging_fraction': 0.6895456316225947}. Best is trial 32 with value: 0.6536207550596899.
# [I 2025-10-24 06:24:06,684] Trial 45 finished with value: 0.665516104135429 and parameters: {'lr': 0.06497900379664574, 'n_estimators': 391, 'max_depth': 18, 'num_leaves': 51, 'subsample': 0.7582979267239988, 'colsample_bytree': 0.8651906198740047, 'reg_alpha': 0.11239070473982651, 'reg_lambda': 1.3050956051665916, 'path_smooth': 6.60351807814746e-06, 'min_data_in_leaf': 72, 'max_bin': 176, 'feature_fraction': 0.7304175673398711, 'bagging_fraction': 0.7446920499023151}. Best is trial 45 with value: 0.665516104135429.
# [I 2025-10-24 06:24:07,033] Trial 46 finished with value: 0.6419513848234852 and parameters: {'lr': 0.06334149600068927, 'n_estimators': 352, 'max_depth': 14, 'num_leaves': 51, 'subsample': 0.7623540515510633, 'colsample_bytree': 0.9157474910620418, 'reg_alpha': 0.13011852962301407, 'reg_lambda': 0.5688580487689004, 'path_smooth': 1.43984329759391e-06, 'min_data_in_leaf': 87, 'max_bin': 179, 'feature_fraction': 0.7264280463574564, 'bagging_fraction': 0.8121671878706489}. Best is trial 45 with value: 0.665516104135429.
# [I 2025-10-24 06:24:10,246] Trial 47 finished with value: 0.6568522132237321 and parameters: {'lr': 0.06621858719269945, 'n_estimators': 388, 'max_depth': 18, 'num_leaves': 46, 'subsample': 0.7987761965183324, 'colsample_bytree': 0.851726279884025, 'reg_alpha': 0.06882117456995933, 'reg_lambda': 1.348417507185803, 'path_smooth': 6.815472355718257e-06, 'min_data_in_leaf': 72, 'max_bin': 192, 'feature_fraction': 0.5483275661067747, 'bagging_fraction': 0.6949855160379318}. Best is trial 45 with value: 0.665516104135429.
# [I 2025-10-24 06:24:11,195] Trial 48 finished with value: 0.6619029532189855 and parameters: {'lr': 0.06619320578075964, 'n_estimators': 391, 'max_depth': 18, 'num_leaves': 47, 'subsample': 0.791316830279257, 'colsample_bytree': 0.8730119178171427, 'reg_alpha': 0.056098925038809366, 'reg_lambda': 0.04309133063815291, 'path_smooth': 6.087005609757738e-06, 'min_data_in_leaf': 72, 'max_bin': 191, 'feature_fraction': 0.5352868392480123, 'bagging_fraction': 0.747678863273486}. Best is trial 45 with value: 0.665516104135429.
# [I 2025-10-24 06:24:11,959] Trial 49 pruned.
# [I 2025-10-24 06:24:11,961] A new study created in memory with name: no-name-c3b755b5-7a58-412f-96f1-3c20f25e85cd
# Q2 최적 파라미터: {'lr': 0.06497900379664574, 'n_estimators': 391, 'max_depth': 18, 'num_leaves': 51, 'subsample': 0.7582979267239988, 'colsample_bytree': 0.8651906198740047, 'reg_alpha': 0.11239070473982651, 'reg_lambda': 1.3050956051665916, 'path_smooth': 6.60351807814746e-06, 'min_data_in_leaf': 72, 'max_bin': 176, 'feature_fraction': 0.7304175673398711, 'bagging_fraction': 0.7446920499023151}
# Q2 최고 F1 점수: 0.6655
# ==================================================
#
# === target: Q3 ===
# [I 2025-10-24 06:24:12,320] Trial 0 finished with value: 0.6000479754127162 and parameters: {'lr': 1.5106249671860432e-05, 'n_estimators': 339, 'max_depth': 31, 'num_leaves': 17, 'subsample': 0.5023240118702073, 'colsample_bytree': 0.7526598267090864, 'reg_alpha': 0.6834515648539062, 'reg_lambda': 4.603537484050716, 'path_smooth': 4.1267228833656876e-08, 'min_data_in_leaf': 74, 'max_bin': 172, 'feature_fraction': 0.6605739639515698, 'bagging_fraction': 0.592452365530872}. Best is trial 0 with value: 0.6000479754127162.
# [I 2025-10-24 06:24:12,705] Trial 1 finished with value: 0.5904364210087103 and parameters: {'lr': 2.708916662683437e-05, 'n_estimators': 186, 'max_depth': 4, 'num_leaves': 63, 'subsample': 0.5372630344763973, 'colsample_bytree': 0.849442817276649, 'reg_alpha': 0.09266314028306984, 'reg_lambda': 1.1663679970572534, 'path_smooth': 2.0788347659089347e-06, 'min_data_in_leaf': 50, 'max_bin': 141, 'feature_fraction': 0.599451423457273, 'bagging_fraction': 0.7580210670788405}. Best is trial 0 with value: 0.6000479754127162.
# [I 2025-10-24 06:24:13,360] Trial 2 finished with value: 0.5458241128163016 and parameters: {'lr': 1.5387507769813355e-05, 'n_estimators': 478, 'max_depth': 25, 'num_leaves': 19, 'subsample': 0.8903762209202944, 'colsample_bytree': 0.7884919116004143, 'reg_alpha': 0.015516998171697351, 'reg_lambda': 4.807638732776518, 'path_smooth': 4.6122213491899746e-07, 'min_data_in_leaf': 100, 'max_bin': 184, 'feature_fraction': 0.5859246944646821, 'bagging_fraction': 0.8591900416062732}. Best is trial 0 with value: 0.6000479754127162.
# [I 2025-10-24 06:24:13,922] Trial 3 finished with value: 0.6014858070593881 and parameters: {'lr': 0.0003949565350617718, 'n_estimators': 433, 'max_depth': 23, 'num_leaves': 39, 'subsample': 0.7071083559176792, 'colsample_bytree': 0.5496234775811784, 'reg_alpha': 0.013551397268244015, 'reg_lambda': 0.3294174003334398, 'path_smooth': 1.1082047819203755e-07, 'min_data_in_leaf': 41, 'max_bin': 202, 'feature_fraction': 0.6154333863457454, 'bagging_fraction': 0.6344213222785804}. Best is trial 3 with value: 0.6014858070593881.
# [I 2025-10-24 06:24:14,780] Trial 4 finished with value: 0.5938994417278285 and parameters: {'lr': 0.00024842547867017325, 'n_estimators': 373, 'max_depth': 12, 'num_leaves': 19, 'subsample': 0.6246250399067793, 'colsample_bytree': 0.7905619719408312, 'reg_alpha': 0.5311818664356938, 'reg_lambda': 0.05908387293672967, 'path_smooth': 1.970364963074316e-08, 'min_data_in_leaf': 15, 'max_bin': 109, 'feature_fraction': 0.8716354302039999, 'bagging_fraction': 0.5817532287988983}. Best is trial 3 with value: 0.6014858070593881.
# [I 2025-10-24 06:24:15,078] Trial 5 pruned.
# [I 2025-10-24 06:24:15,531] Trial 6 finished with value: 0.6183397339400664 and parameters: {'lr': 0.004971176898604735, 'n_estimators': 454, 'max_depth': 17, 'num_leaves': 43, 'subsample': 0.8113435608863484, 'colsample_bytree': 0.5089423697793136, 'reg_alpha': 0.027209075541545648, 'reg_lambda': 0.7122607052005215, 'path_smooth': 8.866574261031164e-07, 'min_data_in_leaf': 62, 'max_bin': 102, 'feature_fraction': 0.8457642154451177, 'bagging_fraction': 0.5789877096369924}. Best is trial 6 with value: 0.6183397339400664.
# [I 2025-10-24 06:24:15,975] Trial 7 finished with value: 0.6253117627232895 and parameters: {'lr': 0.030708209305572505, 'n_estimators': 463, 'max_depth': 22, 'num_leaves': 19, 'subsample': 0.6542488308929868, 'colsample_bytree': 0.7237448195681488, 'reg_alpha': 0.2171478639402438, 'reg_lambda': 3.3978134684137644, 'path_smooth': 0.00028973076199137357, 'min_data_in_leaf': 56, 'max_bin': 240, 'feature_fraction': 0.7779933956373506, 'bagging_fraction': 0.6220690244156954}. Best is trial 7 with value: 0.6253117627232895.
# [I 2025-10-24 06:24:16,307] Trial 8 finished with value: 0.6012699351131898 and parameters: {'lr': 4.915582398065948e-05, 'n_estimators': 60, 'max_depth': 5, 'num_leaves': 46, 'subsample': 0.6438518665043911, 'colsample_bytree': 0.6589654033338963, 'reg_alpha': 0.07536134088594347, 'reg_lambda': 0.03184880122203618, 'path_smooth': 8.851563484150123e-08, 'min_data_in_leaf': 15, 'max_bin': 150, 'feature_fraction': 0.5734300459735587, 'bagging_fraction': 0.6766331659840753}. Best is trial 7 with value: 0.6253117627232895.
# [I 2025-10-24 06:24:16,736] Trial 9 finished with value: 0.6351715275662843 and parameters: {'lr': 0.0012170103800183503, 'n_estimators': 499, 'max_depth': 18, 'num_leaves': 29, 'subsample': 0.7625788449074901, 'colsample_bytree': 0.6439281786271318, 'reg_alpha': 0.008109647434881012, 'reg_lambda': 0.001976399822541516, 'path_smooth': 3.912486872128621e-08, 'min_data_in_leaf': 61, 'max_bin': 240, 'feature_fraction': 0.7803822173527346, 'bagging_fraction': 0.8425945496838478}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:17,359] Trial 10 finished with value: 0.629671420297996 and parameters: {'lr': 0.003620154020577552, 'n_estimators': 192, 'max_depth': 11, 'num_leaves': 31, 'subsample': 0.9983482371324646, 'colsample_bytree': 0.6134147880564583, 'reg_alpha': 0.0011648266744261333, 'reg_lambda': 0.0010904514490470117, 'path_smooth': 2.688342094832092e-05, 'min_data_in_leaf': 36, 'max_bin': 253, 'feature_fraction': 0.5102416498210152, 'bagging_fraction': 0.8985975812656989}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:17,915] Trial 11 finished with value: 0.6292795065881693 and parameters: {'lr': 0.003117144522931021, 'n_estimators': 188, 'max_depth': 11, 'num_leaves': 31, 'subsample': 0.9790057400308871, 'colsample_bytree': 0.6389211304664341, 'reg_alpha': 0.0010918887696487968, 'reg_lambda': 0.0010289981025728312, 'path_smooth': 2.6795693536501164e-05, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5019493750943811, 'bagging_fraction': 0.8971037364574037}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:18,303] Trial 12 finished with value: 0.6318372034199073 and parameters: {'lr': 0.003817814365871883, 'n_estimators': 236, 'max_depth': 10, 'num_leaves': 31, 'subsample': 0.9763804673164594, 'colsample_bytree': 0.6088667589030718, 'reg_alpha': 0.0015551897153078472, 'reg_lambda': 0.001127254387830724, 'path_smooth': 2.0452367009361094e-05, 'min_data_in_leaf': 35, 'max_bin': 229, 'feature_fraction': 0.758928243224532, 'bagging_fraction': 0.8191499086923213}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:18,610] Trial 13 pruned.
# [I 2025-10-24 06:24:19,073] Trial 14 finished with value: 0.62425877796991 and parameters: {'lr': 0.013856885214550287, 'n_estimators': 264, 'max_depth': 16, 'num_leaves': 27, 'subsample': 0.8501083879901923, 'colsample_bytree': 0.6867557237259828, 'reg_alpha': 0.004956179308212131, 'reg_lambda': 0.005376569827964351, 'path_smooth': 0.0009269511379014035, 'min_data_in_leaf': 27, 'max_bin': 217, 'feature_fraction': 0.7064228927578374, 'bagging_fraction': 0.814802051791972}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:19,302] Trial 15 pruned.
# [I 2025-10-24 06:24:19,639] Trial 16 pruned.
# [I 2025-10-24 06:24:19,964] Trial 17 pruned.
# [I 2025-10-24 06:24:20,314] Trial 18 pruned.
# [I 2025-10-24 06:24:23,050] Trial 19 finished with value: 0.6280810648892421 and parameters: {'lr': 0.018968278603210556, 'n_estimators': 398, 'max_depth': 26, 'num_leaves': 24, 'subsample': 0.6007250400758861, 'colsample_bytree': 0.5669663677214118, 'reg_alpha': 0.001609409983743245, 'reg_lambda': 0.15786685003382092, 'path_smooth': 4.703996875011578e-06, 'min_data_in_leaf': 44, 'max_bin': 200, 'feature_fraction': 0.886164562770425, 'bagging_fraction': 0.8531477822407709}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:23,401] Trial 20 pruned.
# [I 2025-10-24 06:24:23,954] Trial 21 pruned.
# [I 2025-10-24 06:24:24,229] Trial 22 pruned.
# [I 2025-10-24 06:24:24,617] Trial 23 pruned.
# [I 2025-10-24 06:24:24,999] Trial 24 pruned.
# [I 2025-10-24 06:24:25,612] Trial 25 pruned.
# [I 2025-10-24 06:24:26,609] Trial 26 pruned.
# [I 2025-10-24 06:24:26,921] Trial 27 pruned.
# [I 2025-10-24 06:24:27,364] Trial 28 pruned.
# [I 2025-10-24 06:24:27,729] Trial 29 pruned.
# [I 2025-10-24 06:24:28,271] Trial 30 pruned.
# [I 2025-10-24 06:24:28,854] Trial 31 finished with value: 0.6265072409895243 and parameters: {'lr': 0.002774260853630536, 'n_estimators': 204, 'max_depth': 12, 'num_leaves': 30, 'subsample': 0.9765534991778356, 'colsample_bytree': 0.6279892403355114, 'reg_alpha': 0.001065867951078726, 'reg_lambda': 0.001009175292175892, 'path_smooth': 2.3052808717709213e-05, 'min_data_in_leaf': 33, 'max_bin': 255, 'feature_fraction': 0.5183980782362944, 'bagging_fraction': 0.8909690582778851}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:29,464] Trial 32 pruned.
# [I 2025-10-24 06:24:29,937] Trial 33 pruned.
# [I 2025-10-24 06:24:30,477] Trial 34 pruned.
# [I 2025-10-24 06:24:30,957] Trial 35 pruned.
# [I 2025-10-24 06:24:31,720] Trial 36 pruned.
# [I 2025-10-24 06:24:32,165] Trial 37 pruned.
# [I 2025-10-24 06:24:32,555] Trial 38 pruned.
# [I 2025-10-24 06:24:32,817] Trial 39 pruned.
# [I 2025-10-24 06:24:33,051] Trial 40 pruned.
# [I 2025-10-24 06:24:35,556] Trial 41 finished with value: 0.6291068985733829 and parameters: {'lr': 0.01660940967228521, 'n_estimators': 407, 'max_depth': 29, 'num_leaves': 23, 'subsample': 0.578079202332578, 'colsample_bytree': 0.5752624314017392, 'reg_alpha': 0.001981838547731023, 'reg_lambda': 0.2247977547527071, 'path_smooth': 5.430961824041493e-06, 'min_data_in_leaf': 46, 'max_bin': 195, 'feature_fraction': 0.899901357691473, 'bagging_fraction': 0.8635144861231208}. Best is trial 9 with value: 0.6351715275662843.
# [I 2025-10-24 06:24:36,359] Trial 42 finished with value: 0.6427536320197857 and parameters: {'lr': 0.013604904210327118, 'n_estimators': 430, 'max_depth': 24, 'num_leaves': 19, 'subsample': 0.5645433380750695, 'colsample_bytree': 0.593252942688302, 'reg_alpha': 0.0013643575284378597, 'reg_lambda': 0.2438984658544583, 'path_smooth': 1.8137214232302684e-05, 'min_data_in_leaf': 49, 'max_bin': 208, 'feature_fraction': 0.8649173762764597, 'bagging_fraction': 0.8797974768111675}. Best is trial 42 with value: 0.6427536320197857.
# [I 2025-10-24 06:24:36,834] Trial 43 finished with value: 0.6374728947582946 and parameters: {'lr': 0.00625452287634712, 'n_estimators': 438, 'max_depth': 26, 'num_leaves': 19, 'subsample': 0.6656351967585624, 'colsample_bytree': 0.5017186654073665, 'reg_alpha': 0.0011928199403024365, 'reg_lambda': 0.5405167408046622, 'path_smooth': 2.7011602008587064e-05, 'min_data_in_leaf': 51, 'max_bin': 207, 'feature_fraction': 0.8735604072422598, 'bagging_fraction': 0.8778917941956604}. Best is trial 42 with value: 0.6427536320197857.
# [I 2025-10-24 06:24:37,351] Trial 44 finished with value: 0.6388458816831868 and parameters: {'lr': 0.005750148178684939, 'n_estimators': 430, 'max_depth': 24, 'num_leaves': 19, 'subsample': 0.6871547418479673, 'colsample_bytree': 0.534572997417773, 'reg_alpha': 0.004474870071334021, 'reg_lambda': 0.4597221234914657, 'path_smooth': 1.4735324018342853e-05, 'min_data_in_leaf': 50, 'max_bin': 206, 'feature_fraction': 0.8644798684556815, 'bagging_fraction': 0.834778937857163}. Best is trial 42 with value: 0.6427536320197857.
# [I 2025-10-24 06:24:37,832] Trial 45 finished with value: 0.6303642577310995 and parameters: {'lr': 0.011181605919534592, 'n_estimators': 439, 'max_depth': 24, 'num_leaves': 19, 'subsample': 0.676357082307606, 'colsample_bytree': 0.5096558092327261, 'reg_alpha': 0.00428818479600862, 'reg_lambda': 0.6346178998052633, 'path_smooth': 1.3766950488997882e-05, 'min_data_in_leaf': 53, 'max_bin': 182, 'feature_fraction': 0.8606549874476216, 'bagging_fraction': 0.8335225437072314}. Best is trial 42 with value: 0.6427536320197857.
# [I 2025-10-24 06:24:38,367] Trial 46 pruned.
# [I 2025-10-24 06:24:38,814] Trial 47 finished with value: 0.633247172437881 and parameters: {'lr': 0.005691064297757157, 'n_estimators': 430, 'max_depth': 23, 'num_leaves': 20, 'subsample': 0.7238760074092109, 'colsample_bytree': 0.5453919216870583, 'reg_alpha': 0.014337196871511429, 'reg_lambda': 1.7890410610780336, 'path_smooth': 6.507020881795845e-05, 'min_data_in_leaf': 57, 'max_bin': 208, 'feature_fraction': 0.8431257450841789, 'bagging_fraction': 0.8033803633286731}. Best is trial 42 with value: 0.6427536320197857.
# [I 2025-10-24 06:24:39,266] Trial 48 pruned.
# ...
# [I 2025-10-24 06:25:13,355] Trial 2 finished with value: 0.6565218257454121 and parameters: {'lr': 1.5387507769813355e-05, 'n_estimators': 478, 'max_depth': 25, 'num_leaves': 19, 'subsample': 0.8903762209202944, 'colsample_bytree': 0.7884919116004143, 'reg_alpha': 0.015516998171697351, 'reg_lambda': 4.807638732776518, 'path_smooth': 4.6122213491899746e-07, 'min_data_in_leaf': 100, 'max_bin': 184, 'feature_fraction': 0.5859246944646821, 'bagging_fraction': 0.8591900416062732}. Best is trial 1 with value: 0.6900624286949082.
# [I 2025-10-24 06:25:15,834] Trial 3 finished with value: 0.7002065625756211 and parameters: {'lr': 0.0003949565350617718, 'n_estimators': 433, 'max_depth': 23, 'num_leaves': 39, 'subsample': 0.7071083559176792, 'colsample_bytree': 0.5496234775811784, 'reg_alpha': 0.013551397268244015, 'reg_lambda': 0.3294174003334398, 'path_smooth': 1.1082047819203755e-07, 'min_data_in_leaf': 41, 'max_bin': 202, 'feature_fraction': 0.6154333863457454, 'bagging_fraction': 0.6344213222785804}. Best is trial 3 with value: 0.7002065625756211.
# [I 2025-10-24 06:25:17,471] Trial 4 finished with value: 0.6981999787763624 and parameters: {'lr': 0.00024842547867017325, 'n_estimators': 373, 'max_depth': 12, 'num_leaves': 19, 'subsample': 0.6246250399067793, 'colsample_bytree': 0.7905619719408312, 'reg_alpha': 0.5311818664356938, 'reg_lambda': 0.05908387293672967, 'path_smooth': 1.970364963074316e-08, 'min_data_in_leaf': 15, 'max_bin': 109, 'feature_fraction': 0.8716354302039999, 'bagging_fraction': 0.5817532287988983}. Best is trial 3 with value: 0.7002065625756211.
# [I 2025-10-24 06:25:17,916] Trial 5 finished with value: 0.7120812703890522 and parameters: {'lr': 0.05048517672789281, 'n_estimators': 361, 'max_depth': 18, 'num_leaves': 59, 'subsample': 0.7658682645346437, 'colsample_bytree': 0.9742843014092204, 'reg_alpha': 9.892295164270536, 'reg_lambda': 3.593864019211421, 'path_smooth': 2.451889181958769e-07, 'min_data_in_leaf': 85, 'max_bin': 190, 'feature_fraction': 0.7804231316322026, 'bagging_fraction': 0.7114993672863745}. Best is trial 5 with value: 0.7120812703890522.
# [I 2025-10-24 06:25:18,627] Trial 6 finished with value: 0.719238226758554 and parameters: {'lr': 0.004971176898604735, 'n_estimators': 454, 'max_depth': 17, 'num_leaves': 43, 'subsample': 0.8113435608863484, 'colsample_bytree': 0.5089423697793136, 'reg_alpha': 0.027209075541545648, 'reg_lambda': 0.7122607052005215, 'path_smooth': 8.866574261031164e-07, 'min_data_in_leaf': 62, 'max_bin': 102, 'feature_fraction': 0.8457642154451177, 'bagging_fraction': 0.5789877096369924}. Best is trial 6 with value: 0.719238226758554.
# [I 2025-10-24 06:25:19,429] Trial 7 finished with value: 0.7252965993776784 and parameters: {'lr': 0.030708209305572505, 'n_estimators': 463, 'max_depth': 22, 'num_leaves': 19, 'subsample': 0.6542488308929868, 'colsample_bytree': 0.7237448195681488, 'reg_alpha': 0.2171478639402438, 'reg_lambda': 3.3978134684137644, 'path_smooth': 0.00028973076199137357, 'min_data_in_leaf': 56, 'max_bin': 240, 'feature_fraction': 0.7779933956373506, 'bagging_fraction': 0.6220690244156954}. Best is trial 7 with value: 0.7252965993776784.
# [I 2025-10-24 06:25:19,785] Trial 8 finished with value: 0.7171699024274527 and parameters: {'lr': 4.915582398065948e-05, 'n_estimators': 60, 'max_depth': 5, 'num_leaves': 46, 'subsample': 0.6438518665043911, 'colsample_bytree': 0.6589654033338963, 'reg_alpha': 0.07536134088594347, 'reg_lambda': 0.03184880122203618, 'path_smooth': 8.851563484150123e-08, 'min_data_in_leaf': 15, 'max_bin': 150, 'feature_fraction': 0.5734300459735587, 'bagging_fraction': 0.6766331659840753}. Best is trial 7 with value: 0.7252965993776784.
# [I 2025-10-24 06:25:20,562] Trial 9 pruned.
# [I 2025-10-24 06:25:21,285] Trial 10 finished with value: 0.7335702580656402 and parameters: {'lr': 0.09973570945357453, 'n_estimators': 192, 'max_depth': 30, 'num_leaves': 31, 'subsample': 0.9983482371324646, 'colsample_bytree': 0.9102704241543812, 'reg_alpha': 0.0017523992934812807, 'reg_lambda': 0.008715999635183123, 'path_smooth': 0.00046239991285911474, 'min_data_in_leaf': 36, 'max_bin': 253, 'feature_fraction': 0.5102416498210152, 'bagging_fraction': 0.7669039268999743}. Best is trial 10 with value: 0.7335702580656402.
# [I 2025-10-24 06:25:21,881] Trial 11 finished with value: 0.7421624311915729 and parameters: {'lr': 0.09136108152433281, 'n_estimators': 188, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9781257140139507, 'colsample_bytree': 0.9330615222882648, 'reg_alpha': 0.0011723756966183349, 'reg_lambda': 0.003889328553820967, 'path_smooth': 0.0005112095014621532, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5019493750943811, 'bagging_fraction': 0.7662020009863196}. Best is trial 11 with value: 0.7421624311915729.
# [I 2025-10-24 06:25:22,441] Trial 12 finished with value: 0.738036712920098 and parameters: {'lr': 0.09320084023841041, 'n_estimators': 186, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9763804673164594, 'colsample_bytree': 0.964259946001126, 'reg_alpha': 0.0015551897153078472, 'reg_lambda': 0.004204034939634701, 'path_smooth': 0.00040179791513528956, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5067944226528862, 'bagging_fraction': 0.7872160285248717}. Best is trial 11 with value: 0.7421624311915729.
# [I 2025-10-24 06:25:23,072] Trial 13 finished with value: 0.7467002288329521 and parameters: {'lr': 0.01063224428928842, 'n_estimators': 213, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9928607390569557, 'colsample_bytree': 0.9903148518735189, 'reg_alpha': 0.0010287791980248412, 'reg_lambda': 0.0017756589663697627, 'path_smooth': 3.813159671294933e-05, 'min_data_in_leaf': 33, 'max_bin': 217, 'feature_fraction': 0.5316373861714291, 'bagging_fraction': 0.7976820944546316}. Best is trial 13 with value: 0.7467002288329521.
# [I 2025-10-24 06:25:23,961] Trial 14 finished with value: 0.7477833973477901 and parameters: {'lr': 0.01077959506712395, 'n_estimators': 264, 'max_depth': 27, 'num_leaves': 34, 'subsample': 0.9101904196533004, 'colsample_bytree': 0.8853252664794393, 'reg_alpha': 0.004236245334318137, 'reg_lambda': 0.016168648118311695, 'path_smooth': 3.178291080990174e-05, 'min_data_in_leaf': 25, 'max_bin': 217, 'feature_fraction': 0.5402242210816777, 'bagging_fraction': 0.8865501072005892}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:25,011] Trial 15 finished with value: 0.7378681232444478 and parameters: {'lr': 0.011154054164067007, 'n_estimators': 270, 'max_depth': 26, 'num_leaves': 37, 'subsample': 0.8835221702662317, 'colsample_bytree': 0.8730297241802595, 'reg_alpha': 0.004915620032902984, 'reg_lambda': 0.01573130735760934, 'path_smooth': 2.8710871668989502e-05, 'min_data_in_leaf': 21, 'max_bin': 214, 'feature_fraction': 0.6855029467172082, 'bagging_fraction': 0.8982833760693304}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:28,247] Trial 16 finished with value: 0.7447884753154644 and parameters: {'lr': 0.0039267815931021246, 'n_estimators': 262, 'max_depth': 27, 'num_leaves': 50, 'subsample': 0.8975961823710823, 'colsample_bytree': 0.9985011187034571, 'reg_alpha': 0.0039064650847154105, 'reg_lambda': 0.0012177430394238642, 'path_smooth': 1.8376563458438878e-05, 'min_data_in_leaf': 26, 'max_bin': 217, 'feature_fraction': 0.5580279783962024, 'bagging_fraction': 0.5203985036743171}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:28,608] Trial 17 pruned.
# [I 2025-10-24 06:25:29,657] Trial 18 pruned.
# [I 2025-10-24 06:25:31,253] Trial 19 finished with value: 0.7384727942981076 and parameters: {'lr': 0.008461532593757863, 'n_estimators': 239, 'max_depth': 21, 'num_leaves': 53, 'subsample': 0.9397541926971443, 'colsample_bytree': 0.9365474025078249, 'reg_alpha': 0.001021225435306185, 'reg_lambda': 0.0263160047169807, 'path_smooth': 5.129960418197489e-06, 'min_data_in_leaf': 10, 'max_bin': 201, 'feature_fraction': 0.5443300569327884, 'bagging_fraction': 0.8075762316351955}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:31,636] Trial 20 pruned.
# [I 2025-10-24 06:25:32,547] Trial 21 finished with value: 0.7431118625654951 and parameters: {'lr': 0.0035049837413618696, 'n_estimators': 264, 'max_depth': 28, 'num_leaves': 49, 'subsample': 0.9337787720613854, 'colsample_bytree': 0.9920977183735123, 'reg_alpha': 0.004317340455859172, 'reg_lambda': 0.0012810952672320372, 'path_smooth': 8.968988592744435e-05, 'min_data_in_leaf': 24, 'max_bin': 215, 'feature_fraction': 0.5509275370078223, 'bagging_fraction': 0.6784573138074195}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:33,282] Trial 22 pruned.
# [I 2025-10-24 06:25:34,548] Trial 23 finished with value: 0.7435122235627819 and parameters: {'lr': 0.021700700426369762, 'n_estimators': 312, 'max_depth': 29, 'num_leaves': 34, 'subsample': 0.7993266770004936, 'colsample_bytree': 0.9393957345660465, 'reg_alpha': 0.00953987362560436, 'reg_lambda': 0.002407666987019695, 'path_smooth': 1.169545188619985e-05, 'min_data_in_leaf': 19, 'max_bin': 228, 'feature_fraction': 0.6128804473550201, 'bagging_fraction': 0.5003240680161775}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:35,123] Trial 24 pruned.
# [I 2025-10-24 06:25:35,645] Trial 25 pruned.
# [I 2025-10-24 06:25:37,523] Trial 26 finished with value: 0.7431814568784422 and parameters: {'lr': 0.002733555164042547, 'n_estimators': 290, 'max_depth': 26, 'num_leaves': 24, 'subsample': 0.9130143983175417, 'colsample_bytree': 0.9955471030458347, 'reg_alpha': 0.005236508056700454, 'reg_lambda': 0.002370556553121742, 'path_smooth': 1.8292915679880629e-06, 'min_data_in_leaf': 10, 'max_bin': 237, 'feature_fraction': 0.645397820322396, 'bagging_fraction': 0.8606790262962825}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:38,290] Trial 27 finished with value: 0.7451413743693481 and parameters: {'lr': 0.010767485204326853, 'n_estimators': 413, 'max_depth': 15, 'num_leaves': 32, 'subsample': 0.9668158851434371, 'colsample_bytree': 0.8879667514062949, 'reg_alpha': 0.0025188190977668873, 'reg_lambda': 0.00103424901842292, 'path_smooth': 8.20773382083338e-06, 'min_data_in_leaf': 52, 'max_bin': 186, 'feature_fraction': 0.5274114380839544, 'bagging_fraction': 0.5009468604256336}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:41,462] Trial 28 pruned.
# [I 2025-10-24 06:25:42,022] Trial 29 pruned.
# [I 2025-10-24 06:25:42,827] Trial 30 pruned.
# [I 2025-10-24 06:25:43,532] Trial 31 pruned.
# [I 2025-10-24 06:25:44,220] Trial 32 pruned.
# [I 2025-10-24 06:25:44,637] Trial 33 pruned.
# [I 2025-10-24 06:25:45,348] Trial 34 finished with value: 0.7431080920377556 and parameters: {'lr': 0.01424655621671643, 'n_estimators': 340, 'max_depth': 24, 'num_leaves': 58, 'subsample': 0.7141620329187631, 'colsample_bytree': 0.8278308152289748, 'reg_alpha': 0.013041265684029526, 'reg_lambda': 0.0016060994085527098, 'path_smooth': 1.2224395005322136e-05, 'min_data_in_leaf': 47, 'max_bin': 186, 'feature_fraction': 0.5585428284174135, 'bagging_fraction': 0.5980477579320017}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:46,524] Trial 35 pruned.
# [I 2025-10-24 06:25:46,919] Trial 36 pruned.
# [I 2025-10-24 06:25:47,417] Trial 37 pruned.
# [I 2025-10-24 06:25:48,084] Trial 38 pruned.
# [I 2025-10-24 06:25:48,818] Trial 39 pruned.
# [I 2025-10-24 06:25:49,185] Trial 40 pruned.
# [I 2025-10-24 06:25:50,122] Trial 41 pruned.
# [I 2025-10-24 06:25:52,607] Trial 42 finished with value: 0.747525152757847 and parameters: {'lr': 0.025426799408610777, 'n_estimators': 314, 'max_depth': 28, 'num_leaves': 32, 'subsample': 0.7937354757716985, 'colsample_bytree': 0.9742426192616032, 'reg_alpha': 0.0015642008923162057, 'reg_lambda': 0.002488449800416675, 'path_smooth': 1.342735345951995e-05, 'min_data_in_leaf': 16, 'max_bin': 218, 'feature_fraction': 0.5768415430775071, 'bagging_fraction': 0.5175847142469922}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:55,501] Trial 43 finished with value: 0.7409135303605978 and parameters: {'lr': 0.0395772859054493, 'n_estimators': 353, 'max_depth': 27, 'num_leaves': 31, 'subsample': 0.7813231290150529, 'colsample_bytree': 0.9746373202257324, 'reg_alpha': 0.0015676443337420457, 'reg_lambda': 0.0066090175177947125, 'path_smooth': 1.7080539543628504e-05, 'min_data_in_leaf': 18, 'max_bin': 218, 'feature_fraction': 0.5698128818861019, 'bagging_fraction': 0.5210425443765416}. Best is trial 14 with value: 0.7477833973477901.
# [I 2025-10-24 06:25:56,876] Trial 44 finished with value: 0.7544502126616842 and parameters: {'lr': 0.011521486437934367, 'n_estimators': 297, 'max_depth': 31, 'num_leaves': 32, 'subsample': 0.6876643499326835, 'colsample_bytree': 0.9988460215873797, 'reg_alpha': 0.001567427707805425, 'reg_lambda': 0.0031564855329310735, 'path_smooth': 5.184842849523365e-05, 'min_data_in_leaf': 16, 'max_bin': 243, 'feature_fraction': 0.5385931013332868, 'bagging_fraction': 0.5609535482447322}. Best is trial 44 with value: 0.7544502126616842.
# [I 2025-10-24 06:25:58,391] Trial 45 finished with value: 0.743202663390384 and parameters: {'lr': 0.06497900379664574, 'n_estimators': 298, 'max_depth': 31, 'num_leaves': 31, 'subsample': 0.6774579479206029, 'colsample_bytree': 0.5737090392712847, 'reg_alpha': 0.0015916324499708641, 'reg_lambda': 0.002949648291967318, 'path_smooth': 5.635232759815715e-05, 'min_data_in_leaf': 14, 'max_bin': 243, 'feature_fraction': 0.52894321425394, 'bagging_fraction': 0.5807993552453816}. Best is trial 44 with value: 0.7544502126616842.
# [I 2025-10-24 06:26:00,212] Trial 46 finished with value: 0.7471024553677257 and parameters: {'lr': 0.029310767104587864, 'n_estimators': 389, 'max_depth': 31, 'num_leaves': 27, 'subsample': 0.6008355332631905, 'colsample_bytree': 0.9671813523381655, 'reg_alpha': 0.0014087826119599757, 'reg_lambda': 0.010520084718705875, 'path_smooth': 8.046438044340318e-07, 'min_data_in_leaf': 15, 'max_bin': 243, 'feature_fraction': 0.5190675647640245, 'bagging_fraction': 0.7836970106529291}. Best is trial 44 with value: 0.7544502126616842.
# [I 2025-10-24 06:26:02,134] Trial 47 finished with value: 0.7489107256695945 and parameters: {'lr': 0.029805085392914234, 'n_estimators': 388, 'max_depth': 31, 'num_leaves': 27, 'subsample': 0.5883670791527661, 'colsample_bytree': 0.9737022332914813, 'reg_alpha': 0.0010110256345441657, 'reg_lambda': 0.011442427364774448, 'path_smooth': 3.6647599774580766e-07, 'min_data_in_leaf': 14, 'max_bin': 248, 'feature_fraction': 0.5412819483278233, 'bagging_fraction': 0.7943188734304227}. Best is trial 44 with value: 0.7544502126616842.
# [I 2025-10-24 06:26:04,317] Trial 48 pruned.
# [I 2025-10-24 06:26:09,019] Trial 49 finished with value: 0.7483078204727689 and parameters: {'lr': 0.06125641837362569, 'n_estimators': 390, 'max_depth': 31, 'num_leaves': 27, 'subsample': 0.6187055139775788, 'colsample_bytree': 0.9235091701987997, 'reg_alpha': 0.005896953771482613, 'reg_lambda': 0.020330911436529285, 'path_smooth': 4.423485985087803e-07, 'min_data_in_leaf': 12, 'max_bin': 248, 'feature_fraction': 0.8919089343009488, 'bagging_fraction': 0.7366425471831686}. Best is trial 44 with value: 0.7544502126616842.
# S3 최적 파라미터: {'lr': 0.011521486437934367, 'n_estimators': 297, 'max_depth': 31, 'num_leaves': 32, 'subsample': 0.6876643499326835, 'colsample_bytree': 0.9988460215873797, 'reg_alpha': 0.001567427707805425, 'reg_lambda': 0.0031564855329310735, 'path_smooth': 5.184842849523365e-05, 'min_data_in_leaf': 16, 'max_bin': 243, 'feature_fraction': 0.5385931013332868, 'bagging_fraction': 0.5609535482447322}
# S3 최고 F1 점수: 0.7545
# ==================================================

# %%
def smote_optuna_multi(split_date):
  for col in target_multi:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]

    def objective_multi(trial):
      params = {
          'learning_rate': trial.suggest_float("lr", 1e-5, 1e-1, log=True),
          'n_estimators': trial.suggest_int('n_estimators', 50, 500),
          'max_depth': trial.suggest_int('max_depth', 2, 32),
          'num_leaves': trial.suggest_int('num_leaves', 16, 64),
          'subsample': trial.suggest_float('subsample', 0.5, 1.0),
          'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
          'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
          'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
          'path_smooth' : trial.suggest_loguniform('path_smooth', 1e-8, 1e-3),
          'num_leaves' : trial.suggest_int('num_leaves', 30, 200),
          'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
          'max_bin' : trial.suggest_int('max_bin', 100, 255),
          'feature_fraction' : trial.suggest_uniform('feature_fraction', 0.5, 0.9),
          'bagging_fraction' : trial.suggest_uniform('bagging_fraction', 0.5, 0.9),
          'random_state': seed,
          'n_jobs': -1,
          'verbosity': -1,
          'objective': 'multiclass',
          'num_class': 3
      }

      feat = features[col]

      clf_binary = LGBMClassifier(**params)
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='not majority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score_macro = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='f1_macro').mean()

      trial.report(score_macro, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score_macro

    study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=seed))
    study.optimize(objective_multi, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    lgbm_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_multi(split_data)
# Out:
# [I 2025-10-24 06:26:09,037] A new study created in memory with name: no-name-69c0727a-3c6e-4b30-9da6-72b4b46d5055
# === target: S1 ===
# [I 2025-10-24 06:26:11,400] Trial 0 finished with value: 0.3826401341704198 and parameters: {'lr': 1.5106249671860432e-05, 'n_estimators': 339, 'max_depth': 31, 'num_leaves': 17, 'subsample': 0.5023240118702073, 'colsample_bytree': 0.7526598267090864, 'reg_alpha': 0.6834515648539062, 'reg_lambda': 4.603537484050716, 'path_smooth': 4.1267228833656876e-08, 'min_data_in_leaf': 74, 'max_bin': 172, 'feature_fraction': 0.6605739639515698, 'bagging_fraction': 0.592452365530872}. Best is trial 0 with value: 0.3826401341704198.
# [I 2025-10-24 06:26:13,686] Trial 1 finished with value: 0.40401065451483265 and parameters: {'lr': 2.708916662683437e-05, 'n_estimators': 186, 'max_depth': 4, 'num_leaves': 63, 'subsample': 0.5372630344763973, 'colsample_bytree': 0.849442817276649, 'reg_alpha': 0.09266314028306984, 'reg_lambda': 1.1663679970572534, 'path_smooth': 2.0788347659089347e-06, 'min_data_in_leaf': 50, 'max_bin': 141, 'feature_fraction': 0.599451423457273, 'bagging_fraction': 0.7580210670788405}. Best is trial 1 with value: 0.40401065451483265.
# [I 2025-10-24 06:26:16,743] Trial 2 finished with value: 0.3772964994723075 and parameters: {'lr': 1.5387507769813355e-05, 'n_estimators': 478, 'max_depth': 25, 'num_leaves': 19, 'subsample': 0.8903762209202944, 'colsample_bytree': 0.7884919116004143, 'reg_alpha': 0.015516998171697351, 'reg_lambda': 4.807638732776518, 'path_smooth': 4.6122213491899746e-07, 'min_data_in_leaf': 100, 'max_bin': 184, 'feature_fraction': 0.5859246944646821, 'bagging_fraction': 0.8591900416062732}. Best is trial 1 with value: 0.40401065451483265.
# [I 2025-10-24 06:26:24,642] Trial 3 finished with value: 0.4052022542131142 and parameters: {'lr': 0.0003949565350617718, 'n_estimators': 433, 'max_depth': 23, 'num_leaves': 39, 'subsample': 0.7071083559176792, 'colsample_bytree': 0.5496234775811784, 'reg_alpha': 0.013551397268244015, 'reg_lambda': 0.3294174003334398, 'path_smooth': 1.1082047819203755e-07, 'min_data_in_leaf': 41, 'max_bin': 202, 'feature_fraction': 0.6154333863457454, 'bagging_fraction': 0.6344213222785804}. Best is trial 3 with value: 0.4052022542131142.
# [I 2025-10-24 06:26:37,110] Trial 4 finished with value: 0.40656496471275505 and parameters: {'lr': 0.00024842547867017325, 'n_estimators': 373, 'max_depth': 12, 'num_leaves': 19, 'subsample': 0.6246250399067793, 'colsample_bytree': 0.7905619719408312, 'reg_alpha': 0.5311818664356938, 'reg_lambda': 0.05908387293672967, 'path_smooth': 1.970364963074316e-08, 'min_data_in_leaf': 15, 'max_bin': 109, 'feature_fraction': 0.8716354302039999, 'bagging_fraction': 0.5817532287988983}. Best is trial 4 with value: 0.40656496471275505.
# [I 2025-10-24 06:26:41,268] Trial 5 finished with value: 0.4162066566319493 and parameters: {'lr': 0.05048517672789281, 'n_estimators': 361, 'max_depth': 18, 'num_leaves': 59, 'subsample': 0.7658682645346437, 'colsample_bytree': 0.9742843014092204, 'reg_alpha': 9.892295164270536, 'reg_lambda': 3.593864019211421, 'path_smooth': 2.451889181958769e-07, 'min_data_in_leaf': 85, 'max_bin': 190, 'feature_fraction': 0.7804231316322026, 'bagging_fraction': 0.7114993672863745}. Best is trial 5 with value: 0.4162066566319493.
# [I 2025-10-24 06:26:47,657] Trial 6 finished with value: 0.41724513873193275 and parameters: {'lr': 0.004971176898604735, 'n_estimators': 454, 'max_depth': 17, 'num_leaves': 43, 'subsample': 0.8113435608863484, 'colsample_bytree': 0.5089423697793136, 'reg_alpha': 0.027209075541545648, 'reg_lambda': 0.7122607052005215, 'path_smooth': 8.866574261031164e-07, 'min_data_in_leaf': 62, 'max_bin': 102, 'feature_fraction': 0.8457642154451177, 'bagging_fraction': 0.5789877096369924}. Best is trial 6 with value: 0.41724513873193275.
# [I 2025-10-24 06:26:52,403] Trial 7 finished with value: 0.44748948839313235 and parameters: {'lr': 0.030708209305572505, 'n_estimators': 463, 'max_depth': 22, 'num_leaves': 19, 'subsample': 0.6542488308929868, 'colsample_bytree': 0.7237448195681488, 'reg_alpha': 0.2171478639402438, 'reg_lambda': 3.3978134684137644, 'path_smooth': 0.00028973076199137357, 'min_data_in_leaf': 56, 'max_bin': 240, 'feature_fraction': 0.7779933956373506, 'bagging_fraction': 0.6220690244156954}. Best is trial 7 with value: 0.44748948839313235.
# [I 2025-10-24 06:26:54,186] Trial 8 finished with value: 0.4144226834020679 and parameters: {'lr': 4.915582398065948e-05, 'n_estimators': 60, 'max_depth': 5, 'num_leaves': 46, 'subsample': 0.6438518665043911, 'colsample_bytree': 0.6589654033338963, 'reg_alpha': 0.07536134088594347, 'reg_lambda': 0.03184880122203618, 'path_smooth': 8.851563484150123e-08, 'min_data_in_leaf': 15, 'max_bin': 150, 'feature_fraction': 0.5734300459735587, 'bagging_fraction': 0.6766331659840753}. Best is trial 7 with value: 0.44748948839313235.
# [I 2025-10-24 06:27:01,634] Trial 9 pruned.
# [I 2025-10-24 06:27:04,683] Trial 10 finished with value: 0.4652205818344898 and parameters: {'lr': 0.09973570945357453, 'n_estimators': 192, 'max_depth': 30, 'num_leaves': 31, 'subsample': 0.9983482371324646, 'colsample_bytree': 0.9102704241543812, 'reg_alpha': 0.0017523992934812807, 'reg_lambda': 0.008715999635183123, 'path_smooth': 0.00046239991285911474, 'min_data_in_leaf': 36, 'max_bin': 253, 'feature_fraction': 0.5102416498210152, 'bagging_fraction': 0.7669039268999743}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:07,874] Trial 11 finished with value: 0.46457224885006204 and parameters: {'lr': 0.09136108152433281, 'n_estimators': 188, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9781257140139507, 'colsample_bytree': 0.9330615222882648, 'reg_alpha': 0.0011723756966183349, 'reg_lambda': 0.003889328553820967, 'path_smooth': 0.0005112095014621532, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5019493750943811, 'bagging_fraction': 0.7662020009863196}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:16,646] Trial 12 finished with value: 0.45913805393967244 and parameters: {'lr': 0.09320084023841041, 'n_estimators': 186, 'max_depth': 32, 'num_leaves': 29, 'subsample': 0.9763804673164594, 'colsample_bytree': 0.964259946001126, 'reg_alpha': 0.0015551897153078472, 'reg_lambda': 0.004204034939634701, 'path_smooth': 0.00040179791513528956, 'min_data_in_leaf': 33, 'max_bin': 252, 'feature_fraction': 0.5067944226528862, 'bagging_fraction': 0.7872160285248717}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:20,343] Trial 13 finished with value: 0.4301006446453771 and parameters: {'lr': 0.011529052079977743, 'n_estimators': 215, 'max_depth': 28, 'num_leaves': 32, 'subsample': 0.9928618790059229, 'colsample_bytree': 0.8913745656117514, 'reg_alpha': 0.0010525973251747005, 'reg_lambda': 0.007305430314527808, 'path_smooth': 4.7009726709380874e-05, 'min_data_in_leaf': 33, 'max_bin': 215, 'feature_fraction': 0.5337321377317602, 'bagging_fraction': 0.7869763826049884}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:22,724] Trial 14 finished with value: 0.45416138161850894 and parameters: {'lr': 0.009986165660507518, 'n_estimators': 100, 'max_depth': 28, 'num_leaves': 34, 'subsample': 0.9101904196533004, 'colsample_bytree': 0.88039899938208, 'reg_alpha': 0.004441982107483084, 'reg_lambda': 0.016012049835120223, 'path_smooth': 3.178291080990174e-05, 'min_data_in_leaf': 26, 'max_bin': 224, 'feature_fraction': 0.6944906130737712, 'bagging_fraction': 0.7250313062654455}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:28,569] Trial 15 pruned.
# [I 2025-10-24 06:27:31,575] Trial 16 finished with value: 0.4497744321130435 and parameters: {'lr': 0.023065322826754154, 'n_estimators': 132, 'max_depth': 27, 'num_leaves': 51, 'subsample': 0.8424489413656091, 'colsample_bytree': 0.9970291701393508, 'reg_alpha': 0.0029551215360589882, 'reg_lambda': 0.14333097998880948, 'path_smooth': 0.0008745080531220849, 'min_data_in_leaf': 24, 'max_bin': 227, 'feature_fraction': 0.5531195778511888, 'bagging_fraction': 0.5203985036743171}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:33,378] Trial 17 finished with value: 0.4346491385413054 and parameters: {'lr': 0.08862410945994469, 'n_estimators': 269, 'max_depth': 14, 'num_leaves': 37, 'subsample': 0.9469953671652791, 'colsample_bytree': 0.8641077702709576, 'reg_alpha': 6.446669316406296, 'reg_lambda': 0.008418159312440896, 'path_smooth': 0.00011984143221594822, 'min_data_in_leaf': 37, 'max_bin': 207, 'feature_fraction': 0.6528252837743311, 'bagging_fraction': 0.8236205530103688}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:39,193] Trial 18 finished with value: 0.4257996284843638 and parameters: {'lr': 0.017939906352989483, 'n_estimators': 149, 'max_depth': 9, 'num_leaves': 25, 'subsample': 0.8447371231081657, 'colsample_bytree': 0.9265730962063649, 'reg_alpha': 0.03930040866089831, 'reg_lambda': 0.002822255538622927, 'path_smooth': 1.0195614458829131e-05, 'min_data_in_leaf': 25, 'max_bin': 255, 'feature_fraction': 0.6404092612232081, 'bagging_fraction': 0.6768482112804393}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:52,275] Trial 19 finished with value: 0.42644075236088075 and parameters: {'lr': 0.005591437115409805, 'n_estimators': 239, 'max_depth': 21, 'num_leaves': 24, 'subsample': 0.9956082784002334, 'colsample_bytree': 0.8223781530838898, 'reg_alpha': 0.0010405301249874295, 'reg_lambda': 0.017919488382637024, 'path_smooth': 4.703996875011578e-06, 'min_data_in_leaf': 10, 'max_bin': 168, 'feature_fraction': 0.7168356278246858, 'bagging_fraction': 0.7535149212601415}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:27:55,112] Trial 20 pruned.
# [I 2025-10-24 06:27:58,296] Trial 21 finished with value: 0.44191687871953106 and parameters: {'lr': 0.09584041958504375, 'n_estimators': 175, 'max_depth': 32, 'num_leaves': 30, 'subsample': 0.9633354242905913, 'colsample_bytree': 0.9607220335401295, 'reg_alpha': 0.0020252930062837145, 'reg_lambda': 0.004139027833606514, 'path_smooth': 0.0007591937664565091, 'min_data_in_leaf': 31, 'max_bin': 244, 'feature_fraction': 0.5039610124937969, 'bagging_fraction': 0.7844762950329514}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:01,331] Trial 22 finished with value: 0.4325106378431549 and parameters: {'lr': 0.04370863108352946, 'n_estimators': 216, 'max_depth': 25, 'num_leaves': 35, 'subsample': 0.866053985680947, 'colsample_bytree': 0.9555345519227998, 'reg_alpha': 0.0010962433858979972, 'reg_lambda': 0.0010734539857595626, 'path_smooth': 0.0002584325295962891, 'min_data_in_leaf': 47, 'max_bin': 234, 'feature_fraction': 0.5108261914890706, 'bagging_fraction': 0.7501835498008572}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:05,966] Trial 23 finished with value: 0.46209324130177476 and parameters: {'lr': 0.0919356014115329, 'n_estimators': 121, 'max_depth': 30, 'num_leaves': 28, 'subsample': 0.9942621025194974, 'colsample_bytree': 0.9901449141257597, 'reg_alpha': 0.0021892390535302145, 'reg_lambda': 0.005322707486269504, 'path_smooth': 0.00047626020402923643, 'min_data_in_leaf': 38, 'max_bin': 255, 'feature_fraction': 0.5525982145614363, 'bagging_fraction': 0.7935808127081811}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:08,009] Trial 24 finished with value: 0.4359354925485565 and parameters: {'lr': 0.04298836258982543, 'n_estimators': 92, 'max_depth': 29, 'num_leaves': 24, 'subsample': 0.934508224052684, 'colsample_bytree': 0.8340533865614338, 'reg_alpha': 0.008283280804668617, 'reg_lambda': 0.009867998827233588, 'path_smooth': 0.00011195348123508076, 'min_data_in_leaf': 40, 'max_bin': 216, 'feature_fraction': 0.5481273719463157, 'bagging_fraction': 0.8852545815475733}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:12,879] Trial 25 finished with value: 0.43559189134711146 and parameters: {'lr': 0.010582271095761308, 'n_estimators': 129, 'max_depth': 25, 'num_leaves': 27, 'subsample': 0.9987904801517665, 'colsample_bytree': 0.9200483854264256, 'reg_alpha': 0.0033999258184135876, 'reg_lambda': 0.02042679137603797, 'path_smooth': 1.0850401797548701e-05, 'min_data_in_leaf': 20, 'max_bin': 199, 'feature_fraction': 0.5698604974270891, 'bagging_fraction': 0.8105219441151085}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:17,343] Trial 26 pruned.
# [I 2025-10-24 06:28:20,025] Trial 27 finished with value: 0.46374963397419355 and parameters: {'lr': 0.052693351565861, 'n_estimators': 163, 'max_depth': 26, 'num_leaves': 34, 'subsample': 0.9476508635407415, 'colsample_bytree': 0.8836062511696964, 'reg_alpha': 1.9108265307972065, 'reg_lambda': 0.04206015443117417, 'path_smooth': 6.389657500420153e-05, 'min_data_in_leaf': 38, 'max_bin': 220, 'feature_fraction': 0.5336692350036252, 'bagging_fraction': 0.6956548320291781}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:24,282] Trial 28 finished with value: 0.44435577749395955 and parameters: {'lr': 0.019052059192376354, 'n_estimators': 297, 'max_depth': 26, 'num_leaves': 34, 'subsample': 0.929676185532401, 'colsample_bytree': 0.7998365278284161, 'reg_alpha': 2.821622280951175, 'reg_lambda': 0.16695620580416484, 'path_smooth': 6.452754525073555e-05, 'min_data_in_leaf': 30, 'max_bin': 219, 'feature_fraction': 0.5312286858714513, 'bagging_fraction': 0.6895395925221833}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:25,871] Trial 29 finished with value: 0.46064334160819803 and parameters: {'lr': 0.05187133643125248, 'n_estimators': 160, 'max_depth': 23, 'num_leaves': 16, 'subsample': 0.8646514775535667, 'colsample_bytree': 0.7450894074869068, 'reg_alpha': 1.1792559957329065, 'reg_lambda': 0.03534575631469447, 'path_smooth': 2.108457756731569e-05, 'min_data_in_leaf': 76, 'max_bin': 235, 'feature_fraction': 0.686236658183103, 'bagging_fraction': 0.6340542263310074}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:28,989] Trial 30 pruned.
# [I 2025-10-24 06:28:33,078] Trial 31 finished with value: 0.4569503131799594 and parameters: {'lr': 0.0939710255979439, 'n_estimators': 122, 'max_depth': 30, 'num_leaves': 32, 'subsample': 0.9634396554236824, 'colsample_bytree': 0.889079663513676, 'reg_alpha': 0.6641008108589226, 'reg_lambda': 0.0060448291493434315, 'path_smooth': 0.00044005611386973794, 'min_data_in_leaf': 37, 'max_bin': 246, 'feature_fraction': 0.5673794993090405, 'bagging_fraction': 0.7715196356481562}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:34,565] Trial 32 finished with value: 0.4486650609473978 and parameters: {'lr': 0.05122684446911515, 'n_estimators': 97, 'max_depth': 30, 'num_leaves': 21, 'subsample': 0.8955162729371287, 'colsample_bytree': 0.9484298780749745, 'reg_alpha': 1.699318612358483, 'reg_lambda': 0.03308895926535144, 'path_smooth': 8.392803303424468e-05, 'min_data_in_leaf': 44, 'max_bin': 241, 'feature_fraction': 0.526245031085064, 'bagging_fraction': 0.7399876722843525}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:36,930] Trial 33 pruned.
# [I 2025-10-24 06:28:39,494] Trial 34 finished with value: 0.4478040976901031 and parameters: {'lr': 0.06376641956657315, 'n_estimators': 153, 'max_depth': 31, 'num_leaves': 31, 'subsample': 0.9995809149244926, 'colsample_bytree': 0.9910908353510843, 'reg_alpha': 0.27391840994991545, 'reg_lambda': 0.0716589547084282, 'path_smooth': 0.0001965435562122651, 'min_data_in_leaf': 38, 'max_bin': 245, 'feature_fraction': 0.5875897042538536, 'bagging_fraction': 0.8474181652266726}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:46,469] Trial 35 finished with value: 0.4471228432091106 and parameters: {'lr': 0.02414134281357674, 'n_estimators': 238, 'max_depth': 25, 'num_leaves': 27, 'subsample': 0.9179327174224736, 'colsample_bytree': 0.9095401597639552, 'reg_alpha': 0.047671675384631386, 'reg_lambda': 0.3012313822291079, 'path_smooth': 0.0005409204555094267, 'min_data_in_leaf': 27, 'max_bin': 162, 'feature_fraction': 0.5284644128030771, 'bagging_fraction': 0.7682427968217245}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:49,172] Trial 36 pruned.
# [I 2025-10-24 06:28:50,810] Trial 37 pruned.
# [I 2025-10-24 06:28:53,592] Trial 38 finished with value: 0.4619252371814178 and parameters: {'lr': 0.03299306342899173, 'n_estimators': 400, 'max_depth': 23, 'num_leaves': 27, 'subsample': 0.8853974114476708, 'colsample_bytree': 0.819228951310119, 'reg_alpha': 0.14258851942343062, 'reg_lambda': 0.02849433318179332, 'path_smooth': 1.983924569335814e-05, 'min_data_in_leaf': 90, 'max_bin': 123, 'feature_fraction': 0.6076172027179794, 'bagging_fraction': 0.652238545375396}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:28:59,581] Trial 39 pruned.
# [I 2025-10-24 06:29:03,408] Trial 40 finished with value: 0.4449526882603383 and parameters: {'lr': 0.058633638746114866, 'n_estimators': 242, 'max_depth': 14, 'num_leaves': 41, 'subsample': 0.5013034921693932, 'colsample_bytree': 0.9709934767575618, 'reg_alpha': 0.42242696757941856, 'reg_lambda': 0.0064784341221380696, 'path_smooth': 6.868967605536567e-05, 'min_data_in_leaf': 21, 'max_bin': 184, 'feature_fraction': 0.8299556098707676, 'bagging_fraction': 0.6006554752361905}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:29:06,231] Trial 41 finished with value: 0.4584147576695402 and parameters: {'lr': 0.03505910664368729, 'n_estimators': 408, 'max_depth': 24, 'num_leaves': 27, 'subsample': 0.8756820732751994, 'colsample_bytree': 0.8164138580592575, 'reg_alpha': 0.06661198585807251, 'reg_lambda': 0.03929989144306875, 'path_smooth': 1.104446623536675e-05, 'min_data_in_leaf': 97, 'max_bin': 140, 'feature_fraction': 0.6043442781042454, 'bagging_fraction': 0.6570138297622145}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:29:11,322] Trial 42 finished with value: 0.45302571821359683 and parameters: {'lr': 0.06904688717113214, 'n_estimators': 369, 'max_depth': 27, 'num_leaves': 33, 'subsample': 0.9422316756200637, 'colsample_bytree': 0.7766937999743205, 'reg_alpha': 1.0770733818955565, 'reg_lambda': 0.02364587947875162, 'path_smooth': 2.8306900007085927e-05, 'min_data_in_leaf': 90, 'max_bin': 123, 'feature_fraction': 0.5823151373761924, 'bagging_fraction': 0.5538233560911646}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:29:15,090] Trial 43 finished with value: 0.45666868500763824 and parameters: {'lr': 0.031825684924597364, 'n_estimators': 422, 'max_depth': 23, 'num_leaves': 29, 'subsample': 0.8029777521874407, 'colsample_bytree': 0.833870241074398, 'reg_alpha': 0.12728031681773136, 'reg_lambda': 0.014791914285006032, 'path_smooth': 4.213003982866582e-06, 'min_data_in_leaf': 79, 'max_bin': 124, 'feature_fraction': 0.5448169767660584, 'bagging_fraction': 0.6893012883549379}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:29:16,729] Trial 44 pruned.
# [I 2025-10-24 06:29:18,787] Trial 45 pruned.
# [I 2025-10-24 06:29:28,559] Trial 46 finished with value: 0.44911778731744095 and parameters: {'lr': 0.013276224187977945, 'n_estimators': 389, 'max_depth': 26, 'num_leaves': 28, 'subsample': 0.914638208619077, 'colsample_bytree': 0.7625229396431003, 'reg_alpha': 0.0024046394305459657, 'reg_lambda': 1.1222114232657994, 'path_smooth': 4.955530192367511e-05, 'min_data_in_leaf': 30, 'max_bin': 250, 'feature_fraction': 0.5005936531709435, 'bagging_fraction': 0.6167967980865677}. Best is trial 10 with value: 0.4652205818344898.
# [I 2025-10-24 06:29:29,975] Trial 47 finished with value: 0.4670676205669678 and parameters: {'lr': 0.0973504023117758, 'n_estimators': 145, 'max_depth': 29, 'num_leaves': 31, 'subsample': 0.8334974416585945, 'colsample_bytree': 0.9813464924727119, 'reg_alpha': 0.12108433926758039, 'reg_lambda': 0.11900141927455331, 'path_smooth': 0.0005204772531935529, 'min_data_in_leaf': 70, 'max_bin': 113, 'feature_fraction': 0.6709333679019823, 'bagging_fraction': 0.8767147635714478}. Best is trial 47 with value: 0.4670676205669678.
# [I 2025-10-24 06:29:31,564] Trial 48 finished with value: 0.4672848170973086 and parameters: {'lr': 0.09452949172777327, 'n_estimators': 137, 'max_depth': 31, 'num_leaves': 45, 'subsample': 0.7304501634834658, 'colsample_bytree': 0.9826086606626508, 'reg_alpha': 0.003785001012054541, 'reg_lambda': 0.12532041335898567, 'path_smooth': 0.0006079042464351565, 'min_data_in_leaf': 69, 'max_bin': 112, 'feature_fraction': 0.7634096253090628, 'bagging_fraction': 0.8655379652078898}. Best is trial 48 with value: 0.4672848170973086.
# [I 2025-10-24 06:29:32,915] Trial 49 pruned.
# S1 최적 파라미터: {'lr': 0.09452949172777327, 'n_estimators': 137, 'max_depth': 31, 'num_leaves': 45, 'subsample': 0.7304501634834658, 'colsample_bytree': 0.9826086606626508, 'reg_alpha': 0.003785001012054541, 'reg_lambda': 0.12532041335898567, 'path_smooth': 0.0006079042464351565, 'min_data_in_leaf': 69, 'max_bin': 112, 'feature_fraction': 0.7634096253090628, 'bagging_fraction': 0.8655379652078898}
# S1 최고 F1 점수: 0.4673
# ==================================================

# %%
fix_param_binary = {'random_state': seed,
                    'n_jobs': -1,
                    'verbosity': -1
                    }

fix_param_multi = {'random_sate': seed,
                   'n_jobs': -1,
                   'verbosity': -1,
                   'objective': 'multiclass',
                   'num_class': 3
                   }

# %%
def lgbm_smote(split_data, lgbm_best_param_dict, test_x):
  preds = {}

  for col_binary in targets_binary:
    print(col_binary)
    x_train, x_val, y_train, y_val = split_data[col_binary]
    best_param = lgbm_best_param_dict[col_binary]
    feat = features[col_binary]

    clf_binary = LGBMClassifier(**best_param, **fix_param_binary)

    smote = SMOTE(sampling_strategy='minority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_binary.fit(
        x_train_over, y_train_over,
        eval_set=[(x_val[feat], y_val)],
        callbacks=[early_stopping(10), log_evaluation(0)],
        eval_metric='logloss'
    )

    y_pred = clf_binary.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred)
    train_acc = clf_binary.score(x_train[feat], y_train)
    val_acc = clf_binary.score(x_val[feat], y_val)
    print(f'{col_binary} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_binary] = clf_binary.predict(test_x[feat])

  for col_multi in target_multi:
    print(col_multi)
    x_train, x_val, y_train, y_val = split_data[col_multi]
    best_param = lgbm_best_param_dict[col_multi]
    feat = features[col_multi]

    clf_multi = LGBMClassifier(**best_param, **fix_param_multi)

    smote = SMOTE(sampling_strategy='not majority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_multi.fit(
        x_train_over, y_train_over,
        eval_set=[(x_val[feat], y_val)],
        callbacks=[early_stopping(10), log_evaluation(0)],
        eval_metric='multi_logloss'
    )

    y_pred = clf_multi.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred, average='macro')
    train_acc = clf_multi.score(x_train[feat], y_train)
    val_acc = clf_multi.score(x_val[feat], y_val)
    print(f'{col_multi} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_multi] = clf_multi.predict(test_x[feat])

  return preds

# %%
lgbm_best_param_dict
# Out:
# {'Q1': {'lr': 1.1829240481692007e-05,
#   'n_estimators': 303,
#   'max_depth': 13,
#   'num_leaves': 32,
#   'subsample': 0.8986806250207752,
#   'colsample_bytree': 0.5781104978571359,
#   'reg_alpha': 0.09024901265702105,
#   'reg_lambda': 0.0014611929574279922,
#   'path_smooth': 0.00011137009223515029,
#   'min_data_in_leaf': 100,
#   'max_bin': 105,
#   'feature_fraction': 0.8522577269149394,
#   'bagging_fraction': 0.6861650259370463},
#  'Q2': {'lr': 0.06497900379664574,
#   'n_estimators': 391,
#   'max_depth': 18,
#   'num_leaves': 51,
#   'subsample': 0.7582979267239988,
#   'colsample_bytree': 0.8651906198740047,
#   'reg_alpha': 0.11239070473982651,
#   'reg_lambda': 1.3050956051665916,
#   'path_smooth': 6.60351807814746e-06,
#   'min_data_in_leaf': 72,
#   'max_bin': 176,
#   'feature_fraction': 0.7304175673398711,
#   'bagging_fraction': 0.7446920499023151},
#  'Q3': {'lr': 0.013604904210327118,
#   'n_estimators': 430,
#   'max_depth': 24,
#   'num_leaves': 19,
#   'subsample': 0.5645433380750695,
#   'colsample_bytree': 0.593252942688302,
#   'reg_alpha': 0.0013643575284378597,
#   'reg_lambda': 0.2438984658544583,
#   'path_smooth': 1.8137214232302684e-05,
#   'min_data_in_leaf': 49,
#   'max_bin': 208,
#   'feature_fraction': 0.8649173762764597,
#   'bagging_fraction': 0.8797974768111675},
#  'S2': {'lr': 6.241834334580301e-05,
#   'n_estimators': 86,
#   'max_depth': 15,
#   'num_leaves': 33,
#   'subsample': 0.9989160263482014,
#   'colsample_bytree': 0.8938211520593293,
#   'reg_alpha': 0.009407778153257707,
#   'reg_lambda': 0.002673757228442137,
#   'path_smooth': 0.00013962002606948107,
#   'min_data_in_leaf': 36,
#   'max_bin': 148,
#   'feature_fraction': 0.747759888683967,
#   'bagging_fraction': 0.5525298429799801},
#  'S3': {'lr': 0.011521486437934367,
#   'n_estimators': 297,
#   'max_depth': 31,
#   'num_leaves': 32,
#   'subsample': 0.6876643499326835,
#   'colsample_bytree': 0.9988460215873797,
#   'reg_alpha': 0.001567427707805425,
#   'reg_lambda': 0.0031564855329310735,
#   'path_smooth': 5.184842849523365e-05,
#   'min_data_in_leaf': 16,
#   'max_bin': 243,
#   'feature_fraction': 0.5385931013332868,
#   'bagging_fraction': 0.5609535482447322},
#  'S1': {'lr': 0.09452949172777327,
#   'n_estimators': 137,
#   'max_depth': 31,
#   'num_leaves': 45,
#   'subsample': 0.7304501634834658,
#   'colsample_bytree': 0.9826086606626508,
#   'reg_alpha': 0.003785001012054541,
#   'reg_lambda': 0.12532041335898567,
#   'path_smooth': 0.0006079042464351565,
#   'min_data_in_leaf': 69,
#   'max_bin': 112,
#   'feature_fraction': 0.7634096253090628,
#   'bagging_fraction': 0.8655379652078898}}

# %%
preds_lgbm = lgbm_smote(split_data, lgbm_best_param_dict, test_x)
# Out:
# Q1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [27]	valid_0's binary_logloss: 0.678595
# Q1 -> Train Acc: 0.636111 | Validation Accucary: 0.5333 | Validation F1_score: 0.5532
#
# Q2
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [1]	valid_0's binary_logloss: 0.695147
# Q2 -> Train Acc: 0.613889 | Validation Accucary: 0.4444 | Validation F1_score: 0.3056
#
# Q3
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [42]	valid_0's binary_logloss: 0.628176
# Q3 -> Train Acc: 0.847222 | Validation Accucary: 0.6333 | Validation F1_score: 0.7130
#
# S2
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	valid_0's binary_logloss: 0.622367
# S2 -> Train Acc: 0.905556 | Validation Accucary: 0.6111 | Validation F1_score: 0.6847
#
# S3
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	valid_0's binary_logloss: 0.651683
# S3 -> Train Acc: 0.944444 | Validation Accucary: 0.6333 | Validation F1_score: 0.7130
#
# S1
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	valid_0's multi_logloss: 0.978547
# S1 -> Train Acc: 0.822222 | Validation Accucary: 0.4778 | Validation F1_score: 0.4447

# %% [markdown]
# # smote + xgb

# %%
xgb_best_param_dict = {}

def smote_optuna_binary(split_date):
  for col in targets_binary:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]


    def objective_binary(trial):
      params = {
        'learning_rate': trial.suggest_float("lr", 1e-5, 1e-1, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 1e-3, 10.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'random_state': seed,
        'n_jobs': -1,
        'verbosity': 0
        }
      feat = features[col]
      clf_binary = XGBClassifier(**params)
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='minority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score = cross_val_score(pipeline, x_train[feat], y_train, cv=cv, scoring='f1').mean()

      trial.report(score, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score

    study = optuna.create_study(direction="maximize")
    study.optimize(objective_binary, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    xgb_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_binary(split_data)
# Out:
# [I 2025-10-24 06:29:33,293] A new study created in memory with name: no-name-2c4e8182-594d-45e8-845f-c0842878a214
# === target: Q1 ===
# [I 2025-10-24 06:29:35,770] Trial 0 finished with value: 0.5534288081429756 and parameters: {'lr': 2.7082844995150635e-05, 'n_estimators': 64, 'max_depth': 9, 'subsample': 0.721288685250457, 'colsample_bytree': 0.6712866073648217, 'gamma': 0.007415442580646419, 'reg_alpha': 0.005665555708359325, 'reg_lambda': 0.7251860506765602}. Best is trial 0 with value: 0.5534288081429756.
# [I 2025-10-24 06:29:37,453] Trial 1 finished with value: 0.5226837062146651 and parameters: {'lr': 0.02657395967129854, 'n_estimators': 390, 'max_depth': 10, 'subsample': 0.7565078982293211, 'colsample_bytree': 0.5227252726210436, 'gamma': 0.0056585913222279936, 'reg_alpha': 0.0017414163373460222, 'reg_lambda': 0.0090347455567185}. Best is trial 0 with value: 0.5534288081429756.
# [I 2025-10-24 06:29:38,578] Trial 2 finished with value: 0.5069494261119082 and parameters: {'lr': 0.000743409664789288, 'n_estimators': 257, 'max_depth': 8, 'subsample': 0.8095410701450123, 'colsample_bytree': 0.8235830710528707, 'gamma': 0.7390817327743451, 'reg_alpha': 0.0012713016860445804, 'reg_lambda': 0.004693218266319401}. Best is trial 0 with value: 0.5534288081429756.
# [I 2025-10-24 06:29:39,075] Trial 3 finished with value: 0.4990393682243829 and parameters: {'lr': 5.344205073983169e-05, 'n_estimators': 81, 'max_depth': 12, 'subsample': 0.8764282938245194, 'colsample_bytree': 0.9289121015977343, 'gamma': 0.0011907223811958008, 'reg_alpha': 2.0439951030201966, 'reg_lambda': 0.014346878534171294}. Best is trial 0 with value: 0.5534288081429756.
# [I 2025-10-24 06:29:39,721] Trial 4 finished with value: 0.5556436126229412 and parameters: {'lr': 0.027714269945260005, 'n_estimators': 157, 'max_depth': 10, 'subsample': 0.600629171226627, 'colsample_bytree': 0.8807707689021007, 'gamma': 0.2573069396879048, 'reg_alpha': 1.310600766650353, 'reg_lambda': 0.33528511769581465}. Best is trial 4 with value: 0.5556436126229412.
# [I 2025-10-24 06:29:40,884] Trial 5 pruned.
# [I 2025-10-24 06:29:41,557] Trial 6 finished with value: 0.5357304204602309 and parameters: {'lr': 0.00010385907540417728, 'n_estimators': 290, 'max_depth': 12, 'subsample': 0.6805164466324578, 'colsample_bytree': 0.6638499673088303, 'gamma': 9.600581145348464, 'reg_alpha': 0.011792155634529403, 'reg_lambda': 0.0010840573029514365}. Best is trial 4 with value: 0.5556436126229412.
# [I 2025-10-24 06:29:42,150] Trial 7 finished with value: 0.5359420277497098 and parameters: {'lr': 0.00011991836358628022, 'n_estimators': 137, 'max_depth': 4, 'subsample': 0.997378025915268, 'colsample_bytree': 0.5048500251762069, 'gamma': 0.3021776077739452, 'reg_alpha': 0.04918108799367474, 'reg_lambda': 0.002275754615023903}. Best is trial 4 with value: 0.5556436126229412.
# [I 2025-10-24 06:29:42,906] Trial 8 pruned.
# [I 2025-10-24 06:29:43,391] Trial 9 pruned.
# [I 2025-10-24 06:29:44,736] Trial 10 finished with value: 0.5649961718442842 and parameters: {'lr': 0.052043349352232524, 'n_estimators': 487, 'max_depth': 6, 'subsample': 0.5138215417113763, 'colsample_bytree': 0.9499718867414803, 'gamma': 0.029072768377694815, 'reg_alpha': 6.203535463356327, 'reg_lambda': 0.14863916484503414}. Best is trial 10 with value: 0.5649961718442842.
# [I 2025-10-24 06:29:45,830] Trial 11 finished with value: 0.5575179278771663 and parameters: {'lr': 0.060642654632714996, 'n_estimators': 480, 'max_depth': 5, 'subsample': 0.5073555165024983, 'colsample_bytree': 0.9652592225683782, 'gamma': 0.055022547889762366, 'reg_alpha': 7.012265834948791, 'reg_lambda': 0.15746934629781106}. Best is trial 10 with value: 0.5649961718442842.
# [I 2025-10-24 06:29:49,248] Trial 12 finished with value: 0.5475217463356499 and parameters: {'lr': 0.0874699321942966, 'n_estimators': 490, 'max_depth': 5, 'subsample': 0.5086533918010889, 'colsample_bytree': 0.9908783296521513, 'gamma': 0.03732235291268708, 'reg_alpha': 8.782846042877077, 'reg_lambda': 0.06799487528208895}. Best is trial 10 with value: 0.5649961718442842.
# [I 2025-10-24 06:29:50,467] Trial 13 finished with value: 0.5820174066887919 and parameters: {'lr': 0.005158227045382019, 'n_estimators': 500, 'max_depth': 6, 'subsample': 0.5014653515689952, 'colsample_bytree': 0.9874942536147016, 'gamma': 0.05156440289130511, 'reg_alpha': 9.220831718455408, 'reg_lambda': 0.0735303974249241}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:29:51,939] Trial 14 pruned.
# [I 2025-10-24 06:29:53,119] Trial 15 finished with value: 0.5515030047489844 and parameters: {'lr': 0.004181657726985287, 'n_estimators': 411, 'max_depth': 7, 'subsample': 0.5790170641674749, 'colsample_bytree': 0.8540690313429048, 'gamma': 0.23691869011115352, 'reg_alpha': 4.602655979044103, 'reg_lambda': 7.368969431597889}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:29:54,112] Trial 16 pruned.
# [I 2025-10-24 06:29:55,800] Trial 17 pruned.
# [I 2025-10-24 06:29:56,990] Trial 18 finished with value: 0.5519198350833574 and parameters: {'lr': 0.0011815933150197398, 'n_estimators': 359, 'max_depth': 6, 'subsample': 0.6544916396011891, 'colsample_bytree': 0.7800100867429189, 'gamma': 0.019729425745592524, 'reg_alpha': 3.5105530610399884, 'reg_lambda': 0.8330666834470569}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:29:58,220] Trial 19 pruned.
# [I 2025-10-24 06:30:01,396] Trial 20 pruned.
# [I 2025-10-24 06:30:02,920] Trial 21 finished with value: 0.5606132139465473 and parameters: {'lr': 0.09172081766848865, 'n_estimators': 473, 'max_depth': 5, 'subsample': 0.505937525131539, 'colsample_bytree': 0.9620986525367834, 'gamma': 0.07149868854054937, 'reg_alpha': 7.427552284812689, 'reg_lambda': 0.17405015379598573}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:04,199] Trial 22 finished with value: 0.5550536089605449 and parameters: {'lr': 0.044226501752714864, 'n_estimators': 499, 'max_depth': 5, 'subsample': 0.5439061672384603, 'colsample_bytree': 0.954779089900615, 'gamma': 0.12158488230793593, 'reg_alpha': 3.8210236988161204, 'reg_lambda': 0.10500688890524744}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:05,229] Trial 23 finished with value: 0.5591439131672711 and parameters: {'lr': 0.09587472162063604, 'n_estimators': 440, 'max_depth': 6, 'subsample': 0.500624749171587, 'colsample_bytree': 0.9529793319016999, 'gamma': 0.012549591079804336, 'reg_alpha': 7.9529746551622535, 'reg_lambda': 0.038438360588349096}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:06,526] Trial 24 finished with value: 0.5542347951920338 and parameters: {'lr': 1.0204067468284468e-05, 'n_estimators': 433, 'max_depth': 4, 'subsample': 0.6453036441720429, 'colsample_bytree': 0.9079921016986727, 'gamma': 0.0880058822382391, 'reg_alpha': 2.6346339547935593, 'reg_lambda': 1.3873382105809802}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:07,710] Trial 25 finished with value: 0.5541225185726464 and parameters: {'lr': 0.010481244308643774, 'n_estimators': 498, 'max_depth': 7, 'subsample': 0.6286267503581853, 'colsample_bytree': 0.9942671925078196, 'gamma': 0.0658899501392978, 'reg_alpha': 8.805061518825385, 'reg_lambda': 0.2768248936890663}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:08,869] Trial 26 pruned.
# [I 2025-10-24 06:30:10,532] Trial 27 pruned.
# [I 2025-10-24 06:30:11,618] Trial 28 finished with value: 0.5551413292589763 and parameters: {'lr': 0.01581117843089235, 'n_estimators': 422, 'max_depth': 5, 'subsample': 0.7049638273422865, 'colsample_bytree': 0.9609425502936396, 'gamma': 0.5353676463461176, 'reg_alpha': 3.9608343242513513, 'reg_lambda': 0.016053923982031107}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:15,441] Trial 29 pruned.
# [I 2025-10-24 06:30:16,315] Trial 30 pruned.
# [I 2025-10-24 06:30:17,306] Trial 31 pruned.
# [I 2025-10-24 06:30:18,384] Trial 32 finished with value: 0.5594363846173438 and parameters: {'lr': 0.06508617751084182, 'n_estimators': 431, 'max_depth': 6, 'subsample': 0.570815777946547, 'colsample_bytree': 0.8997076614331396, 'gamma': 0.04401015487583242, 'reg_alpha': 5.84300724095537, 'reg_lambda': 0.12564575383907714}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:19,466] Trial 33 pruned.
# [I 2025-10-24 06:30:21,003] Trial 34 finished with value: 0.5634893092702284 and parameters: {'lr': 0.024927987155363266, 'n_estimators': 478, 'max_depth': 5, 'subsample': 0.5346810512082325, 'colsample_bytree': 0.9290101424342174, 'gamma': 0.005460856519483638, 'reg_alpha': 2.3687240367715776, 'reg_lambda': 0.3835000515094351}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:22,378] Trial 35 finished with value: 0.5745153272576637 and parameters: {'lr': 0.0226746256872178, 'n_estimators': 469, 'max_depth': 4, 'subsample': 0.533082411795371, 'colsample_bytree': 0.9272412969057603, 'gamma': 0.004152811170915136, 'reg_alpha': 2.3180728451739196, 'reg_lambda': 0.45436414733365194}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:23,808] Trial 36 pruned.
# [I 2025-10-24 06:30:24,896] Trial 37 pruned.
# [I 2025-10-24 06:30:28,687] Trial 38 finished with value: 0.5611764705882354 and parameters: {'lr': 0.01899866684996455, 'n_estimators': 500, 'max_depth': 4, 'subsample': 0.6179384498107329, 'colsample_bytree': 0.876363803415179, 'gamma': 0.001676943993753695, 'reg_alpha': 1.8816282646474203, 'reg_lambda': 1.6540281134711594}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:29,822] Trial 39 pruned.
# [I 2025-10-24 06:30:30,876] Trial 40 pruned.
# [I 2025-10-24 06:30:32,306] Trial 41 pruned.
# [I 2025-10-24 06:30:33,720] Trial 42 pruned.
# [I 2025-10-24 06:30:34,091] Trial 43 pruned.
# [I 2025-10-24 06:30:35,547] Trial 44 pruned.
# [I 2025-10-24 06:30:36,917] Trial 45 pruned.
# [I 2025-10-24 06:30:38,199] Trial 46 finished with value: 0.5709870479577884 and parameters: {'lr': 0.012144675430691929, 'n_estimators': 420, 'max_depth': 5, 'subsample': 0.557904339209613, 'colsample_bytree': 0.9807845101358875, 'gamma': 0.007051478384990812, 'reg_alpha': 5.675679524822303, 'reg_lambda': 1.4880258091553096}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:41,922] Trial 47 finished with value: 0.5717360192798187 and parameters: {'lr': 0.009609551060442832, 'n_estimators': 422, 'max_depth': 6, 'subsample': 0.5555117824667295, 'colsample_bytree': 0.981614612880699, 'gamma': 0.006806223663217295, 'reg_alpha': 5.770889891465968, 'reg_lambda': 0.06174363579815889}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:43,152] Trial 48 finished with value: 0.5606417876719167 and parameters: {'lr': 0.002416581504744694, 'n_estimators': 377, 'max_depth': 7, 'subsample': 0.680720855751091, 'colsample_bytree': 0.9780803453630431, 'gamma': 0.017328192504482136, 'reg_alpha': 5.56648947868268, 'reg_lambda': 0.018643755242132028}. Best is trial 13 with value: 0.5820174066887919.
# [I 2025-10-24 06:30:44,470] Trial 49 pruned.
# [I 2025-10-24 06:30:44,472] A new study created in memory with name: no-name-063da310-f194-45f8-bf21-8206d0c698b8
# Q1 최적 파라미터: {'lr': 0.005158227045382019, 'n_estimators': 500, 'max_depth': 6, 'subsample': 0.5014653515689952, 'colsample_bytree': 0.9874942536147016, 'gamma': 0.05156440289130511, 'reg_alpha': 9.220831718455408, 'reg_lambda': 0.0735303974249241}
# Q1 최고 F1 점수: 0.5820
# ==================================================
#
# === target: Q2 ===
# [I 2025-10-24 06:30:45,526] Trial 0 finished with value: 0.6260071505075107 and parameters: {'lr': 0.002666100488728505, 'n_estimators': 219, 'max_depth': 7, 'subsample': 0.633084841535613, 'colsample_bytree': 0.5607374309310948, 'gamma': 0.5101357845474125, 'reg_alpha': 0.0044860455270858066, 'reg_lambda': 0.020993523317422887}. Best is trial 0 with value: 0.6260071505075107.
# [I 2025-10-24 06:30:46,252] Trial 1 finished with value: 0.6170434503767838 and parameters: {'lr': 0.053112930718709796, 'n_estimators': 257, 'max_depth': 5, 'subsample': 0.5717456553832535, 'colsample_bytree': 0.7639624404642442, 'gamma': 1.0572489304279908, 'reg_alpha': 3.394998253042146, 'reg_lambda': 0.3303834159537544}. Best is trial 0 with value: 0.6260071505075107.
# [I 2025-10-24 06:30:47,515] Trial 2 finished with value: 0.5841203613175632 and parameters: {'lr': 0.0002905407582022655, 'n_estimators': 413, 'max_depth': 3, 'subsample': 0.9370034049195132, 'colsample_bytree': 0.9328962513898975, 'gamma': 0.009273480117631471, 'reg_alpha': 0.6400074092132239, 'reg_lambda': 0.06610298022338783}. Best is trial 0 with value: 0.6260071505075107.
# [I 2025-10-24 06:30:48,172] Trial 3 finished with value: 0.6421432235600301 and parameters: {'lr': 0.0013392989410354174, 'n_estimators': 111, 'max_depth': 8, 'subsample': 0.5584433166296273, 'colsample_bytree': 0.9817853391406335, 'gamma': 0.0016828978772322548, 'reg_alpha': 0.0015689946498044722, 'reg_lambda': 0.0075605022327688625}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:30:49,747] Trial 4 finished with value: 0.6373000311235606 and parameters: {'lr': 0.0014673429650746718, 'n_estimators': 385, 'max_depth': 5, 'subsample': 0.5994571090442761, 'colsample_bytree': 0.9281794745381824, 'gamma': 0.04074615211997013, 'reg_alpha': 0.06228402700585354, 'reg_lambda': 1.0008163898415605}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:30:50,370] Trial 5 finished with value: 0.6275112360519238 and parameters: {'lr': 0.005007405360372647, 'n_estimators': 183, 'max_depth': 3, 'subsample': 0.5306636620207053, 'colsample_bytree': 0.9131874079949177, 'gamma': 0.00871083773893366, 'reg_alpha': 2.791983194882721, 'reg_lambda': 0.016166082247577183}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:30:54,138] Trial 6 pruned.
# [I 2025-10-24 06:30:58,246] Trial 7 pruned.
# [I 2025-10-24 06:30:59,463] Trial 8 pruned.
# [I 2025-10-24 06:31:01,642] Trial 9 pruned.
# [I 2025-10-24 06:31:02,011] Trial 10 pruned.
# [I 2025-10-24 06:31:02,406] Trial 11 pruned.
# [I 2025-10-24 06:31:03,979] Trial 12 finished with value: 0.6335834142073293 and parameters: {'lr': 0.001844016047286729, 'n_estimators': 342, 'max_depth': 8, 'subsample': 0.6245406862796875, 'colsample_bytree': 0.6832295310918943, 'gamma': 0.0010625328317779763, 'reg_alpha': 0.05627298053867603, 'reg_lambda': 0.6739743674398795}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:07,685] Trial 13 finished with value: 0.6393766937669377 and parameters: {'lr': 0.00738762726596796, 'n_estimators': 311, 'max_depth': 5, 'subsample': 0.7260753202747042, 'colsample_bytree': 0.8437351410717515, 'gamma': 0.012173859840292593, 'reg_alpha': 0.0016291173650024345, 'reg_lambda': 0.0020733375979323245}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:09,189] Trial 14 finished with value: 0.6373158790974882 and parameters: {'lr': 0.012155684999330806, 'n_estimators': 301, 'max_depth': 8, 'subsample': 0.7456641499106142, 'colsample_bytree': 0.8346605932177649, 'gamma': 0.009462990087300489, 'reg_alpha': 0.0010295465505611857, 'reg_lambda': 0.0010417512856574307}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:09,977] Trial 15 finished with value: 0.6358659654153197 and parameters: {'lr': 0.014151825572249678, 'n_estimators': 117, 'max_depth': 9, 'subsample': 0.8403909426848878, 'colsample_bytree': 0.6944293095564085, 'gamma': 0.004979260428866768, 'reg_alpha': 0.003640124876768948, 'reg_lambda': 0.0031488360951177456}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:11,239] Trial 16 pruned.
# [I 2025-10-24 06:31:11,810] Trial 17 pruned.
# [I 2025-10-24 06:31:12,953] Trial 18 pruned.
# [I 2025-10-24 06:31:14,862] Trial 19 pruned.
# [I 2025-10-24 06:31:16,823] Trial 20 finished with value: 0.6364326950939527 and parameters: {'lr': 0.005893267325867531, 'n_estimators': 460, 'max_depth': 6, 'subsample': 0.5725233731232251, 'colsample_bytree': 0.741895299903971, 'gamma': 0.01821883966241189, 'reg_alpha': 0.002854709436215818, 'reg_lambda': 0.03423876426436591}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:20,722] Trial 21 pruned.
# [I 2025-10-24 06:31:22,306] Trial 22 pruned.
# [I 2025-10-24 06:31:23,493] Trial 23 pruned.
# [I 2025-10-24 06:31:24,976] Trial 24 pruned.
# [I 2025-10-24 06:31:25,932] Trial 25 pruned.
# [I 2025-10-24 06:31:27,072] Trial 26 finished with value: 0.6371941282789516 and parameters: {'lr': 0.03525104211577557, 'n_estimators': 324, 'max_depth': 4, 'subsample': 0.7561923888382425, 'colsample_bytree': 0.8126199628492886, 'gamma': 0.004824633367050704, 'reg_alpha': 0.0019322860047490205, 'reg_lambda': 0.0047306026330604664}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:28,318] Trial 27 pruned.
# [I 2025-10-24 06:31:29,370] Trial 28 finished with value: 0.6365772179627601 and parameters: {'lr': 0.00929825334749738, 'n_estimators': 236, 'max_depth': 6, 'subsample': 0.5596571769985219, 'colsample_bytree': 0.8276046466855558, 'gamma': 0.008036283655207642, 'reg_alpha': 0.006823337478628307, 'reg_lambda': 9.669033159353107}. Best is trial 3 with value: 0.6421432235600301.
# [I 2025-10-24 06:31:31,854] Trial 29 pruned.
# [I 2025-10-24 06:31:34,076] Trial 30 pruned.
# [I 2025-10-24 06:31:35,865] Trial 31 pruned.
# [I 2025-10-24 06:31:37,199] Trial 32 pruned.
# [I 2025-10-24 06:31:38,734] Trial 33 pruned.
# [I 2025-10-24 06:31:40,188] Trial 34 pruned.
# [I 2025-10-24 06:31:41,682] Trial 35 finished with value: 0.6472720831783481 and parameters: {'lr': 0.007149295355976545, 'n_estimators': 443, 'max_depth': 3, 'subsample': 0.5030277400591299, 'colsample_bytree': 0.8777503978715401, 'gamma': 0.11962893777217314, 'reg_alpha': 2.114103413555102, 'reg_lambda': 0.0010113704985958338}. Best is trial 35 with value: 0.6472720831783481.
# [I 2025-10-24 06:31:42,998] Trial 36 pruned.
# [I 2025-10-24 06:31:46,620] Trial 37 finished with value: 0.6478913982363623 and parameters: {'lr': 0.007253718909191384, 'n_estimators': 432, 'max_depth': 3, 'subsample': 0.5038814517500667, 'colsample_bytree': 0.8406429214642972, 'gamma': 0.17523222455117982, 'reg_alpha': 1.5438489479832427, 'reg_lambda': 0.001091359355825587}. Best is trial 37 with value: 0.6478913982363623.
# [I 2025-10-24 06:31:47,912] Trial 38 pruned.
# [I 2025-10-24 06:31:49,123] Trial 39 pruned.
# [I 2025-10-24 06:31:50,375] Trial 40 pruned.
# [I 2025-10-24 06:31:51,586] Trial 41 pruned.
# [I 2025-10-24 06:31:53,163] Trial 42 finished with value: 0.6438749510693571 and parameters: {'lr': 0.007551575552850068, 'n_estimators': 472, 'max_depth': 4, 'subsample': 0.524753195348444, 'colsample_bytree': 0.8415630797206228, 'gamma': 0.6745770727863458, 'reg_alpha': 0.8989556015121067, 'reg_lambda': 0.0010119028418953283}. Best is trial 37 with value: 0.6478913982363623.
# [I 2025-10-24 06:31:54,739] Trial 43 pruned.
# [I 2025-10-24 06:31:55,987] Trial 44 pruned.
# [I 2025-10-24 06:32:00,150] Trial 45 finished with value: 0.6445781230263988 and parameters: {'lr': 0.0015694287193930667, 'n_estimators': 500, 'max_depth': 5, 'subsample': 0.5951845107822997, 'colsample_bytree': 0.9200968199136867, 'gamma': 3.0746161220831243, 'reg_alpha': 0.39262935972567525, 'reg_lambda': 0.004123016241939719}. Best is trial 37 with value: 0.6478913982363623.
# [I 2025-10-24 06:32:01,694] Trial 46 pruned.
# [I 2025-10-24 06:32:02,886] Trial 47 pruned.
# [I 2025-10-24 06:32:04,508] Trial 48 pruned.
# [I 2025-10-24 06:32:06,078] Trial 49 pruned.
# [I 2025-10-24 06:32:06,079] A new study created in memory with name: no-name-7a12b0e6-ffd6-4ba1-aee6-b06ee9744869
# Q2 최적 파라미터: {'lr': 0.007253718909191384, 'n_estimators': 432, 'max_depth': 3, 'subsample': 0.5038814517500667, 'colsample_bytree': 0.8406429214642972, 'gamma': 0.17523222455117982, 'reg_alpha': 1.5438489479832427, 'reg_lambda': 0.001091359355825587}
# Q2 최고 F1 점수: 0.6479
# ==================================================
#
# === target: Q3 ===
# [I 2025-10-24 06:32:08,109] Trial 0 finished with value: 0.6629905416919522 and parameters: {'lr': 0.0008877293109075185, 'n_estimators': 368, 'max_depth': 12, 'subsample': 0.6370953879556039, 'colsample_bytree': 0.796547476177212, 'gamma': 0.0029177876285568093, 'reg_alpha': 0.0010536704045484907, 'reg_lambda': 0.00165288749320443}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:08,991] Trial 1 finished with value: 0.6212131450798064 and parameters: {'lr': 0.024838799220349844, 'n_estimators': 185, 'max_depth': 5, 'subsample': 0.6018454568146132, 'colsample_bytree': 0.7960320839243126, 'gamma': 0.05270272431781748, 'reg_alpha': 2.0795925465995384, 'reg_lambda': 1.6175855423152434}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:12,197] Trial 2 finished with value: 0.6318510949356896 and parameters: {'lr': 0.00951825647822062, 'n_estimators': 259, 'max_depth': 3, 'subsample': 0.8211952990360312, 'colsample_bytree': 0.930451957549183, 'gamma': 0.014504556124569568, 'reg_alpha': 0.0022420945458104516, 'reg_lambda': 3.216780821783824}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:14,046] Trial 3 finished with value: 0.6328915111442317 and parameters: {'lr': 0.0026378047167645528, 'n_estimators': 493, 'max_depth': 6, 'subsample': 0.8710965933189034, 'colsample_bytree': 0.5080765897744288, 'gamma': 1.963189132876209, 'reg_alpha': 0.05399806197642072, 'reg_lambda': 8.38525349548122}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:16,143] Trial 4 finished with value: 0.6234322569962771 and parameters: {'lr': 0.00021429701360467846, 'n_estimators': 414, 'max_depth': 9, 'subsample': 0.6804078138508034, 'colsample_bytree': 0.5580135640765631, 'gamma': 0.023483993505360994, 'reg_alpha': 0.3928277206352211, 'reg_lambda': 0.05065070278050698}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:17,006] Trial 5 pruned.
# [I 2025-10-24 06:32:18,298] Trial 6 pruned.
# [I 2025-10-24 06:32:18,872] Trial 7 finished with value: 0.6424563844693576 and parameters: {'lr': 0.022494084908479373, 'n_estimators': 81, 'max_depth': 12, 'subsample': 0.7203567874829916, 'colsample_bytree': 0.9558464414055832, 'gamma': 0.0330849613595732, 'reg_alpha': 0.0011750843437208127, 'reg_lambda': 2.855284540466916}. Best is trial 0 with value: 0.6629905416919522.
# [I 2025-10-24 06:32:19,806] Trial 8 pruned.
# [I 2025-10-24 06:32:21,206] Trial 9 pruned.
# [I 2025-10-24 06:32:25,447] Trial 10 finished with value: 0.6672289954680015 and parameters: {'lr': 0.0002924705994276602, 'n_estimators': 332, 'max_depth': 11, 'subsample': 0.5236451088661606, 'colsample_bytree': 0.8521852476257035, 'gamma': 0.0011939531400051494, 'reg_alpha': 0.009499346736507, 'reg_lambda': 0.0016746818910006297}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:27,146] Trial 11 finished with value: 0.6631794141066293 and parameters: {'lr': 0.0003929450384786114, 'n_estimators': 327, 'max_depth': 12, 'subsample': 0.5214763851965049, 'colsample_bytree': 0.8569451659073953, 'gamma': 0.001447631620864795, 'reg_alpha': 0.009499767274790722, 'reg_lambda': 0.0012609281910996467}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:28,777] Trial 12 finished with value: 0.644056812752465 and parameters: {'lr': 0.00034664506087863186, 'n_estimators': 306, 'max_depth': 11, 'subsample': 0.5068245036716048, 'colsample_bytree': 0.8774953947784077, 'gamma': 0.0011079896214293596, 'reg_alpha': 0.013897914238490051, 'reg_lambda': 0.0010049870016564798}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:30,438] Trial 13 finished with value: 0.6621402570879289 and parameters: {'lr': 7.807499756354938e-05, 'n_estimators': 309, 'max_depth': 11, 'subsample': 0.532946832406948, 'colsample_bytree': 0.8685034223457678, 'gamma': 0.3475031265715259, 'reg_alpha': 0.009530810869740138, 'reg_lambda': 0.007117955584132177}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:31,776] Trial 14 finished with value: 0.6483593801689971 and parameters: {'lr': 0.0006259279331317965, 'n_estimators': 258, 'max_depth': 12, 'subsample': 0.500705978273781, 'colsample_bytree': 0.8598746783935906, 'gamma': 0.001144246841189173, 'reg_alpha': 0.009801609600675594, 'reg_lambda': 0.36908664356281806}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:33,764] Trial 15 finished with value: 0.6560767482918366 and parameters: {'lr': 1.4025078867214287e-05, 'n_estimators': 370, 'max_depth': 10, 'subsample': 0.5648185099794262, 'colsample_bytree': 0.9814964395332523, 'gamma': 0.31770229355596596, 'reg_alpha': 0.04662912275499807, 'reg_lambda': 0.005720438735794943}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:37,606] Trial 16 finished with value: 0.6652659449254039 and parameters: {'lr': 0.005302727354712121, 'n_estimators': 329, 'max_depth': 7, 'subsample': 0.6694855716374601, 'colsample_bytree': 0.6796731310092174, 'gamma': 0.004493412796655461, 'reg_alpha': 0.004276028936666484, 'reg_lambda': 0.0028765154071306387}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:38,768] Trial 17 pruned.
# [I 2025-10-24 06:32:40,404] Trial 18 pruned.
# [I 2025-10-24 06:32:41,465] Trial 19 pruned.
# [I 2025-10-24 06:32:42,555] Trial 20 pruned.
# [I 2025-10-24 06:32:44,334] Trial 21 pruned.
# [I 2025-10-24 06:32:46,218] Trial 22 pruned.
# [I 2025-10-24 06:32:48,118] Trial 23 finished with value: 0.6639231919852506 and parameters: {'lr': 6.971803210248892e-05, 'n_estimators': 377, 'max_depth': 7, 'subsample': 0.5592870624883803, 'colsample_bytree': 0.7500518621413913, 'gamma': 0.0017749258742499063, 'reg_alpha': 0.0042421916119081944, 'reg_lambda': 0.0036324313137173127}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:52,556] Trial 24 pruned.
# [I 2025-10-24 06:32:53,895] Trial 25 finished with value: 0.6524745297267294 and parameters: {'lr': 7.398925894178792e-05, 'n_estimators': 280, 'max_depth': 6, 'subsample': 0.5708340967996347, 'colsample_bytree': 0.6623525277865769, 'gamma': 0.007267469056035766, 'reg_alpha': 0.002389150735016767, 'reg_lambda': 0.014488233544501029}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:32:55,866] Trial 26 pruned.
# [I 2025-10-24 06:32:57,697] Trial 27 pruned.
# [I 2025-10-24 06:32:59,825] Trial 28 pruned.
# [I 2025-10-24 06:33:04,094] Trial 29 finished with value: 0.6584574016747355 and parameters: {'lr': 0.0008419457921220022, 'n_estimators': 381, 'max_depth': 9, 'subsample': 0.6534901415618073, 'colsample_bytree': 0.5999180521216528, 'gamma': 0.002852152781653505, 'reg_alpha': 0.017692772116182313, 'reg_lambda': 0.009548533482493673}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:33:05,207] Trial 30 pruned.
# [I 2025-10-24 06:33:07,042] Trial 31 pruned.
# [I 2025-10-24 06:33:08,712] Trial 32 finished with value: 0.6640236617701829 and parameters: {'lr': 0.000383704772490968, 'n_estimators': 325, 'max_depth': 11, 'subsample': 0.5173911772632404, 'colsample_bytree': 0.8122213317985657, 'gamma': 0.0039995853113703374, 'reg_alpha': 0.005580354033568389, 'reg_lambda': 0.003549375275122438}. Best is trial 10 with value: 0.6672289954680015.
# [I 2025-10-24 06:33:10,190] Trial 33 pruned.
# [I 2025-10-24 06:33:11,229] Trial 34 pruned.
# [I 2025-10-24 06:33:13,005] Trial 35 pruned.
# [I 2025-10-24 06:33:17,226] Trial 36 pruned.
# [I 2025-10-24 06:33:18,486] Trial 37 pruned.
# [I 2025-10-24 06:33:21,240] Trial 38 pruned.
# [I 2025-10-24 06:33:22,222] Trial 39 pruned.
# [I 2025-10-24 06:33:25,076] Trial 40 pruned.
# [I 2025-10-24 06:33:26,788] Trial 41 finished with value: 0.6689056695325176 and parameters: {'lr': 0.0004404216002912915, 'n_estimators': 324, 'max_depth': 12, 'subsample': 0.5226924038998063, 'colsample_bytree': 0.8331966130714386, 'gamma': 0.0015323702267678312, 'reg_alpha': 0.022735694948487355, 'reg_lambda': 0.0013044544681549623}. Best is trial 41 with value: 0.6689056695325176.
# [I 2025-10-24 06:33:31,079] Trial 42 pruned.
# [I 2025-10-24 06:33:32,635] Trial 43 finished with value: 0.658628180330308 and parameters: {'lr': 0.001294605280636462, 'n_estimators': 300, 'max_depth': 12, 'subsample': 0.5200805046722669, 'colsample_bytree': 0.8387657830007313, 'gamma': 0.0025095959784528126, 'reg_alpha': 0.01584236817732319, 'reg_lambda': 0.0011556527824702152}. Best is trial 41 with value: 0.6689056695325176.
# [I 2025-10-24 06:33:34,633] Trial 44 finished with value: 0.6612696070717154 and parameters: {'lr': 0.0005546666213823965, 'n_estimators': 395, 'max_depth': 10, 'subsample': 0.5927670241985139, 'colsample_bytree': 0.6944293642535033, 'gamma': 0.0014574654515313783, 'reg_alpha': 0.004940957563252112, 'reg_lambda': 0.010761823792043119}. Best is trial 41 with value: 0.6689056695325176.
# [I 2025-10-24 06:33:36,357] Trial 45 finished with value: 0.6612902883891352 and parameters: {'lr': 0.00016842028382147217, 'n_estimators': 325, 'max_depth': 12, 'subsample': 0.5664845971419105, 'colsample_bytree': 0.7874793876391354, 'gamma': 0.010216411275376387, 'reg_alpha': 0.008874034916029975, 'reg_lambda': 0.005328016578569888}. Best is trial 41 with value: 0.6689056695325176.
# [I 2025-10-24 06:33:37,755] Trial 46 pruned.
# [I 2025-10-24 06:33:39,832] Trial 47 pruned.
# [I 2025-10-24 06:33:44,312] Trial 48 pruned.
# [I 2025-10-24 06:33:44,828] Trial 49 pruned.
# [I 2025-10-24 06:33:44,829] A new study created in memory with name: no-name-98423400-abc7-4147-bb45-bfa8a0f67484
# Q3 최적 파라미터: {'lr': 0.0004404216002912915, 'n_estimators': 324, 'max_depth': 12, 'subsample': 0.5226924038998063, 'colsample_bytree': 0.8331966130714386, 'gamma': 0.0015323702267678312, 'reg_alpha': 0.022735694948487355, 'reg_lambda': 0.0013044544681549623}
# Q3 최고 F1 점수: 0.6689
# ==================================================
#
# === target: S2 ===
# [I 2025-10-24 06:33:46,864] Trial 0 finished with value: 0.7205888673973779 and parameters: {'lr': 0.0002410445304180822, 'n_estimators': 121, 'max_depth': 12, 'subsample': 0.6342449389334963, 'colsample_bytree': 0.6364833450977291, 'gamma': 0.12001712197350589, 'reg_alpha': 0.5462207482695721, 'reg_lambda': 0.4615812380119016}. Best is trial 0 with value: 0.7205888673973779.
# [I 2025-10-24 06:33:49,263] Trial 1 finished with value: 0.6932139913004549 and parameters: {'lr': 0.0026438706878197517, 'n_estimators': 304, 'max_depth': 4, 'subsample': 0.9415615245475621, 'colsample_bytree': 0.5058472419283702, 'gamma': 0.015641755954584193, 'reg_alpha': 0.019936632076531482, 'reg_lambda': 0.08891632049178586}. Best is trial 0 with value: 0.7205888673973779.
# [I 2025-10-24 06:33:58,510] Trial 2 finished with value: 0.7327681023533559 and parameters: {'lr': 0.013812471135604795, 'n_estimators': 497, 'max_depth': 9, 'subsample': 0.767585581375442, 'colsample_bytree': 0.7104172481824911, 'gamma': 0.002098388101843748, 'reg_alpha': 0.30187875667699715, 'reg_lambda': 0.0026401899568401655}. Best is trial 2 with value: 0.7327681023533559.
# [I 2025-10-24 06:34:01,170] Trial 3 finished with value: 0.6838628514498706 and parameters: {'lr': 0.0054102479809430525, 'n_estimators': 397, 'max_depth': 3, 'subsample': 0.8448547419342087, 'colsample_bytree': 0.6909268835338744, 'gamma': 0.11929556338654454, 'reg_alpha': 5.730391348424694, 'reg_lambda': 0.8110574019306782}. Best is trial 2 with value: 0.7327681023533559.
# [I 2025-10-24 06:34:05,920] Trial 4 finished with value: 0.6948466609380854 and parameters: {'lr': 0.0003763307429373879, 'n_estimators': 425, 'max_depth': 5, 'subsample': 0.9627009592035805, 'colsample_bytree': 0.6628128708562286, 'gamma': 0.12255702138895891, 'reg_alpha': 0.0015409017184722462, 'reg_lambda': 0.008800614602204899}. Best is trial 2 with value: 0.7327681023533559.
# [I 2025-10-24 06:34:22,730] Trial 5 finished with value: 0.7144985143344659 and parameters: {'lr': 2.4421904568013852e-05, 'n_estimators': 496, 'max_depth': 11, 'subsample': 0.9372788152504132, 'colsample_bytree': 0.8376176193627141, 'gamma': 2.0327731822444037, 'reg_alpha': 0.0030864847979348194, 'reg_lambda': 0.08781879136571198}. Best is trial 2 with value: 0.7327681023533559.
# [I 2025-10-24 06:34:23,997] Trial 6 pruned.
# [I 2025-10-24 06:34:26,353] Trial 7 finished with value: 0.7134758140611251 and parameters: {'lr': 1.0468858822828675e-05, 'n_estimators': 149, 'max_depth': 6, 'subsample': 0.8685428593807392, 'colsample_bytree': 0.7030503098760466, 'gamma': 0.005719661612011041, 'reg_alpha': 0.04174278238895199, 'reg_lambda': 1.6451567635987265}. Best is trial 2 with value: 0.7327681023533559.
# [I 2025-10-24 06:34:27,776] Trial 8 pruned.
# [I 2025-10-24 06:34:29,849] Trial 9 pruned.
# [I 2025-10-24 06:34:35,810] Trial 10 finished with value: 0.7328961978693292 and parameters: {'lr': 0.030180249310867425, 'n_estimators': 214, 'max_depth': 9, 'subsample': 0.7619082473440093, 'colsample_bytree': 0.8082711177415909, 'gamma': 0.0011400401922353057, 'reg_alpha': 0.7802732205229752, 'reg_lambda': 0.0011749005446589904}. Best is trial 10 with value: 0.7328961978693292.
# [I 2025-10-24 06:34:39,145] Trial 11 finished with value: 0.7230609541748297 and parameters: {'lr': 0.03804855624690538, 'n_estimators': 220, 'max_depth': 9, 'subsample': 0.7647729843398535, 'colsample_bytree': 0.8080512494965159, 'gamma': 0.0010844336017799068, 'reg_alpha': 1.103975250155529, 'reg_lambda': 0.0010727668003180195}. Best is trial 10 with value: 0.7328961978693292.
# [I 2025-10-24 06:34:42,725] Trial 12 finished with value: 0.7326018090611053 and parameters: {'lr': 0.010012311076603879, 'n_estimators': 201, 'max_depth': 9, 'subsample': 0.5179679020547988, 'colsample_bytree': 0.9255699112948098, 'gamma': 0.001007428124761882, 'reg_alpha': 1.685778795978979, 'reg_lambda': 0.0010473677159017457}. Best is trial 10 with value: 0.7328961978693292.
# [I 2025-10-24 06:34:49,918] Trial 13 finished with value: 0.7298123806018544 and parameters: {'lr': 0.023147385329501165, 'n_estimators': 360, 'max_depth': 8, 'subsample': 0.7916107589156145, 'colsample_bytree': 0.7558649237229536, 'gamma': 0.0038429423281397122, 'reg_alpha': 0.40196129488048216, 'reg_lambda': 0.003216748500563294}. Best is trial 10 with value: 0.7328961978693292.
# [I 2025-10-24 06:34:53,876] Trial 14 finished with value: 0.733176436547223 and parameters: {'lr': 0.015983309748865453, 'n_estimators': 231, 'max_depth': 10, 'subsample': 0.7069753399486137, 'colsample_bytree': 0.7734693969477552, 'gamma': 0.00359693418183015, 'reg_alpha': 0.050584048856889066, 'reg_lambda': 0.0028779272037673174}. Best is trial 14 with value: 0.733176436547223.
# [I 2025-10-24 06:34:56,825] Trial 15 finished with value: 0.7263686790322605 and parameters: {'lr': 0.076036560433746, 'n_estimators': 218, 'max_depth': 10, 'subsample': 0.6931803017978985, 'colsample_bytree': 0.7769098093847826, 'gamma': 0.007206356709297089, 'reg_alpha': 0.008746507898566938, 'reg_lambda': 8.82419683791564}. Best is trial 14 with value: 0.733176436547223.
# [I 2025-10-24 06:35:03,840] Trial 16 pruned.
# [I 2025-10-24 06:35:04,901] Trial 17 pruned.
# [I 2025-10-24 06:35:10,074] Trial 18 finished with value: 0.7245794102667216 and parameters: {'lr': 0.001453599427502469, 'n_estimators': 173, 'max_depth': 7, 'subsample': 0.5836761243487698, 'colsample_bytree': 0.9859018979980683, 'gamma': 0.04080136048981122, 'reg_alpha': 0.023257240927633722, 'reg_lambda': 0.0021321902234032928}. Best is trial 14 with value: 0.733176436547223.
# [I 2025-10-24 06:35:16,994] Trial 19 finished with value: 0.7348328618990146 and parameters: {'lr': 0.03168843848345176, 'n_estimators': 260, 'max_depth': 11, 'subsample': 0.8313920319271536, 'colsample_bytree': 0.8012112497483911, 'gamma': 0.002830695670329136, 'reg_alpha': 0.007801067346970639, 'reg_lambda': 0.19136789041059127}. Best is trial 19 with value: 0.7348328618990146.
# [I 2025-10-24 06:35:22,131] Trial 20 finished with value: 0.7305296936740235 and parameters: {'lr': 0.008529731955437108, 'n_estimators': 268, 'max_depth': 11, 'subsample': 0.88362271368068, 'colsample_bytree': 0.6211025785905132, 'gamma': 0.009206343688490512, 'reg_alpha': 0.005819978150328219, 'reg_lambda': 0.2340266986010668}. Best is trial 19 with value: 0.7348328618990146.
# [I 2025-10-24 06:35:28,822] Trial 21 pruned.
# [I 2025-10-24 06:35:32,841] Trial 22 finished with value: 0.7348866213151927 and parameters: {'lr': 0.02085458654435706, 'n_estimators': 245, 'max_depth': 11, 'subsample': 0.720569870907701, 'colsample_bytree': 0.7379090475645086, 'gamma': 0.001992844545882047, 'reg_alpha': 0.07471737864229025, 'reg_lambda': 0.21220733101915448}. Best is trial 22 with value: 0.7348866213151927.
# [I 2025-10-24 06:35:37,371] Trial 23 finished with value: 0.7299558583152342 and parameters: {'lr': 0.013640899222891974, 'n_estimators': 254, 'max_depth': 11, 'subsample': 0.7204205602523371, 'colsample_bytree': 0.7374854329168219, 'gamma': 0.0028804788868985126, 'reg_alpha': 0.08718077888994248, 'reg_lambda': 0.279228334429675}. Best is trial 22 with value: 0.7348866213151927.
# [I 2025-10-24 06:35:42,978] Trial 24 finished with value: 0.7410836324021732 and parameters: {'lr': 0.09877925386802186, 'n_estimators': 333, 'max_depth': 12, 'subsample': 0.8092652654651314, 'colsample_bytree': 0.7416712760837048, 'gamma': 0.009822954677625425, 'reg_alpha': 0.04384113481402127, 'reg_lambda': 2.253284141419141}. Best is trial 24 with value: 0.7410836324021732.
# [I 2025-10-24 06:35:46,705] Trial 25 finished with value: 0.7351095306398916 and parameters: {'lr': 0.0748674746995094, 'n_estimators': 349, 'max_depth': 12, 'subsample': 0.8116135916497924, 'colsample_bytree': 0.7479513945814479, 'gamma': 0.05335556296274239, 'reg_alpha': 0.020489408420179926, 'reg_lambda': 3.0832213290836883}. Best is trial 24 with value: 0.7410836324021732.
# [I 2025-10-24 06:35:51,631] Trial 26 finished with value: 0.7426264724806255 and parameters: {'lr': 0.08141899397859692, 'n_estimators': 358, 'max_depth': 12, 'subsample': 0.8902139848698751, 'colsample_bytree': 0.7376298425043428, 'gamma': 0.05144651343478961, 'reg_alpha': 0.02428925611434765, 'reg_lambda': 4.7756771029000245}. Best is trial 26 with value: 0.7426264724806255.
# [I 2025-10-24 06:35:56,979] Trial 27 finished with value: 0.7430791457290219 and parameters: {'lr': 0.09932711043486042, 'n_estimators': 356, 'max_depth': 12, 'subsample': 0.8979683048845699, 'colsample_bytree': 0.617810414168815, 'gamma': 0.05049975544217836, 'reg_alpha': 0.021404994933020796, 'reg_lambda': 6.450520947265888}. Best is trial 27 with value: 0.7430791457290219.
# [I 2025-10-24 06:36:00,266] Trial 28 pruned.
# [I 2025-10-24 06:36:11,806] Trial 29 pruned.
# [I 2025-10-24 06:36:14,436] Trial 30 pruned.
# [I 2025-10-24 06:36:20,790] Trial 31 finished with value: 0.736997142246298 and parameters: {'lr': 0.05912640717505934, 'n_estimators': 352, 'max_depth': 12, 'subsample': 0.80567287388984, 'colsample_bytree': 0.6785839552420132, 'gamma': 0.06393982195387558, 'reg_alpha': 0.013444701938744443, 'reg_lambda': 3.6237341458045447}. Best is trial 27 with value: 0.7430791457290219.
# [I 2025-10-24 06:36:24,968] Trial 32 finished with value: 0.740856826017453 and parameters: {'lr': 0.047748140670461826, 'n_estimators': 365, 'max_depth': 12, 'subsample': 0.8549626436147877, 'colsample_bytree': 0.5000123833583152, 'gamma': 0.013623649570884768, 'reg_alpha': 0.014151415439497318, 'reg_lambda': 4.268961677518831}. Best is trial 27 with value: 0.7430791457290219.
# [I 2025-10-24 06:36:29,364] Trial 33 finished with value: 0.7417177319115916 and parameters: {'lr': 0.04638220227321729, 'n_estimators': 382, 'max_depth': 11, 'subsample': 0.8626418701950261, 'colsample_bytree': 0.5060069375767655, 'gamma': 0.010323524625342225, 'reg_alpha': 0.015132681805957423, 'reg_lambda': 5.7601406354028475}. Best is trial 27 with value: 0.7430791457290219.
# [I 2025-10-24 06:36:34,807] Trial 34 pruned.
# [I 2025-10-24 06:36:40,027] Trial 35 pruned.
# [I 2025-10-24 06:36:50,060] Trial 36 pruned.
# [I 2025-10-24 06:36:53,975] Trial 37 finished with value: 0.7488587128362048 and parameters: {'lr': 0.04614071108938825, 'n_estimators': 450, 'max_depth': 8, 'subsample': 0.9421204688567754, 'colsample_bytree': 0.5304800114088037, 'gamma': 0.016060080731164703, 'reg_alpha': 0.1362755293398884, 'reg_lambda': 0.7591868489598357}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:01,223] Trial 38 pruned.
# [I 2025-10-24 06:37:06,250] Trial 39 finished with value: 0.7344788087056129 and parameters: {'lr': 0.018553889211821162, 'n_estimators': 466, 'max_depth': 8, 'subsample': 0.9577837622755399, 'colsample_bytree': 0.5226583611615591, 'gamma': 0.20993603136648348, 'reg_alpha': 0.2358435618645846, 'reg_lambda': 0.4588474245043528}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:13,503] Trial 40 pruned.
# [I 2025-10-24 06:37:16,540] Trial 41 finished with value: 0.7364506014521547 and parameters: {'lr': 0.09985649630699092, 'n_estimators': 379, 'max_depth': 12, 'subsample': 0.8553589147938168, 'colsample_bytree': 0.6639843753986214, 'gamma': 0.03222152409871682, 'reg_alpha': 0.030975810361703233, 'reg_lambda': 2.6712485992053465}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:19,444] Trial 42 finished with value: 0.742735277472619 and parameters: {'lr': 0.054999648463251165, 'n_estimators': 318, 'max_depth': 11, 'subsample': 0.9190221456210136, 'colsample_bytree': 0.5195531069446335, 'gamma': 0.015695362544163125, 'reg_alpha': 0.05577805123877182, 'reg_lambda': 0.5793239235821093}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:25,658] Trial 43 finished with value: 0.7436224372284471 and parameters: {'lr': 0.0491912782453154, 'n_estimators': 438, 'max_depth': 9, 'subsample': 0.9302083796624306, 'colsample_bytree': 0.5235909512071759, 'gamma': 0.013956866286993828, 'reg_alpha': 0.15554066928793367, 'reg_lambda': 0.5361314057136252}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:32,754] Trial 44 finished with value: 0.7428982243415233 and parameters: {'lr': 0.009031309355777634, 'n_estimators': 495, 'max_depth': 8, 'subsample': 0.9269993160574836, 'colsample_bytree': 0.5568733256639353, 'gamma': 0.015798962705654666, 'reg_alpha': 0.5322750541652544, 'reg_lambda': 0.7031335085507722}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:42,427] Trial 45 finished with value: 0.7460812512069317 and parameters: {'lr': 0.011161308174069188, 'n_estimators': 497, 'max_depth': 8, 'subsample': 0.931456939186876, 'colsample_bytree': 0.5660932230103777, 'gamma': 0.018254796402337323, 'reg_alpha': 0.5312882649254593, 'reg_lambda': 0.5602758886406785}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:51,991] Trial 46 finished with value: 0.744052710893096 and parameters: {'lr': 0.010589615540426542, 'n_estimators': 497, 'max_depth': 8, 'subsample': 0.9680070356541562, 'colsample_bytree': 0.5605260907258618, 'gamma': 0.004902614581386444, 'reg_alpha': 0.5445370640706108, 'reg_lambda': 0.1212573949805959}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:37:58,393] Trial 47 finished with value: 0.740433088344103 and parameters: {'lr': 0.01328136723529828, 'n_estimators': 480, 'max_depth': 7, 'subsample': 0.9719618576868866, 'colsample_bytree': 0.6149182012718312, 'gamma': 0.004896063580634167, 'reg_alpha': 0.3403930176798838, 'reg_lambda': 0.09840804079307419}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:38:09,137] Trial 48 pruned.
# [I 2025-10-24 06:38:16,318] Trial 49 finished with value: 0.7404245328159439 and parameters: {'lr': 0.023459326381612758, 'n_estimators': 499, 'max_depth': 8, 'subsample': 0.940503110356227, 'colsample_bytree': 0.591023879801251, 'gamma': 0.03663066496928719, 'reg_alpha': 1.6743879658888858, 'reg_lambda': 0.14942023132815896}. Best is trial 37 with value: 0.7488587128362048.
# [I 2025-10-24 06:38:16,319] A new study created in memory with name: no-name-8bb2f2ce-4ef3-4568-bb93-2b0ad20ee3e8
# S2 최적 파라미터: {'lr': 0.04614071108938825, 'n_estimators': 450, 'max_depth': 8, 'subsample': 0.9421204688567754, 'colsample_bytree': 0.5304800114088037, 'gamma': 0.016060080731164703, 'reg_alpha': 0.1362755293398884, 'reg_lambda': 0.7591868489598357}
# S2 최고 F1 점수: 0.7489
# ==================================================
#
# === target: S3 ===
# [I 2025-10-24 06:38:18,165] Trial 0 finished with value: 0.7052602753881526 and parameters: {'lr': 9.805567061846455e-05, 'n_estimators': 136, 'max_depth': 6, 'subsample': 0.8141797896619805, 'colsample_bytree': 0.5417581648233354, 'gamma': 0.0040033576686604525, 'reg_alpha': 7.870409830608495, 'reg_lambda': 0.7208497333798164}. Best is trial 0 with value: 0.7052602753881526.
# [I 2025-10-24 06:38:22,749] Trial 1 finished with value: 0.7449329205366356 and parameters: {'lr': 1.0692275192049048e-05, 'n_estimators': 220, 'max_depth': 8, 'subsample': 0.6747293562596282, 'colsample_bytree': 0.8897429874136478, 'gamma': 0.0222258209058594, 'reg_alpha': 0.005702566816762267, 'reg_lambda': 0.001586406296534713}. Best is trial 1 with value: 0.7449329205366356.
# [I 2025-10-24 06:38:25,302] Trial 2 finished with value: 0.6865963804873831 and parameters: {'lr': 2.0987372486824175e-05, 'n_estimators': 408, 'max_depth': 6, 'subsample': 0.5860427874824861, 'colsample_bytree': 0.6253011330443927, 'gamma': 6.868014758891523, 'reg_alpha': 3.7268870246303596, 'reg_lambda': 1.3789689277965556}. Best is trial 1 with value: 0.7449329205366356.
# [I 2025-10-24 06:38:30,894] Trial 3 finished with value: 0.7481870360040377 and parameters: {'lr': 0.0010525683270818306, 'n_estimators': 157, 'max_depth': 9, 'subsample': 0.7088198599221048, 'colsample_bytree': 0.8146409758516597, 'gamma': 0.3944287362630393, 'reg_alpha': 0.43212047076341215, 'reg_lambda': 0.0010204809238372478}. Best is trial 3 with value: 0.7481870360040377.
# [I 2025-10-24 06:38:35,722] Trial 4 finished with value: 0.7631092712005498 and parameters: {'lr': 0.0745593004919745, 'n_estimators': 498, 'max_depth': 6, 'subsample': 0.5571794469506122, 'colsample_bytree': 0.8049048970085451, 'gamma': 0.0029854466591996533, 'reg_alpha': 0.037336538890851166, 'reg_lambda': 6.635983985852138}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:38:38,642] Trial 5 pruned.
# [I 2025-10-24 06:38:39,941] Trial 6 pruned.
# [I 2025-10-24 06:38:46,317] Trial 7 finished with value: 0.7517426545086119 and parameters: {'lr': 0.00678395140746924, 'n_estimators': 320, 'max_depth': 5, 'subsample': 0.7361017135606602, 'colsample_bytree': 0.8551816798658932, 'gamma': 0.013446224312846453, 'reg_alpha': 0.39227950472236583, 'reg_lambda': 0.03371622446270789}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:38:49,176] Trial 8 finished with value: 0.7599184688132765 and parameters: {'lr': 0.014286117922736053, 'n_estimators': 155, 'max_depth': 8, 'subsample': 0.6304978325929795, 'colsample_bytree': 0.8143548685794032, 'gamma': 0.00549152204525896, 'reg_alpha': 0.057664002251816456, 'reg_lambda': 0.0530371181022227}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:38:58,820] Trial 9 finished with value: 0.7558541022854744 and parameters: {'lr': 5.5040344087838735e-05, 'n_estimators': 425, 'max_depth': 11, 'subsample': 0.8565547770896124, 'colsample_bytree': 0.545505241716945, 'gamma': 0.7034044670741898, 'reg_alpha': 0.004458145486063104, 'reg_lambda': 0.0025461403262972853}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:39:02,511] Trial 10 pruned.
# [I 2025-10-24 06:39:03,445] Trial 11 pruned.
# [I 2025-10-24 06:39:05,969] Trial 12 finished with value: 0.7502567212451992 and parameters: {'lr': 0.024197359537713094, 'n_estimators': 309, 'max_depth': 4, 'subsample': 0.6192842980012117, 'colsample_bytree': 0.7592169863604752, 'gamma': 0.0012659045552642905, 'reg_alpha': 0.05739690313525104, 'reg_lambda': 0.40612984682455}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:39:09,729] Trial 13 pruned.
# [I 2025-10-24 06:39:19,012] Trial 14 finished with value: 0.7569911664254925 and parameters: {'lr': 0.0032422680995262865, 'n_estimators': 500, 'max_depth': 10, 'subsample': 0.6321347656336819, 'colsample_bytree': 0.7534462741844329, 'gamma': 0.0035624612843409955, 'reg_alpha': 0.017411690760695705, 'reg_lambda': 0.021561422278308862}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:39:24,261] Trial 15 pruned.
# [I 2025-10-24 06:39:28,537] Trial 16 pruned.
# [I 2025-10-24 06:39:32,141] Trial 17 finished with value: 0.7550539478521805 and parameters: {'lr': 0.04740362478414164, 'n_estimators': 276, 'max_depth': 7, 'subsample': 0.6320891658878098, 'colsample_bytree': 0.9029812291656988, 'gamma': 0.0011700837385717987, 'reg_alpha': 1.4637536184186575, 'reg_lambda': 0.007908437703266874}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:39:40,696] Trial 18 pruned.
# [I 2025-10-24 06:39:42,113] Trial 19 pruned.
# [I 2025-10-24 06:39:53,832] Trial 20 pruned.
# [I 2025-10-24 06:40:05,633] Trial 21 finished with value: 0.7528244997588258 and parameters: {'lr': 0.0028617468706328164, 'n_estimators': 474, 'max_depth': 10, 'subsample': 0.6297356236217883, 'colsample_bytree': 0.7768605415476785, 'gamma': 0.0033141275980673878, 'reg_alpha': 0.029739298458477503, 'reg_lambda': 0.016821647270606595}. Best is trial 4 with value: 0.7631092712005498.
# [I 2025-10-24 06:40:17,280] Trial 22 finished with value: 0.7648180198545309 and parameters: {'lr': 0.0020760891608048683, 'n_estimators': 465, 'max_depth': 11, 'subsample': 0.6763670646201911, 'colsample_bytree': 0.7129825955543805, 'gamma': 0.002491652513169936, 'reg_alpha': 0.010094081014090846, 'reg_lambda': 0.02831915891392152}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:40:28,710] Trial 23 pruned.
# [I 2025-10-24 06:40:32,605] Trial 24 pruned.
# [I 2025-10-24 06:40:42,502] Trial 25 finished with value: 0.7546292874364253 and parameters: {'lr': 0.0014435003618557287, 'n_estimators': 455, 'max_depth': 7, 'subsample': 0.5984835738136735, 'colsample_bytree': 0.788959201398454, 'gamma': 0.016562051327805777, 'reg_alpha': 0.0015798553784253575, 'reg_lambda': 0.014542576637422987}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:40:46,977] Trial 26 pruned.
# [I 2025-10-24 06:40:52,902] Trial 27 pruned.
# [I 2025-10-24 06:40:58,900] Trial 28 pruned.
# [I 2025-10-24 06:41:00,672] Trial 29 pruned.
# [I 2025-10-24 06:41:01,906] Trial 30 pruned.
# [I 2025-10-24 06:41:13,966] Trial 31 finished with value: 0.7605021140675069 and parameters: {'lr': 0.0030075242699719048, 'n_estimators': 492, 'max_depth': 10, 'subsample': 0.6431183779885948, 'colsample_bytree': 0.7675176939203152, 'gamma': 0.002137217638892479, 'reg_alpha': 0.014420636870241428, 'reg_lambda': 0.015667663163375607}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:41:25,881] Trial 32 pruned.
# [I 2025-10-24 06:41:34,213] Trial 33 pruned.
# [I 2025-10-24 06:41:38,620] Trial 34 pruned.
# [I 2025-10-24 06:41:48,028] Trial 35 finished with value: 0.7607882745948429 and parameters: {'lr': 0.0020550930587052976, 'n_estimators': 444, 'max_depth': 10, 'subsample': 0.5756184885246238, 'colsample_bytree': 0.5847698003868349, 'gamma': 0.016355388961143018, 'reg_alpha': 0.10716649595605218, 'reg_lambda': 0.0031878521419463515}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:41:55,130] Trial 36 pruned.
# [I 2025-10-24 06:42:04,036] Trial 37 finished with value: 0.7595875522619916 and parameters: {'lr': 0.00017662315738732238, 'n_estimators': 401, 'max_depth': 9, 'subsample': 0.5840879752752307, 'colsample_bytree': 0.6422358922624232, 'gamma': 0.02876483076860906, 'reg_alpha': 0.036180642938135596, 'reg_lambda': 0.003635033551102262}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:42:13,267] Trial 38 pruned.
# [I 2025-10-24 06:42:19,699] Trial 39 pruned.
# [I 2025-10-24 06:42:29,734] Trial 40 pruned.
# [I 2025-10-24 06:42:40,308] Trial 41 finished with value: 0.7630503144654088 and parameters: {'lr': 0.007187251672568885, 'n_estimators': 480, 'max_depth': 8, 'subsample': 0.726201972144292, 'colsample_bytree': 0.7720057179277915, 'gamma': 0.00616359048328783, 'reg_alpha': 0.0941050470726651, 'reg_lambda': 0.03881489364284174}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:42:51,737] Trial 42 finished with value: 0.7622735873867054 and parameters: {'lr': 0.002825694256840455, 'n_estimators': 482, 'max_depth': 8, 'subsample': 0.7223937193042936, 'colsample_bytree': 0.8702804448257118, 'gamma': 0.0018833293055475625, 'reg_alpha': 0.10780142461229429, 'reg_lambda': 0.11603302258102283}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:43:01,165] Trial 43 finished with value: 0.7562921023752858 and parameters: {'lr': 0.005848935986608314, 'n_estimators': 473, 'max_depth': 8, 'subsample': 0.8152352989337499, 'colsample_bytree': 0.8759173532358362, 'gamma': 0.0065257275537926466, 'reg_alpha': 0.09013818725002647, 'reg_lambda': 0.1536127205796795}. Best is trial 22 with value: 0.7648180198545309.
# [I 2025-10-24 06:43:11,361] Trial 44 pruned.
# [I 2025-10-24 06:43:21,084] Trial 45 pruned.
# [I 2025-10-24 06:43:30,428] Trial 46 pruned.
# [I 2025-10-24 06:43:36,014] Trial 47 pruned.
# [I 2025-10-24 06:43:46,307] Trial 48 pruned.
# [I 2025-10-24 06:43:50,714] Trial 49 pruned.
# S3 최적 파라미터: {'lr': 0.0020760891608048683, 'n_estimators': 465, 'max_depth': 11, 'subsample': 0.6763670646201911, 'colsample_bytree': 0.7129825955543805, 'gamma': 0.002491652513169936, 'reg_alpha': 0.010094081014090846, 'reg_lambda': 0.02831915891392152}
# S3 최고 F1 점수: 0.7648
# ==================================================

# %%
def smote_optuna_multi(split_date):
  for col in target_multi:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]

    def objective_multi(trial):
      params = {'learning_rate': trial.suggest_float("lr", 1e-5, 1e-1, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 1e-3, 10.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'random_state': seed,
        'n_jobs': -1,
        'verbosity': 2,
        'objective': 'multiclass',
        'num_class': 3
                }
      feat = features[col]

      clf_binary = XGBClassifier(**params)
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='not majority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score_macro = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='f1_macro').mean()

      trial.report(score_macro, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score_macro

    study = optuna.create_study(direction="maximize")
    study.optimize(objective_multi, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    xgb_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_multi(split_data)
# Out:
# [I 2025-10-24 06:43:50,729] A new study created in memory with name: no-name-3e1ef533-c877-44de-94dd-6a78eeb3f6b5
# === target: S1 ===
# [06:43:50] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:44:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:44:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:44:23] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:44:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:44:42,503] Trial 0 finished with value: 0.40399263673863217 and parameters: {'lr': 0.00014281940155395315, 'n_estimators': 497, 'max_depth': 4, 'subsample': 0.8956681962941607, 'colsample_bytree': 0.8451898752107849, 'gamma': 1.0874641407119445, 'reg_alpha': 0.01805025184202124, 'reg_lambda': 5.75608892161817}. Best is trial 0 with value: 0.40399263673863217.
# [06:44:42] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:44:50] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:44:56] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:45:05] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:45:11] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:45:19,733] Trial 1 finished with value: 0.40855220855681773 and parameters: {'lr': 0.0030425238224273494, 'n_estimators': 282, 'max_depth': 5, 'subsample': 0.8170044955249266, 'colsample_bytree': 0.6934582011355332, 'gamma': 0.18463023843735232, 'reg_alpha': 0.01723084519183287, 'reg_lambda': 3.737452869410432}. Best is trial 1 with value: 0.40855220855681773.
# [06:45:19] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:45:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:45:41] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:45:50] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:46:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:46:12,861] Trial 2 finished with value: 0.4345088936755963 and parameters: {'lr': 0.000973387269552397, 'n_estimators': 349, 'max_depth': 11, 'subsample': 0.828358403539935, 'colsample_bytree': 0.5413167229163132, 'gamma': 0.1423720689247687, 'reg_alpha': 6.3383068489284, 'reg_lambda': 0.0024198436279509127}. Best is trial 2 with value: 0.4345088936755963.
# [06:46:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:46:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:46:21] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:46:24] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:46:27] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:46:29,788] Trial 3 finished with value: 0.42166169409227033 and parameters: {'lr': 0.0015325540734799467, 'n_estimators': 174, 'max_depth': 6, 'subsample': 0.9010737473752246, 'colsample_bytree': 0.8004957483594911, 'gamma': 7.087785115496811, 'reg_alpha': 0.014010659212553796, 'reg_lambda': 0.002229610626367877}. Best is trial 2 with value: 0.4345088936755963.
# [06:46:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:46:46] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:47:00] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:47:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:47:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:47:45,013] Trial 4 finished with value: 0.4412346171766114 and parameters: {'lr': 0.0030945877119748786, 'n_estimators': 334, 'max_depth': 11, 'subsample': 0.5331006231093145, 'colsample_bytree': 0.9312305076112499, 'gamma': 0.027678070607010517, 'reg_alpha': 0.013777644309204242, 'reg_lambda': 0.011198242583174664}. Best is trial 4 with value: 0.4412346171766114.
# [06:47:45] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:47:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:48:05] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:21] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:48:31,231] Trial 5 finished with value: 0.4422522632008718 and parameters: {'lr': 0.016822994253461912, 'n_estimators': 458, 'max_depth': 11, 'subsample': 0.9403321660962451, 'colsample_bytree': 0.8614799387378269, 'gamma': 1.0189215040517856, 'reg_alpha': 0.3646495022496935, 'reg_lambda': 4.784078068897332}. Best is trial 5 with value: 0.4422522632008718.
# [06:48:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:34] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:48:36] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:39] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:44] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:48:47,385] Trial 6 finished with value: 0.45535368009702204 and parameters: {'lr': 0.019690645838653882, 'n_estimators': 83, 'max_depth': 9, 'subsample': 0.6085034564361231, 'colsample_bytree': 0.6851814994506682, 'gamma': 0.0014058814360278238, 'reg_alpha': 0.0022597747975200266, 'reg_lambda': 1.9413575806725996}. Best is trial 6 with value: 0.45535368009702204.
# [06:48:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:48:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:49:07] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:49:17] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:49:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:49:40,334] Trial 7 finished with value: 0.4376775085172146 and parameters: {'lr': 0.0037496604348903565, 'n_estimators': 282, 'max_depth': 8, 'subsample': 0.6763609816423746, 'colsample_bytree': 0.6199011154095346, 'gamma': 0.041350272878244616, 'reg_alpha': 0.04152953800493051, 'reg_lambda': 0.3060010965743098}. Best is trial 6 with value: 0.45535368009702204.
# [06:49:40] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:49:45] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:49:53] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:49:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:06] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:50:13,340] Trial 8 finished with value: 0.45023299271919665 and parameters: {'lr': 2.1087303832515604e-05, 'n_estimators': 179, 'max_depth': 6, 'subsample': 0.5470547050405088, 'colsample_bytree': 0.91409009131873, 'gamma': 0.029774760465326185, 'reg_alpha': 0.0012199013737736934, 'reg_lambda': 7.813234619425836}. Best is trial 6 with value: 0.45535368009702204.
# [06:50:13] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:20] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:50:28] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:33] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:41] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:50:47,518] Trial 9 pruned.
# [06:50:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:49] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:50:51] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:56] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:50:58,024] Trial 10 finished with value: 0.45623968794700503 and parameters: {'lr': 0.08859185318842767, 'n_estimators': 51, 'max_depth': 9, 'subsample': 0.658732262891285, 'colsample_bytree': 0.7064685420279516, 'gamma': 0.0011877283608786608, 'reg_alpha': 0.42286031491427334, 'reg_lambda': 0.0423429849605506}. Best is trial 10 with value: 0.45623968794700503.
# [06:50:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:50:59] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:51:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:07] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:51:09,190] Trial 11 finished with value: 0.44579903178367264 and parameters: {'lr': 0.08153763482393175, 'n_estimators': 53, 'max_depth': 9, 'subsample': 0.6747033959887813, 'colsample_bytree': 0.7182939855514965, 'gamma': 0.0011885253257329308, 'reg_alpha': 0.27672779526018526, 'reg_lambda': 0.03616036742305682}. Best is trial 10 with value: 0.45623968794700503.
# [06:51:09] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:10] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:51:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:13] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:51:16,867] Trial 12 finished with value: 0.4424291192237077 and parameters: {'lr': 0.08493356845302691, 'n_estimators': 53, 'max_depth': 9, 'subsample': 0.6444726908695082, 'colsample_bytree': 0.6483106727860879, 'gamma': 0.00508233210688347, 'reg_alpha': 2.0297577186003184, 'reg_lambda': 0.7755832362510479}. Best is trial 10 with value: 0.45623968794700503.
# [06:51:16] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:23] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:51:28] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:34] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:39] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:51:46,222] Trial 13 finished with value: 0.46460401637957405 and parameters: {'lr': 0.022133791393320813, 'n_estimators': 139, 'max_depth': 8, 'subsample': 0.6138092569019429, 'colsample_bytree': 0.7681144934060891, 'gamma': 0.006299982727169865, 'reg_alpha': 0.24633071717464936, 'reg_lambda': 0.07069000899913704}. Best is trial 13 with value: 0.46460401637957405.
# [06:51:46] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:51:51] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:51:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:04] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:52:17,563] Trial 14 pruned.
# [06:52:17] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:21] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:52:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:33] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:39] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:52:43,203] Trial 15 pruned.
# [06:52:43] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:45] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:52:48] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:53] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:52:55] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:52:58,552] Trial 16 pruned.
# [06:52:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:04] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:53:08] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:11] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:17] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:53:21,506] Trial 17 pruned.
# [06:53:21] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:24] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:53:26] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:32] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:34] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:53:37,699] Trial 18 pruned.
# [06:53:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:43] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:53:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:51] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:53:57] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:54:00,645] Trial 19 pruned.
# [06:54:00] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:54:06] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:11] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:14] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:54:16,888] Trial 20 pruned.
# [06:54:16] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:19] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:54:23] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:26] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:28] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:54:30,606] Trial 21 pruned.
# [06:54:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:36] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:54:40] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:43] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:49] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:54:53,001] Trial 22 pruned.
# [06:54:53] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:54:56] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:55:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:04] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:08] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:55:11,112] Trial 23 pruned.
# [06:55:11] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:18] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:55:23] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:36] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:55:44,053] Trial 24 finished with value: 0.46428418070464694 and parameters: {'lr': 0.029457203900776767, 'n_estimators': 219, 'max_depth': 9, 'subsample': 0.5046660627372277, 'colsample_bytree': 0.717950705320649, 'gamma': 0.007663229298155008, 'reg_alpha': 0.23690001536221472, 'reg_lambda': 0.2599161718726468}. Best is trial 13 with value: 0.46460401637957405.
# [06:55:44] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:48] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:55:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:55:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:56:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:56:09,961] Trial 25 finished with value: 0.4427941492790407 and parameters: {'lr': 0.04379975308350594, 'n_estimators': 213, 'max_depth': 7, 'subsample': 0.5057819374541411, 'colsample_bytree': 0.7251361075524536, 'gamma': 0.0072077104323396155, 'reg_alpha': 0.203942588931663, 'reg_lambda': 0.21215817066703085}. Best is trial 13 with value: 0.46460401637957405.
# [06:56:10] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:56:18] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:56:26] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:56:36] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:56:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:56:55,447] Trial 26 pruned.
# [06:56:55] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:02] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:57:07] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:14] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:19] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:57:26,275] Trial 27 finished with value: 0.4540102975824979 and parameters: {'lr': 0.027915868510955608, 'n_estimators': 147, 'max_depth': 10, 'subsample': 0.5663929835538588, 'colsample_bytree': 0.8856543358386744, 'gamma': 0.002838846817584386, 'reg_alpha': 0.6932812963917486, 'reg_lambda': 0.023246820151562375}. Best is trial 13 with value: 0.46460401637957405.
# [06:57:26] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:57:39] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:44] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:57:51] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:57:56,993] Trial 28 pruned.
# [06:57:57] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:58:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:58:34] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:58:52] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:59:13] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:59:31,225] Trial 29 pruned.
# [06:59:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:59:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [06:59:41] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:59:44] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:59:51] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 06:59:54,764] Trial 30 finished with value: 0.4449438711852138 and parameters: {'lr': 0.005776956228611499, 'n_estimators': 243, 'max_depth': 4, 'subsample': 0.7806807671020184, 'colsample_bytree': 0.7467201738554423, 'gamma': 0.08153168638655209, 'reg_alpha': 0.03457955712419432, 'reg_lambda': 0.04405797755470329}. Best is trial 13 with value: 0.46460401637957405.
# [06:59:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [06:59:57] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:00:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:06] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:09] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:00:14,310] Trial 31 pruned.
# [07:00:14] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:16] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:00:18] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:20] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:22] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:00:24,037] Trial 32 pruned.
# [07:00:24] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:00:33] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:43] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:00:46,425] Trial 33 finished with value: 0.4697647179300838 and parameters: {'lr': 0.05160665222603649, 'n_estimators': 156, 'max_depth': 9, 'subsample': 0.5821378530908934, 'colsample_bytree': 0.5855602464031099, 'gamma': 0.006690316987727416, 'reg_alpha': 0.38435427498777225, 'reg_lambda': 2.0606678446638806}. Best is trial 33 with value: 0.4697647179300838.
# [07:00:46] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:49] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:00:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:00:58] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:01:04,364] Trial 34 finished with value: 0.44803414230584854 and parameters: {'lr': 0.062401051872323095, 'n_estimators': 159, 'max_depth': 10, 'subsample': 0.5642579061970014, 'colsample_bytree': 0.5672279464791637, 'gamma': 0.007538096427346508, 'reg_alpha': 0.40337140941002664, 'reg_lambda': 1.1507390057933022}. Best is trial 33 with value: 0.4697647179300838.
# [07:01:04] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:01:16] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:22] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:26] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:01:30,429] Trial 35 pruned.
# [07:01:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:01:41] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:48] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:01:52] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:01:59,679] Trial 36 pruned.
# [07:01:59] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:02] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:02:05] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:07] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:02:15,689] Trial 37 pruned.
# [07:02:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:20] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:02:27] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:32] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:02:39] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:02:43,958] Trial 38 pruned.
# [07:02:44] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:03:07] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:03:27] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:03:50] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:04:14] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:04:37,538] Trial 39 pruned.
# [07:04:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:04:42] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:04:49] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:04:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:04:59] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:05:06,041] Trial 40 finished with value: 0.4512103702281478 and parameters: {'lr': 0.014467063329249009, 'n_estimators': 190, 'max_depth': 6, 'subsample': 0.7727298784323651, 'colsample_bytree': 0.6334962212534178, 'gamma': 0.05812256592802063, 'reg_alpha': 0.7806691971664603, 'reg_lambda': 0.0014610257096663766}. Best is trial 33 with value: 0.4697647179300838.
# [07:05:06] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:09] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:05:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:17] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:20] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:05:24,077] Trial 41 pruned.
# [07:05:24] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:05:38] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:45] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:50] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:05:57,162] Trial 42 pruned.
# [07:05:57] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:05:59] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:06:01] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:08] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:06:10,417] Trial 43 pruned.
# [07:06:10] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:14] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:06:20] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:24] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:28] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:06:34,932] Trial 44 pruned.
# [07:06:35] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:37] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:06:38] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:40] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:42] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:06:47,070] Trial 45 pruned.
# [07:06:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:06:54] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:07:04] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:07:15] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:07:25] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:07:33,248] Trial 46 finished with value: 0.4624257231021997 and parameters: {'lr': 0.014627649930428355, 'n_estimators': 303, 'max_depth': 11, 'subsample': 0.5227900409656653, 'colsample_bytree': 0.7113587505226334, 'gamma': 0.12591196216520809, 'reg_alpha': 0.002806461429444396, 'reg_lambda': 0.22552642340264675}. Best is trial 33 with value: 0.4697647179300838.
# [07:07:33] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:07:43] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:07:53] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:00] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:10] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:08:20,820] Trial 47 finished with value: 0.4539184172457745 and parameters: {'lr': 0.015162958945749339, 'n_estimators': 311, 'max_depth': 11, 'subsample': 0.5265335831513014, 'colsample_bytree': 0.7216835048429172, 'gamma': 0.14945717464867314, 'reg_alpha': 0.2937613318137597, 'reg_lambda': 0.29031391411004226}. Best is trial 33 with value: 0.4697647179300838.
# [07:08:21] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:25] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:08:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:36] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:40] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:08:46,908] Trial 48 pruned.
# [07:08:47] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:08:53] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 430, 185760).
# [07:09:03] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:09:12] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [07:09:19] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (429, 430, 184470).
# [I 2025-10-24 07:09:29,055] Trial 49 pruned.
# S1 최적 파라미터: {'lr': 0.05160665222603649, 'n_estimators': 156, 'max_depth': 9, 'subsample': 0.5821378530908934, 'colsample_bytree': 0.5855602464031099, 'gamma': 0.006690316987727416, 'reg_alpha': 0.38435427498777225, 'reg_lambda': 2.0606678446638806}
# S1 최고 F1 점수: 0.4698
# ==================================================

# %%
fix_param_binary = {'random_state': seed,
                    'n_jobs': -1,
                    'verbosity': 2
                    }

fix_param_multi = {'random_sate': seed,
                   'n_jobs': -1,
                   'verbosity': 2,
                   'objective': 'multiclass',
                   'num_class': 3
                   }

# %%
import xgboost as xgb
xgb.set_config(verbosity=0)

# %%
def xgb_smote(split_data, xgb_best_param_dict, test_x):
  preds = {}

  for col_binary in targets_binary:
    print(col_binary)
    x_train, x_val, y_train, y_val = split_data[col_binary]
    best_param = xgb_best_param_dict[col_binary]
    feat = features[col_binary]

    clf_binary = XGBClassifier(**best_param, **fix_param_binary,
                               use_label_encoder=False
    )

    smote = SMOTE(sampling_strategy='minority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_binary.fit(
        x_train_over, y_train_over,
        eval_set=[(x_val[feat], y_val)],
        verbose=False,
    )

    y_pred = clf_binary.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred)
    train_acc = clf_binary.score(x_train[feat], y_train)
    val_acc = clf_binary.score(x_val[feat], y_val)
    print(f'{col_binary} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_binary] = clf_binary.predict(test_x[feat])

  for col_multi in target_multi:
    print(col_multi)
    x_train, x_val, y_train, y_val = split_data[col_multi]
    best_param = xgb_best_param_dict[col_multi]
    feat = features[col_multi]

    clf_multi = XGBClassifier(**best_param, **fix_param_multi,
                              use_label_encoder=False
    )

    smote = SMOTE(sampling_strategy='not majority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_multi.fit(
        x_train_over, y_train_over,
        eval_set=[(x_val[feat], y_val)],
        verbose=False,
    )

    y_pred = clf_multi.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred, average='macro')
    train_acc = clf_multi.score(x_train[feat], y_train)
    val_acc = clf_multi.score(x_val[feat], y_val)
    print(f'{col_multi} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_multi] = clf_multi.predict(test_x[feat])

  return preds

# %%
xgb_best_param_dict
# Out:
# {'Q1': {'lr': 0.005158227045382019,
#   'n_estimators': 500,
#   'max_depth': 6,
#   'subsample': 0.5014653515689952,
#   'colsample_bytree': 0.9874942536147016,
#   'gamma': 0.05156440289130511,
#   'reg_alpha': 9.220831718455408,
#   'reg_lambda': 0.0735303974249241},
#  'Q2': {'lr': 0.007253718909191384,
#   'n_estimators': 432,
#   'max_depth': 3,
#   'subsample': 0.5038814517500667,
#   'colsample_bytree': 0.8406429214642972,
#   'gamma': 0.17523222455117982,
#   'reg_alpha': 1.5438489479832427,
#   'reg_lambda': 0.001091359355825587},
#  'Q3': {'lr': 0.0004404216002912915,
#   'n_estimators': 324,
#   'max_depth': 12,
#   'subsample': 0.5226924038998063,
#   'colsample_bytree': 0.8331966130714386,
#   'gamma': 0.0015323702267678312,
#   'reg_alpha': 0.022735694948487355,
#   'reg_lambda': 0.0013044544681549623},
#  'S2': {'lr': 0.04614071108938825,
#   'n_estimators': 450,
#   'max_depth': 8,
#   'subsample': 0.9421204688567754,
#   'colsample_bytree': 0.5304800114088037,
#   'gamma': 0.016060080731164703,
#   'reg_alpha': 0.1362755293398884,
#   'reg_lambda': 0.7591868489598357},
#  'S3': {'lr': 0.0020760891608048683,
#   'n_estimators': 465,
#   'max_depth': 11,
#   'subsample': 0.6763670646201911,
#   'colsample_bytree': 0.7129825955543805,
#   'gamma': 0.002491652513169936,
#   'reg_alpha': 0.010094081014090846,
#   'reg_lambda': 0.02831915891392152},
#  'S1': {'lr': 0.05160665222603649,
#   'n_estimators': 156,
#   'max_depth': 9,
#   'subsample': 0.5821378530908934,
#   'colsample_bytree': 0.5855602464031099,
#   'gamma': 0.006690316987727416,
#   'reg_alpha': 0.38435427498777225,
#   'reg_lambda': 2.0606678446638806}}

# %%
preds = xgb_smote(split_data, xgb_best_param_dict, test_x)
# Out:
# Q1
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (364, 105, 38220).
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 105, 9450).
# Q1 -> Train Acc: 0.766667 | Validation Accucary: 0.6222 | Validation F1_score: 0.6222
#
# Q2
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (404, 105, 42420).
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 105, 9450).
# Q2 -> Train Acc: 1.000000 | Validation Accucary: 0.5556 | Validation F1_score: 0.5455
#
# Q3
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (432, 105, 45360).
# [07:09:29] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 105, 9450).
# Q3 -> Train Acc: 1.000000 | Validation Accucary: 0.6556 | Validation F1_score: 0.7156
#
# S2
# [07:09:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (468, 109, 51012).
# [07:09:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 109, 9810).
# S2 -> Train Acc: 1.000000 | Validation Accucary: 0.6222 | Validation F1_score: 0.6964
#
# S3
# [07:09:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (476, 111, 52836).
# [07:09:30] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 111, 9990).
# S3 -> Train Acc: 1.000000 | Validation Accucary: 0.7333 | Validation F1_score: 0.8000
#
# S1
# [07:09:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (537, 109, 58533).
# [07:09:31] INFO: /workspace/src/data/iterative_dmatrix.cc:56: Finished constructing the `IterativeDMatrix`: (90, 109, 9810).
# S1 -> Train Acc: 1.000000 | Validation Accucary: 0.5667 | Validation F1_score: 0.5323

# %% [markdown]
# # smote + catb

# %%
catb_best_param_dict = {}

def smote_optuna_binary(split_date):
  for col in targets_binary:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]


    def objective_binary(trial):
      params = {'iterations' :trial.suggest_int("iterations", 100, 1000),
        'learning_rate': trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True),
        'depth': trial.suggest_int("depth", 4, 10),
        'l2_leaf_reg': trial.suggest_float("l2_leaf_reg", 1e-3, 100.0, log=True),
        'bootstrap_type': trial.suggest_categorical("bootstrap_type", ["Bayesian"]),
        'random_strength': trial.suggest_float("random_strength", 1e-3, 10.0, log=True),
        'bagging_temperature': trial.suggest_float("bagging_temperature", 0.0, 10.0),
        'od_type': trial.suggest_categorical("od_type", ["IncToDec", "Iter"]),
        'od_wait': trial.suggest_int("od_wait", 10, 50),
        'border_count': trial.suggest_int("border_count", 32, 255),
        'random_state': seed,
        'verbose': 0
                }

      feat = features[col]
      clf_binary = CatBoostClassifier(**params, task_type="GPU")
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='minority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score = cross_val_score(pipeline, x_train[feat], y_train, cv=cv, scoring='f1').mean()

      trial.report(score, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score

    study = optuna.create_study(direction="maximize")
    study.optimize(objective_binary, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    catb_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_binary(split_data)
# Out:
# [I 2025-10-24 07:09:32,507] A new study created in memory with name: no-name-5b3826f2-4b8d-42d7-bcf3-98a471eb9794
# === target: Q1 ===
# [I 2025-10-24 07:10:35,511] Trial 0 finished with value: 0.5559356190988981 and parameters: {'iterations': 701, 'learning_rate': 1.4583258437369743e-05, 'depth': 5, 'l2_leaf_reg': 3.6772690759626188, 'bootstrap_type': 'Bayesian', 'random_strength': 0.0017646130726175287, 'bagging_temperature': 7.627793722370252, 'od_type': 'IncToDec', 'od_wait': 34, 'border_count': 178}. Best is trial 0 with value: 0.5559356190988981.
# [I 2025-10-24 07:12:28,651] Trial 1 finished with value: 0.5520092566532195 and parameters: {'iterations': 678, 'learning_rate': 0.00041784213762068414, 'depth': 7, 'l2_leaf_reg': 0.5199262345560142, 'bootstrap_type': 'Bayesian', 'random_strength': 4.7459259525908575, 'bagging_temperature': 3.384806192204637, 'od_type': 'Iter', 'od_wait': 30, 'border_count': 240}. Best is trial 0 with value: 0.5559356190988981.
# [I 2025-10-24 07:13:33,769] Trial 2 finished with value: 0.47818540614767213 and parameters: {'iterations': 653, 'learning_rate': 0.008785129315676316, 'depth': 6, 'l2_leaf_reg': 0.0017763498544212308, 'bootstrap_type': 'Bayesian', 'random_strength': 0.056477689157071846, 'bagging_temperature': 0.85826466993558, 'od_type': 'IncToDec', 'od_wait': 16, 'border_count': 131}. Best is trial 0 with value: 0.5559356190988981.
# [I 2025-10-24 07:13:54,108] Trial 3 finished with value: 0.5474555123074392 and parameters: {'iterations': 465, 'learning_rate': 5.461325894959962e-05, 'depth': 8, 'l2_leaf_reg': 8.781136119923616, 'bootstrap_type': 'Bayesian', 'random_strength': 1.8680546274472103, 'bagging_temperature': 0.38425007741732076, 'od_type': 'IncToDec', 'od_wait': 14, 'border_count': 111}. Best is trial 0 with value: 0.5559356190988981.
# [I 2025-10-24 07:15:51,560] Trial 4 finished with value: 0.529463159369844 and parameters: {'iterations': 505, 'learning_rate': 1.0527553452080607e-05, 'depth': 8, 'l2_leaf_reg': 0.0067834460545220365, 'bootstrap_type': 'Bayesian', 'random_strength': 0.47566119348112673, 'bagging_temperature': 4.773073908245253, 'od_type': 'IncToDec', 'od_wait': 36, 'border_count': 159}. Best is trial 0 with value: 0.5559356190988981.
# [I 2025-10-24 07:17:28,498] Trial 5 pruned.
# [I 2025-10-24 07:17:54,095] Trial 6 finished with value: 0.5770652828778118 and parameters: {'iterations': 424, 'learning_rate': 0.00020281508871726234, 'depth': 9, 'l2_leaf_reg': 80.56536282434888, 'bootstrap_type': 'Bayesian', 'random_strength': 0.0035284923065999328, 'bagging_temperature': 9.663393085325234, 'od_type': 'Iter', 'od_wait': 31, 'border_count': 134}. Best is trial 6 with value: 0.5770652828778118.
# [I 2025-10-24 07:18:10,371] Trial 7 pruned.
# [I 2025-10-24 07:18:20,211] Trial 8 finished with value: 0.6030798782834774 and parameters: {'iterations': 264, 'learning_rate': 0.0013582557859227829, 'depth': 5, 'l2_leaf_reg': 58.22380170969132, 'bootstrap_type': 'Bayesian', 'random_strength': 1.0785998791518974, 'bagging_temperature': 8.948175413266362, 'od_type': 'IncToDec', 'od_wait': 36, 'border_count': 203}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:18:32,424] Trial 9 pruned.
# [I 2025-10-24 07:18:39,518] Trial 10 finished with value: 0.5709407238673171 and parameters: {'iterations': 107, 'learning_rate': 0.004406727552417732, 'depth': 4, 'l2_leaf_reg': 60.508943138666844, 'bootstrap_type': 'Bayesian', 'random_strength': 0.07460530855601749, 'bagging_temperature': 9.720928286778115, 'od_type': 'IncToDec', 'od_wait': 50, 'border_count': 64}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:21:29,595] Trial 11 finished with value: 0.6000894047839477 and parameters: {'iterations': 875, 'learning_rate': 0.0001789019686983886, 'depth': 9, 'l2_leaf_reg': 65.60572866933843, 'bootstrap_type': 'Bayesian', 'random_strength': 0.01484818033225943, 'bagging_temperature': 9.395026274642447, 'od_type': 'Iter', 'od_wait': 20, 'border_count': 208}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:25:43,693] Trial 12 finished with value: 0.5695716767719746 and parameters: {'iterations': 942, 'learning_rate': 0.0001206284058549732, 'depth': 10, 'l2_leaf_reg': 8.963769069144977, 'bootstrap_type': 'Bayesian', 'random_strength': 0.014156952685620422, 'bagging_temperature': 7.938063759146731, 'od_type': 'Iter', 'od_wait': 22, 'border_count': 207}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:26:57,501] Trial 13 pruned.
# [I 2025-10-24 07:27:16,529] Trial 14 finished with value: 0.5875253371079142 and parameters: {'iterations': 173, 'learning_rate': 0.00190319375732416, 'depth': 10, 'l2_leaf_reg': 28.470623122485463, 'bootstrap_type': 'Bayesian', 'random_strength': 0.014940518396306234, 'bagging_temperature': 8.668754162879846, 'od_type': 'IncToDec', 'od_wait': 24, 'border_count': 207}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:28:31,380] Trial 15 pruned.
# [I 2025-10-24 07:28:47,967] Trial 16 finished with value: 0.5755382869563828 and parameters: {'iterations': 242, 'learning_rate': 0.00028710929141680536, 'depth': 9, 'l2_leaf_reg': 2.295132937283462, 'bootstrap_type': 'Bayesian', 'random_strength': 9.830995941835477, 'bagging_temperature': 9.989015982952395, 'od_type': 'Iter', 'od_wait': 42, 'border_count': 212}. Best is trial 8 with value: 0.6030798782834774.
# [I 2025-10-24 07:30:06,301] Trial 17 pruned.
# [I 2025-10-24 07:33:08,468] Trial 18 finished with value: 0.6069448059796414 and parameters: {'iterations': 799, 'learning_rate': 6.913518170760424e-05, 'depth': 9, 'l2_leaf_reg': 70.20666830932932, 'bootstrap_type': 'Bayesian', 'random_strength': 0.18472456633512502, 'bagging_temperature': 4.436463990713915, 'od_type': 'Iter', 'od_wait': 41, 'border_count': 249}. Best is trial 18 with value: 0.6069448059796414.
# [I 2025-10-24 07:34:18,149] Trial 19 pruned.
# [I 2025-10-24 07:34:30,515] Trial 20 pruned.
# [I 2025-10-24 07:37:54,987] Trial 21 finished with value: 0.6146516560932579 and parameters: {'iterations': 886, 'learning_rate': 0.00010509986901369273, 'depth': 9, 'l2_leaf_reg': 91.16204665349844, 'bootstrap_type': 'Bayesian', 'random_strength': 0.050347178742413866, 'bagging_temperature': 6.024097721316773, 'od_type': 'Iter', 'od_wait': 40, 'border_count': 226}. Best is trial 21 with value: 0.6146516560932579.
# [I 2025-10-24 07:42:06,323] Trial 22 finished with value: 0.5818387599209518 and parameters: {'iterations': 902, 'learning_rate': 0.00010021742987463149, 'depth': 10, 'l2_leaf_reg': 13.793497920556522, 'bootstrap_type': 'Bayesian', 'random_strength': 0.03463848123248205, 'bagging_temperature': 6.2112830336162075, 'od_type': 'Iter', 'od_wait': 40, 'border_count': 225}. Best is trial 21 with value: 0.6146516560932579.
# [I 2025-10-24 07:44:41,172] Trial 23 pruned.
# [I 2025-10-24 07:46:59,093] Trial 24 pruned.
# [I 2025-10-24 07:49:53,439] Trial 25 pruned.
# [I 2025-10-24 07:55:31,532] Trial 26 pruned.
# [I 2025-10-24 07:57:06,206] Trial 27 finished with value: 0.5905100401606426 and parameters: {'iterations': 533, 'learning_rate': 0.0037128875311249706, 'depth': 8, 'l2_leaf_reg': 90.30908294451473, 'bootstrap_type': 'Bayesian', 'random_strength': 0.007454552873695522, 'bagging_temperature': 6.5980280354649885, 'od_type': 'Iter', 'od_wait': 43, 'border_count': 192}. Best is trial 21 with value: 0.6146516560932579.
# [I 2025-10-24 07:58:36,991] Trial 28 pruned.
# [I 2025-10-24 08:00:04,950] Trial 29 pruned.
# [I 2025-10-24 08:01:09,257] Trial 30 pruned.
# [I 2025-10-24 08:04:11,065] Trial 31 finished with value: 0.6045338492283922 and parameters: {'iterations': 917, 'learning_rate': 0.00016971588528448905, 'depth': 9, 'l2_leaf_reg': 48.17494319214853, 'bootstrap_type': 'Bayesian', 'random_strength': 0.008297214517588618, 'bagging_temperature': 9.076221676629176, 'od_type': 'Iter', 'od_wait': 38, 'border_count': 218}. Best is trial 21 with value: 0.6146516560932579.
# [I 2025-10-24 08:07:16,780] Trial 32 finished with value: 0.5953944429554185 and parameters: {'iterations': 931, 'learning_rate': 0.000130252324904817, 'depth': 9, 'l2_leaf_reg': 34.06129316362651, 'bootstrap_type': 'Bayesian', 'random_strength': 0.006445155868995646, 'bagging_temperature': 8.973743873444008, 'od_type': 'Iter', 'od_wait': 33, 'border_count': 225}. Best is trial 21 with value: 0.6146516560932579.
# [I 2025-10-24 08:10:43,502] Trial 33 finished with value: 0.6218817702012813 and parameters: {'iterations': 802, 'learning_rate': 0.0004490569958622083, 'depth': 10, 'l2_leaf_reg': 83.75327832550892, 'bootstrap_type': 'Bayesian', 'random_strength': 0.03741880854050848, 'bagging_temperature': 7.217618640008894, 'od_type': 'Iter', 'od_wait': 38, 'border_count': 238}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:14:04,743] Trial 34 pruned.
# [I 2025-10-24 08:18:01,916] Trial 35 finished with value: 0.5858860286805673 and parameters: {'iterations': 656, 'learning_rate': 8.802009387528888e-05, 'depth': 10, 'l2_leaf_reg': 22.202891434300646, 'bootstrap_type': 'Bayesian', 'random_strength': 0.00777109147980981, 'bagging_temperature': 3.957890801623114, 'od_type': 'Iter', 'od_wait': 39, 'border_count': 243}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:22:27,548] Trial 36 pruned.
# [I 2025-10-24 08:25:03,786] Trial 37 finished with value: 0.6146684233640756 and parameters: {'iterations': 855, 'learning_rate': 3.6981705791242694e-05, 'depth': 8, 'l2_leaf_reg': 96.02544132084802, 'bootstrap_type': 'Bayesian', 'random_strength': 0.04109154232705658, 'bagging_temperature': 5.828947713108472, 'od_type': 'Iter', 'od_wait': 38, 'border_count': 113}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:28:09,748] Trial 38 pruned.
# [I 2025-10-24 08:30:45,746] Trial 39 finished with value: 0.6090450588141326 and parameters: {'iterations': 845, 'learning_rate': 3.737759249779134e-05, 'depth': 8, 'l2_leaf_reg': 84.16650149131894, 'bootstrap_type': 'Bayesian', 'random_strength': 0.03622740415645327, 'bagging_temperature': 5.734325700696242, 'od_type': 'Iter', 'od_wait': 43, 'border_count': 115}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:33:10,661] Trial 40 pruned.
# [I 2025-10-24 08:35:37,085] Trial 41 finished with value: 0.605088884129364 and parameters: {'iterations': 825, 'learning_rate': 2.161936948408146e-05, 'depth': 8, 'l2_leaf_reg': 85.2351029305084, 'bootstrap_type': 'Bayesian', 'random_strength': 0.123988075372156, 'bagging_temperature': 5.772976983798911, 'od_type': 'Iter', 'od_wait': 41, 'border_count': 108}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:38:39,752] Trial 42 finished with value: 0.6169499933139037 and parameters: {'iterations': 958, 'learning_rate': 4.633638308896334e-05, 'depth': 8, 'l2_leaf_reg': 93.59672287279763, 'bootstrap_type': 'Bayesian', 'random_strength': 0.05136464298634072, 'bagging_temperature': 4.619297272734928, 'od_type': 'Iter', 'od_wait': 47, 'border_count': 145}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:40:53,086] Trial 43 finished with value: 0.600744416873449 and parameters: {'iterations': 965, 'learning_rate': 4.885422212464348e-05, 'depth': 7, 'l2_leaf_reg': 86.11444081386595, 'bootstrap_type': 'Bayesian', 'random_strength': 0.04622451985784173, 'bagging_temperature': 6.946818592703865, 'od_type': 'Iter', 'od_wait': 46, 'border_count': 145}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:43:42,459] Trial 44 finished with value: 0.6008502080791237 and parameters: {'iterations': 875, 'learning_rate': 2.5652065015661292e-05, 'depth': 8, 'l2_leaf_reg': 39.07027407495863, 'bootstrap_type': 'Bayesian', 'random_strength': 0.022791902730644843, 'bagging_temperature': 5.014970838948875, 'od_type': 'Iter', 'od_wait': 48, 'border_count': 95}. Best is trial 33 with value: 0.6218817702012813.
# [I 2025-10-24 08:46:23,201] Trial 45 finished with value: 0.6250421621389364 and parameters: {'iterations': 950, 'learning_rate': 1.0725000291013526e-05, 'depth': 8, 'l2_leaf_reg': 97.05448563128365, 'bootstrap_type': 'Bayesian', 'random_strength': 0.07154403059197816, 'bagging_temperature': 7.5714789101390405, 'od_type': 'Iter', 'od_wait': 36, 'border_count': 143}. Best is trial 45 with value: 0.6250421621389364.
# [I 2025-10-24 08:49:08,166] Trial 46 pruned.
# [I 2025-10-24 08:52:22,796] Trial 47 pruned.
# [I 2025-10-24 08:54:44,997] Trial 48 finished with value: 0.6010338807883676 and parameters: {'iterations': 992, 'learning_rate': 1.3444718816914412e-05, 'depth': 7, 'l2_leaf_reg': 46.27373610505816, 'bootstrap_type': 'Bayesian', 'random_strength': 0.004079399541347504, 'bagging_temperature': 6.3686107242549195, 'od_type': 'Iter', 'od_wait': 37, 'border_count': 98}. Best is trial 45 with value: 0.6250421621389364.
# [I 2025-10-24 08:57:23,153] Trial 49 pruned.
# [I 2025-10-24 08:57:23,154] A new study created in memory with name: no-name-d1ad9779-7927-42e8-a44b-a681ec89eb4e
# Q1 최적 파라미터: {'iterations': 950, 'learning_rate': 1.0725000291013526e-05, 'depth': 8, 'l2_leaf_reg': 97.05448563128365, 'bootstrap_type': 'Bayesian', 'random_strength': 0.07154403059197816, 'bagging_temperature': 7.5714789101390405, 'od_type': 'Iter', 'od_wait': 36, 'border_count': 143}
# Q1 최고 F1 점수: 0.6250
# ==================================================
#
# === target: Q2 ===
# [I 2025-10-24 08:59:19,249] Trial 0 finished with value: 0.6520728745995943 and parameters: {'iterations': 782, 'learning_rate': 0.05095837022060957, 'depth': 7, 'l2_leaf_reg': 0.069687568229395, 'bootstrap_type': 'Bayesian', 'random_strength': 0.05753928328730566, 'bagging_temperature': 3.608429307417522, 'od_type': 'IncToDec', 'od_wait': 21, 'border_count': 163}. Best is trial 0 with value: 0.6520728745995943.
# [I 2025-10-24 09:02:38,985] Trial 1 finished with value: 0.6623907394283014 and parameters: {'iterations': 868, 'learning_rate': 0.0004635721724001282, 'depth': 8, 'l2_leaf_reg': 0.10802866790742956, 'bootstrap_type': 'Bayesian', 'random_strength': 0.17456520174243242, 'bagging_temperature': 6.504045086257535, 'od_type': 'IncToDec', 'od_wait': 39, 'border_count': 134}. Best is trial 1 with value: 0.6623907394283014.
# [I 2025-10-24 09:05:46,366] Trial 2 finished with value: 0.639846107262888 and parameters: {'iterations': 791, 'learning_rate': 4.141739583105101e-05, 'depth': 8, 'l2_leaf_reg': 0.09958570629166531, 'bootstrap_type': 'Bayesian', 'random_strength': 3.612573699044476, 'bagging_temperature': 5.030417422724192, 'od_type': 'IncToDec', 'od_wait': 49, 'border_count': 173}. Best is trial 1 with value: 0.6623907394283014.
# [I 2025-10-24 09:07:43,245] Trial 3 finished with value: 0.6673487359620046 and parameters: {'iterations': 644, 'learning_rate': 0.0041862826569294895, 'depth': 9, 'l2_leaf_reg': 4.521934301896703, 'bootstrap_type': 'Bayesian', 'random_strength': 5.442921652921069, 'bagging_temperature': 9.021432505309022, 'od_type': 'IncToDec', 'od_wait': 42, 'border_count': 140}. Best is trial 3 with value: 0.6673487359620046.
# [I 2025-10-24 09:16:42,060] Trial 4 finished with value: 0.6522415934638166 and parameters: {'iterations': 720, 'learning_rate': 0.008300670648428703, 'depth': 10, 'l2_leaf_reg': 2.677532169233465, 'bootstrap_type': 'Bayesian', 'random_strength': 6.7482619463668, 'bagging_temperature': 0.4314144315638435, 'od_type': 'IncToDec', 'od_wait': 50, 'border_count': 39}. Best is trial 3 with value: 0.6673487359620046.
# [I 2025-10-24 09:16:51,509] Trial 5 pruned.
# [I 2025-10-24 09:17:05,842] Trial 6 finished with value: 0.6757459402279296 and parameters: {'iterations': 183, 'learning_rate': 0.08356557096399164, 'depth': 9, 'l2_leaf_reg': 24.68949055454367, 'bootstrap_type': 'Bayesian', 'random_strength': 2.9325734880640404, 'bagging_temperature': 2.671627528531407, 'od_type': 'IncToDec', 'od_wait': 11, 'border_count': 174}. Best is trial 6 with value: 0.6757459402279296.
# [I 2025-10-24 09:25:44,287] Trial 7 pruned.
# [I 2025-10-24 09:25:53,816] Trial 8 pruned.
# [I 2025-10-24 09:29:02,648] Trial 9 pruned.
# [I 2025-10-24 09:29:16,386] Trial 10 finished with value: 0.6573705202444204 and parameters: {'iterations': 421, 'learning_rate': 0.06229237756489288, 'depth': 6, 'l2_leaf_reg': 99.04493067180545, 'bootstrap_type': 'Bayesian', 'random_strength': 0.004808263747454735, 'bagging_temperature': 2.1985940983385, 'od_type': 'Iter', 'od_wait': 12, 'border_count': 216}. Best is trial 6 with value: 0.6757459402279296.
# [I 2025-10-24 09:30:33,626] Trial 11 pruned.
# [I 2025-10-24 09:30:46,098] Trial 12 finished with value: 0.6641226040924737 and parameters: {'iterations': 141, 'learning_rate': 0.0017302592908048158, 'depth': 9, 'l2_leaf_reg': 0.002079369346258198, 'bootstrap_type': 'Bayesian', 'random_strength': 0.6745915027312843, 'bagging_temperature': 7.055220416559006, 'od_type': 'IncToDec', 'od_wait': 10, 'border_count': 77}. Best is trial 6 with value: 0.6757459402279296.
# [I 2025-10-24 09:32:37,514] Trial 13 pruned.
# [I 2025-10-24 09:33:01,483] Trial 14 pruned.
# [I 2025-10-24 09:35:08,260] Trial 15 pruned.
# [I 2025-10-24 09:35:18,667] Trial 16 pruned.
# [I 2025-10-24 09:35:32,447] Trial 17 finished with value: 0.6702235301839305 and parameters: {'iterations': 439, 'learning_rate': 0.020218720011946356, 'depth': 6, 'l2_leaf_reg': 2.775920555634343, 'bootstrap_type': 'Bayesian', 'random_strength': 2.127721009760065, 'bagging_temperature': 3.862298951971481, 'od_type': 'IncToDec', 'od_wait': 25, 'border_count': 186}. Best is trial 6 with value: 0.6757459402279296.
# [I 2025-10-24 09:35:45,922] Trial 18 pruned.
# [I 2025-10-24 09:35:56,835] Trial 19 pruned.
# [I 2025-10-24 09:36:09,198] Trial 20 pruned.
# [I 2025-10-24 09:36:18,317] Trial 21 pruned.
# [I 2025-10-24 09:36:32,230] Trial 22 finished with value: 0.6818262366467317 and parameters: {'iterations': 331, 'learning_rate': 0.09849041304372688, 'depth': 7, 'l2_leaf_reg': 1.7963209336696702, 'bootstrap_type': 'Bayesian', 'random_strength': 3.2885026492443354, 'bagging_temperature': 7.8418144486768995, 'od_type': 'IncToDec', 'od_wait': 26, 'border_count': 217}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:36:45,725] Trial 23 finished with value: 0.6648682170542635 and parameters: {'iterations': 327, 'learning_rate': 0.09548785533762734, 'depth': 7, 'l2_leaf_reg': 2.097374705204469, 'bootstrap_type': 'Bayesian', 'random_strength': 1.1524394799035513, 'bagging_temperature': 8.210032154660029, 'od_type': 'IncToDec', 'od_wait': 25, 'border_count': 219}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:36:55,142] Trial 24 finished with value: 0.6644251993977628 and parameters: {'iterations': 186, 'learning_rate': 0.04324205090125248, 'depth': 6, 'l2_leaf_reg': 0.504890236408623, 'bootstrap_type': 'Bayesian', 'random_strength': 2.4744805837560775, 'bagging_temperature': 5.980058806943701, 'od_type': 'IncToDec', 'od_wait': 25, 'border_count': 233}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:37:12,465] Trial 25 finished with value: 0.6743169426206361 and parameters: {'iterations': 486, 'learning_rate': 0.023688605492530403, 'depth': 7, 'l2_leaf_reg': 7.928330333113397, 'bootstrap_type': 'Bayesian', 'random_strength': 0.5714615931762581, 'bagging_temperature': 4.309404262823669, 'od_type': 'IncToDec', 'od_wait': 17, 'border_count': 179}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:37:26,361] Trial 26 pruned.
# [I 2025-10-24 09:39:17,600] Trial 27 pruned.
# [I 2025-10-24 09:39:35,111] Trial 28 pruned.
# [I 2025-10-24 09:39:47,244] Trial 29 pruned.
# [I 2025-10-24 09:40:04,761] Trial 30 pruned.
# [I 2025-10-24 09:40:17,717] Trial 31 pruned.
# [I 2025-10-24 09:40:30,264] Trial 32 finished with value: 0.6789981474720431 and parameters: {'iterations': 354, 'learning_rate': 0.05086345419620017, 'depth': 6, 'l2_leaf_reg': 8.687021371355861, 'bootstrap_type': 'Bayesian', 'random_strength': 4.294475787909602, 'bagging_temperature': 3.836205031908022, 'od_type': 'IncToDec', 'od_wait': 32, 'border_count': 199}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:40:39,911] Trial 33 pruned.
# [I 2025-10-24 09:40:53,106] Trial 34 pruned.
# [I 2025-10-24 09:41:06,033] Trial 35 pruned.
# [I 2025-10-24 09:43:22,631] Trial 36 pruned.
# [I 2025-10-24 09:43:32,940] Trial 37 pruned.
# [I 2025-10-24 09:45:38,604] Trial 38 pruned.
# [I 2025-10-24 09:45:46,868] Trial 39 pruned.
# [I 2025-10-24 09:46:16,747] Trial 40 pruned.
# [I 2025-10-24 09:47:14,868] Trial 41 pruned.
# [I 2025-10-24 09:48:11,307] Trial 42 finished with value: 0.6687884991881465 and parameters: {'iterations': 609, 'learning_rate': 0.06999897772326902, 'depth': 5, 'l2_leaf_reg': 2.443077140025516, 'bootstrap_type': 'Bayesian', 'random_strength': 1.5801156106647474, 'bagging_temperature': 3.3333866025991816, 'od_type': 'IncToDec', 'od_wait': 20, 'border_count': 185}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:48:26,605] Trial 43 pruned.
# [I 2025-10-24 09:48:46,664] Trial 44 finished with value: 0.6789708368949813 and parameters: {'iterations': 444, 'learning_rate': 0.07065352184727679, 'depth': 8, 'l2_leaf_reg': 0.04077863105551499, 'bootstrap_type': 'Bayesian', 'random_strength': 6.547275929516314, 'bagging_temperature': 2.565029626782059, 'od_type': 'IncToDec', 'od_wait': 27, 'border_count': 33}. Best is trial 22 with value: 0.6818262366467317.
# [I 2025-10-24 09:49:00,242] Trial 45 pruned.
# [I 2025-10-24 09:51:17,691] Trial 46 pruned.
# [I 2025-10-24 09:51:42,698] Trial 47 pruned.
# [I 2025-10-24 09:55:49,159] Trial 48 pruned.
# [I 2025-10-24 09:56:09,820] Trial 49 pruned.
# [I 2025-10-24 09:56:09,821] A new study created in memory with name: no-name-94ae0a63-ac4e-469f-8bc4-b7c768a9e06e
# Q2 최적 파라미터: {'iterations': 331, 'learning_rate': 0.09849041304372688, 'depth': 7, 'l2_leaf_reg': 1.7963209336696702, 'bootstrap_type': 'Bayesian', 'random_strength': 3.2885026492443354, 'bagging_temperature': 7.8418144486768995, 'od_type': 'IncToDec', 'od_wait': 26, 'border_count': 217}
# Q2 최고 F1 점수: 0.6818
# ==================================================
#
# === target: Q3 ===
# [I 2025-10-24 09:56:30,419] Trial 0 finished with value: 0.6631151489510152 and parameters: {'iterations': 461, 'learning_rate': 1.3914935305865043e-05, 'depth': 8, 'l2_leaf_reg': 0.005204426712052842, 'bootstrap_type': 'Bayesian', 'random_strength': 0.07044622951188226, 'bagging_temperature': 8.24013050995456, 'od_type': 'IncToDec', 'od_wait': 37, 'border_count': 93}. Best is trial 0 with value: 0.6631151489510152.
# [I 2025-10-24 09:58:39,028] Trial 1 finished with value: 0.6514695696527382 and parameters: {'iterations': 557, 'learning_rate': 0.003969882703358422, 'depth': 8, 'l2_leaf_reg': 2.979505097275985, 'bootstrap_type': 'Bayesian', 'random_strength': 0.05673517994601318, 'bagging_temperature': 7.268323053073768, 'od_type': 'Iter', 'od_wait': 34, 'border_count': 201}. Best is trial 0 with value: 0.6631151489510152.
# [I 2025-10-24 09:59:00,742] Trial 2 finished with value: 0.5730310997019857 and parameters: {'iterations': 375, 'learning_rate': 1.6922695335378307e-05, 'depth': 9, 'l2_leaf_reg': 81.1632844898932, 'bootstrap_type': 'Bayesian', 'random_strength': 0.05332236248521714, 'bagging_temperature': 2.2938227252753505, 'od_type': 'Iter', 'od_wait': 22, 'border_count': 43}. Best is trial 0 with value: 0.6631151489510152.
# [I 2025-10-24 09:59:43,436] Trial 3 finished with value: 0.588319104136337 and parameters: {'iterations': 509, 'learning_rate': 0.0002706494607959815, 'depth': 4, 'l2_leaf_reg': 91.86869877739028, 'bootstrap_type': 'Bayesian', 'random_strength': 0.05745743952903775, 'bagging_temperature': 6.4613790394288175, 'od_type': 'IncToDec', 'od_wait': 50, 'border_count': 53}. Best is trial 0 with value: 0.6631151489510152.
# [I 2025-10-24 09:59:52,053] Trial 4 finished with value: 0.6628057044657003 and parameters: {'iterations': 157, 'learning_rate': 0.0008235076081267962, 'depth': 6, 'l2_leaf_reg': 0.13140947468526337, 'bootstrap_type': 'Bayesian', 'random_strength': 0.20437017316998773, 'bagging_temperature': 6.409889353498239, 'od_type': 'IncToDec', 'od_wait': 45, 'border_count': 217}. Best is trial 0 with value: 0.6631151489510152.
# [I 2025-10-24 10:07:24,703] Trial 5 finished with value: 0.6849971325606192 and parameters: {'iterations': 925, 'learning_rate': 8.506765013419595e-05, 'depth': 9, 'l2_leaf_reg': 0.07463696200481806, 'bootstrap_type': 'Bayesian', 'random_strength': 0.0015948123309469549, 'bagging_temperature': 5.668960841585201, 'od_type': 'Iter', 'od_wait': 40, 'border_count': 209}. Best is trial 5 with value: 0.6849971325606192.

# %%
def smote_optuna_multi(split_date):
  for col in target_multi:
    print(f'=== target: {col} ===')
    x_train, x_val, y_train, y_val = split_data[col]

    def objective_multi(trial):
      params = {'learning_rate': trial.suggest_float("lr", 1e-5, 1e-1, log=True),
                'n_estimators': trial.suggest_int('n_estimators', 50, 300),
                'random_state': seed,
                'verbose': 0,
                'loss_function': 'MultiClass'
                }
      feat = features[col]

      clf_binary = CatBoostClassifier(**params, task_type="GPU")
      pipeline = imbalanced_make_pipeline(SMOTE(sampling_strategy='not majority', random_state=seed), clf_binary)

      cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
      score_macro = cross_val_score(pipeline, x_train, y_train, cv=cv, scoring='f1_macro').mean()

      trial.report(score_macro, step=0)
      if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

      return score_macro

    study = optuna.create_study(direction="maximize")
    study.optimize(objective_multi, n_trials=50)

    best_params = study.best_params
    best_score = study.best_value
    catb_best_param_dict[col] = best_params
    print(f"{col} 최적 파라미터: {best_params}")
    print(f"{col} 최고 F1 점수: {best_score:.4f}")
    print("=" * 50, "\n")

# %%
smote_optuna_multi(split_data)

# %%
fix_param_binary = {'random_state': seed,
                    'n_jobs': -1,
                    'verbose': False
                    }

fix_param_multi = {'random_sate': seed,
                   'n_jobs': -1,
                   'verbose': False,
                   'loss_function': 'MultiClass'
                   }

# %%
def catb_smote(split_data, xgb_best_param_dict, test_x):
  preds = {}

  for col_binary in targets_binary:
    print(col_binary)
    x_train, x_val, y_train, y_val = split_data[col_binary]
    best_param = catb_best_param_dict[col_binary]
    feat = features[col_binary]

    clf_binary = CatBoostClassifier(**best_param, **fix_param_binary, task_type="GPU")

    smote = SMOTE(sampling_strategy='minority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_binary.fit(
        x_train_over, y_train_over,
        eval_set=(x_val[feat], y_val),
        early_stopping_rounds=10,
        verbose=False,
        eval_metric='Logloss'
        )

    y_pred = clf_binary.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred)
    train_acc = clf_binary.score(x_train[feat], y_train)
    val_acc = clf_binary.score(x_val[feat], y_val)
    print(f'{col_binary} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_binary] = clf_binary.predict(test_x[feat])

  for col_multi in target_multi:
    print(col_multi)
    x_train, x_val, y_train, y_val = split_data[col_multi]
    best_param = catb_best_param_dict[col_multi]
    feat = features[col_multi]

    clf_multi = CatBoostClassifier(**best_param, **fix_param_multi, task_type="GPU")

    smote = SMOTE(sampling_strategy='not majority', random_state=seed)
    x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

    clf_multi.fit(
        x_train_over, y_train_over
        eval_set=(x_val[feat], y_val),
        early_stopping_rounds=10,
        verbose=False,
        eval_metric='MultiClass'
    )

    y_pred = clf_multi.predict(x_val[feat])

    f1 = f1_score(y_val, y_pred, average='macro')
    train_acc = clf_multi.score(x_train[feat], y_train)
    val_acc = clf_multi.score(x_val[feat], y_val)
    print(f'{col_multi} -> Train Acc: {train_acc:4f} | Validation Accucary: {val_acc:.4f} | Validation F1_score: {f1:.4f}')
    print()

    preds[col_multi] = clf_multi.predict(test_x[feat])

  return preds

# %%
catb_best_param_dict

# %%
preds = catb_smote(split_data, catb_best_param_dict, test_x)

# %% [markdown]
# # voting

# %%
def prediction(models, test, mode=None, weights=None):
    #hard voting일 경우
    if mode == "hard":
        preds = np.asarray([x.predict(test).reshape(-1) for x in models]).T
        res = np.apply_along_axis(
            lambda x: np.argmax(np.bincount(x, weights=weights)),
            axis=1,
            arr=preds
        )
    #soft voting일 경우
    elif mode == "soft":
        preds = np.asarray([x.predict_proba(test) for x in models])
        res = np.zeros(preds[0].shape)
        for pred, weight in zip(preds, weights):
            res = res + pred*weight
        res = np.argmax(preds, axis=0)
    else:
        res = models[0].predict(test)
    return res

#hard voting을 선택하여 모델 중요도별 가중치 제공.
preds = prediction(models, test_x, 'hard', [2,5,4] )

# %%
def voting(split_data,
           lgbm_best_param_dict, xgb_best_param_dict, catb_best_param_dict,
           test_x):

    preds = {}

    # 이진 분류
    for col_binary in targets_binary:
        x_train, x_val, y_train, y_val = split_data[col_binary]
        feat = features[col_binary]

        lgbm = LGBMClassifier(**lgbm_best_param_dict[col_binary],
                              random_state = seed,
                              n_jobs = -1,
                              verbosity = -1)
        xgb = XGBClassifier(**xgb_best_param_dict[col_binary],
                            random_state = seed,
                            n_jobs = -1,
                            verbosity = 0)
        catb = CatBoostClassifier(**catb_best_param_dict[col_binary],
                                  random_state = seed,
                                  n_jobs=-1,
                                  verbose=False)

        smote = SMOTE(sampling_strategy='minority', random_state=seed)
        x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

        voting_binary = VotingClassifier(
            estimators=[('lgbm', lgbm), ('xgb', xgb), ('catb', catb)],
            voting='hard'
        )

        voting_binary.fit(x_train_over, y_train_over)
        y_pred = voting_binary.predict(x_val[feat])

        f1 = f1_score(y_val, y_pred)
        train_acc = voting_binary.score(x_train[feat], y_train)
        val_acc = voting_binary.score(x_val[feat], y_val)

        print(f'Binary {col_binary} -> Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | Val F1: {f1:.4f}')
        preds[col_binary] = voting_binary.predict(test_x[feat])

    # 다중 분류
    for col_multi in target_multi:
        x_train, x_val, y_train, y_val = split_data[col_multi]
        feat = features[col_multi]

        model1 = LGBMClassifier(**lgbm_param[col_multi],
                                random_sate = seed,
                                n_jobs =-1,
                                verbosity = -1,
                                objective = 'multiclass',
                                num_class = 3)
        model2 = XGBClassifier(**xgb_param[col_multi],
                               random_sate = seed,
                               n_jobs =-1,
                               verbosity = 0,
                               objective = 'multiclass',
                               num_class = 3)
        model3 = CatBoostClassifier(**catb_param,
                                    random_sate = seed, n_jobs = -1,
                                    verbose = False,
                                    loss_function = 'MultiClass')

        smote = SMOTE(sampling_strategy='not majority', random_state=seed)
        x_train_over, y_train_over = smote.fit_resample(x_train[feat], y_train)

        voting_multi = VotingClassifier(
            estimators=[('lgbm', model1), ('xgb', model2), ('catb', model3)],
            voting='soft'
        )

        voting_multi.fit(x_train_over, y_train_over)
        y_pred = voting_multi.predict(x_val[feat])

        f1 = f1_score(y_val, y_pred, average='macro')
        train_acc = voting_multi.score(x_train[feat], y_train)
        val_acc = voting_multi.score(x_val[feat], y_val)

        print(f'Multi {col_multi} -> Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f} | Val F1: {f1:.4f}')
        preds[col_multi] = voting_multi.predict(test_x[feat])

    return preds

# %%
preds = voting(split_data, lgbm_best_param_dict, xgb_best_param_dict, catb_best_param_dict, test_x)

# %% [markdown]
# # stacking

# %% [markdown]
# # 결과저장

# %%
final = sample_submission[['subject_id','sleep_date','lifelog_date']].copy()
final['lifelog_date'] = pd.to_datetime(final['lifelog_date']).dt.date

final['id'] = final['subject_id'] + '_' + final['lifelog_date'].astype(str)
assert len(final) == len(preds['S1'])

target_list = ['Q1', 'Q2', 'Q3', 'S1','S2','S3']
for col in target_list:
  final[col] = preds[col].astype(int)

submission_final = final[['subject_id','sleep_date','lifelog_date', 'Q1','Q2','Q3','S1','S2','S3']]
submission_final.to_csv('submission_final.csv',index=False)

from google.colab import files
files.download("submission_final.csv")
